# %% [markdown]
# ## Full Journal Processing Workbook

# %% [markdown]
# ### Module Incudes

# %%
# General
import os
import io
from pathlib import Path
from typing import List, Dict
import json
import re
import time
from datetime import datetime
import logging
from math import floor

# OCR processing
from google.cloud import vision
from pdf2image import convert_from_path
from PIL import Image, ImageDraw, ImageFont
from pathlib import Path
import fitz  # for pdf work: PyMuPDF
from xml.sax.saxutils import escape


# XML
from xml.sax.saxutils import escape

# Local modules
from data_processing.ocr_processing import (
    make_image_preprocess_mask,
    build_processed_pdf, 
    save_processed_pdf_data, 
    load_processed_PDF_data
)

from data_processing.gpt_processing import (
    start_batch_with_retries, 
    set_model_settings,
    delete_api_files
)

from data_processing.xml_processing import split_xml_pages, split_xml_on_pagebreaks, save_pages_to_xml

from data_processing.text_processing import get_text_from_file

from data_processing.gpt_processing.pdf_journal_process import (
    setup_logger,
    generate_clean_batch, batch_section, batch_translate, 
    save_sectioning_data, save_translation_data, save_cleaned_data
)

# %% [markdown]
# ## Parameters

# %%
# files
project_dir = Path("/Users/phapman/Desktop/tnh-scholar/")
data_dir = project_dir / "data_processing"
pdf_dir = data_dir / "PDF" / "Phat_Giao_journals" # directory to read pdfs from
journal_dir = data_dir / "processed_journal_data"
journal_name = "phat-giao-viet-nam-1956-11"
pdf_to_process = pdf_dir / f"{journal_name}.pdf"
working_dir = journal_dir / journal_name
ocr_data_dir = journal_dir / "ocr_data"
cleaned_xml_path = working_dir / f"full_cleaned_{journal_name}.xml"
batch_job_dir = working_dir / "processing_batch_files"
clean_batch_jsonl = batch_job_dir / f"clean_batch_{journal_name}.jsonl"
ocr_file = journal_dir / journal_name / f"full_OCR_{journal_name}.xml"
translation_xml_path = working_dir / f"translation_{journal_name}.xml"
section_batch_jsonl = batch_job_dir / "section_batch.jsonl"
translate_batch_jsonl = batch_job_dir / "translation_batch.jsonl"
section_metadata_path = working_dir / "section_metadata.json"
raw_json_metadata_path = working_dir / "raw_metadata_response.txt"
logfile = data_dir / "gpt_processing" / "pdf_journal_process" / "processing_info.log"

# %% [markdown]
# ### Settings for cleaning OCR generated text

# %%
# setup for OCR cleaning
def user_wrap_function_clean(text_block):   # Function to wrap user message sent to model. Currently no wrapping.
    return text_block  

model_settings_clean = {
    "gpt-4o": {
        "max_tokens": 1000, # default value
        "temperature": 0
    }
}
system_message_clean = """You are a meticulous and consistent world expert at cleaning OCR-generated Vietnamese text. 
You are cleaning pages from a 1950's Buddhist Journal. 
Each line of scanned data will be enclosed in <> brackets. Leave <> brackets in place.
Your goal is to minimally modify the text to generate a cleaned version.
Do not remove any content from the main body of the text. 
Do not change the line formatting. 

You can use the semantic meaning of the text to infer corrections—but make no semantic changes. 
You can also add diacritical marks if they are missing or clearly inaccurate. 
Do not change any proper names, except to add missing diacritical marks or to fix orthographic errors if the context is clear.  

This particular text has a title marker in the footer, "Phat Giao Viet Nam," and also a publishing mark diagonally across the text.  
The publishing watermark is "TU VIEN HUE QUANG"  and is faint so only parts of it may appear in some locations in the text. Remove all text corresponding to the watermark.
Text corresponding to the footer, the publishing watermak (or part thereof), and page numbers can be omitted.

IMPORTANT: If the page is blank return: blank page 
IMPORTANT: Output the corrected text only with no comments (including ``` xml)"""

# %% [markdown]
# ### Settings for sectioning a journal

# %%
# finding journal sections
model_settings_section = {
    "gpt-4o": {
        "max_tokens": 5000,
        "temperature": 0.25
    }
}

system_message_section = """You are a highly skilled assistant processing a Vietnamese Buddhist journal scanned from OCR. 
Use the title: "Journal of Vietnamese Buddhism."
You will be determining the journal sections by page number. You will also generate metadata for the full text and each section. 
You will return this metadata in JSON format.

Instructions:
1. Analyze the text and divide it into sections based on logical breaks, such as headings, topic changes, or clear shifts in content.
2. Ensure every page is part of a section. The first title page should always be its own section. Blank pages should be titled "blank page".
3. For each section, provide:
   - The original title in Vietnamese (`section_title_vi`).
   - The translated title in English (`section_title_en`).
   - The author's name if it is available (`section_author`). 
   - A one-paragraph summary of the section in English (`section_summary`).
   - A list of keywords for the section that are related to its content, these can be proper names, specific concepts, or contextual information.
   - The section's start and end page numbers (`start_page` and `end_page`).
   - Use "null" for any data that is not available (such as author name) for the section.

4. Return the output as a JSON object with the following schema:
{
    "journal_summary": "A one-page summary of the whole journal in English.",
    "sections": [
        {
            "title_vi": "Original title in Vietnamese",
            "title_en": "Translated title in English",
            "author": "Name of the author of the section",
            "summary": "One-paragraph summary of the section in English",
            "keywords": "A list of keywords for the section",
            "start_page":  X,
            "end_page":  Y
        },
        ...
    ]
}

5.  Ensure the JSON is well-formed and adheres strictly to the provided schema.
6.  IMPORTANT: ensure every page is part of a section and sections appear in order of pagination."""

# %% [markdown]
# ### Settings for translation

# %%
# translation settings
model_settings_translate = {
    "gpt-4o": {
        "max_tokens": 5000,  # a default value, updated per batch
        "temperature": 0.75
    }
}

system_message_translate = """You are the world's foremost translator of Zen Master Thich Nhat Hanh's Vietnamese writing into English, following the language style of the plumvillage.org website.
The text is based on an OCR scan of a journal you edited from 1956-1958. Use the title: "Journal of Vietnamese Buddhism" for the journal when it is referenced.
You will be translating a single section of the journal and will be provided with the section title in English. 
Translate for the most meaningful, typical, and eloquent English interpretation that is simple, yet poetic. 
Translate precisely; do not add change the text or add commentary.  
Notes on the text can be added in the <notes>.
Make corrections in the text only where necessary (for example if words are missing) to create logical flow. Note all corrections in the <translation-notes>. 
Do not change <pagebreak> tag postioning. Each translated page must match its original page source as pages will be studied side by side with the original Vietnamese.
Infer paragraphs and text structure from the text layout.
Add XML tags for clarity, using only the following tags: 

   <section> for major sections.
   <subsection> for subsections.
   <title> for main titles of sections and subsections. 
   <subtitle> for subtitles of sections and subsections. 
   <heading> for headings that do not mark titles or subtitles
   <p> for paragraphs.
   <br/> for linebreaks that add meaning such as in poems or other structures.
   <TOC> for tables of contents
   <author> for named authors of sections (only)
   <i> for italics. 
   <b> for bold.
   <notes>
   <translation-notes>

You may use <notes> at the end of the section for notes on historical, cultural, spiritual, or other interesting elements of the text.
You want advanced students of Thay to understand the text in its larger historical context, in the context of Vietnamese Buddhism, and in the context of his life.
You may add <translation-notes> at the end of the section as a commentary to summarize your translation choices. 
For <translation-notes>, you may include information on Sino-Vietnamese, complex, unusual, poetic, or other interesting terms, and significant corrections to the text. 
In the <translation-notes> include the original Vietnamese terms for reference.

IMPORTANT: All titles, XML sections, text, poetry, quotations, and terms MUST BE TRANSLATED TO ENGLISH. Do not however, translate names of people; leave names in Vietnamese with diacritics.
IMPORTANT: Return pure XML with no formatting marks such as xml or ```.
IMPORTANT: The returned XML should begin and end with <section> tags."""

# %% [markdown]
# ## Process execution pipeline

# %% [markdown]
# ### start logger

# %%
logger = setup_logger(logfile)

# %% [markdown]
# ### OCR Scan

# %%
# process pdf with OCR through google vision
client = vision.ImageAnnotatorClient()
pre_mask1 = make_image_preprocess_mask(0.1)  #this masks the bottom 10% of the image where the publishing mark is located
text_pages, word_locations_list, annotated_images, unannotated_images = build_processed_pdf(pdf_to_process, client, pre_mask1)
# Out:
# 2024-12-03 19:19:39,371 - google.auth._default - DEBUG - Checking None for explicit credentials as part of auth process...
# 2024-12-03 19:19:39,372 - google.auth._default - DEBUG - Checking Cloud SDK credentials as part of auth process...
# I0000 00:00:1733282379.839355  366393 check_gcp_environment_no_op.cc:29] ALTS: Platforms other than Linux and Windows are not supported
# 2024-12-03 19:19:39,842 - ocr_processing - INFO - Processing file with 99 pages:
# 	/Users/phapman/Desktop/tnh-scholar/data_processing/PDF/Phat_Giao_journals/phat-giao-viet-nam-1956-09-10.pdf
# 2024-12-03 19:19:39,843 - ocr_processing - INFO - Processing page 1/99...
# 2024-12-03 19:19:42,760 - google.auth.transport.requests - DEBUG - Making request: POST https://oauth2.googleapis.com/token
# 2024-12-03 19:19:45,136 - ocr_processing - INFO - Processing page 2/99...
# 2024-12-03 19:19:46,863 - ocr_processing - INFO - Processing page 3/99...
# 2024-12-03 19:19:48,463 - ocr_processing - INFO - Processing page 4/99...
# 2024-12-03 19:19:50,693 - ocr_processing - INFO - Processing page 5/99...
# 2024-12-03 19:19:53,580 - ocr_processing - INFO - Processing page 6/99...
# 2024-12-03 19:19:55,627 - ocr_processing - INFO - Processing page 7/99...
# 2024-12-03 19:19:57,793 - ocr_processing - INFO - Processing page 8/99...
# 2024-12-03 19:20:00,718 - ocr_processing - INFO - Processing page 9/99...
# 2024-12-03 19:20:03,876 - ocr_processing - INFO - Processing page 10/99...
# 2024-12-03 19:20:08,799 - ocr_processing - INFO - Processing page 11/99...
# 2024-12-03 19:20:10,257 - ocr_processing - INFO - Processing page 12/99...
# 2024-12-03 19:20:12,338 - ocr_processing - INFO - Processing page 13/99...
# 2024-12-03 19:20:15,520 - ocr_processing - INFO - Processing page 14/99...
# 2024-12-03 19:20:18,357 - ocr_processing - INFO - Processing page 15/99...
# 2024-12-03 19:20:20,621 - ocr_processing - INFO - Processing page 16/99...
# 2024-12-03 19:20:23,709 - ocr_processing - INFO - Processing page 17/99...
# 2024-12-03 19:20:27,258 - ocr_processing - INFO - Processing page 18/99...
# 2024-12-03 19:20:29,572 - ocr_processing - INFO - Processing page 19/99...
# 2024-12-03 19:20:32,585 - ocr_processing - INFO - Processing page 20/99...
# 2024-12-03 19:20:35,919 - ocr_processing - INFO - Processing page 21/99...
# save processed info
save_processed_pdf_data(ocr_data_dir, journal_name, text_pages, word_locations_list, annotated_images, unannotated_images)
save_pages_to_xml(working_dir / f"full_OCR_{journal_name}.xml", text_pages, overwrite=True)
# Out:
# Processed data saved in: /Users/phapman/Desktop/tnh-scholar/data_processing/processed_journal_data/phat-giao-viet-nam-1956-09-10
# XML file successfully saved at /Users/phapman/Desktop/tnh-scholar/data_processing/processed_journal_data/phat-giao-viet-nam-1956-09-10/full_OCR_phat-giao-viet-nam-1956-09-10.xml

# %% [markdown]
# ### Data Cleaning

# %%
generate_clean_batch(ocr_file, clean_batch_jsonl, system_message_clean, user_wrap_function_clean)
job_description = f"cleaning for {journal_name} on {ocr_file}"
cleaned_data = start_batch_with_retries(clean_batch_jsonl, job_description) # run the clean process
save_cleaned_data(cleaned_xml_path, cleaned_data, journal_name)
# Out:
# 2024-12-03 19:24:54,497 - journal_process - INFO - Processing file: /Users/phapman/Desktop/tnh-scholar/data_processing/processed_journal_data/phat-giao-viet-nam-1956-09-10/full_OCR_phat-giao-viet-nam-1956-09-10.xml
# 2024-12-03 19:24:54,500 - journal_process - INFO - Found 99 pages in /Users/phapman/Desktop/tnh-scholar/data_processing/processed_journal_data/phat-giao-viet-nam-1956-09-10/full_OCR_phat-giao-viet-nam-1956-09-10.xml.
# 2024-12-03 19:24:54,541 - gpt_interface - INFO - Creating JSONL batch file with 75598 requested tokens:
# 	/Users/phapman/Desktop/tnh-scholar/data_processing/processed_journal_data/phat-giao-viet-nam-1956-09-10/processing_batch_files/clean_batch_phat-giao-viet-nam-1956-09-10.jsonl
# 2024-12-03 19:24:54,541 - gpt_interface - DEBUG - Batch request details: Method=POST, URL=/v1/chat/completions
# 2024-12-03 19:24:54,542 - gpt_interface - DEBUG - Batch parameters:
#     model: gpt-4o
#     max_tokens: 145
#     temperature: 0.75
# 2024-12-03 19:24:54,547 - gpt_interface - INFO - JSONL file created at: /Users/phapman/Desktop/tnh-scholar/data_processing/processed_journal_data/phat-giao-viet-nam-1956-09-10/processing_batch_files/clean_batch_phat-giao-viet-nam-1956-09-10.jsonl
# 2024-12-03 19:24:54,547 - journal_process - INFO - Batch file created successfully: /Users/phapman/Desktop/tnh-scholar/data_processing/processed_journal_data/phat-giao-viet-nam-1956-09-10/processing_batch_files/clean_batch_phat-giao-viet-nam-1956-09-10.jsonl
# 2024-12-03 19:24:57,995 - gpt_interface - INFO - Batch Initiated with description: 12-03-2024 19:24:54 PST | clean_batch_phat-giao-viet-nam-1956-09-10.jsonl | cleaning for phat-giao-viet-nam-1956-09-10 on /Users/phapman/Desktop/tnh-scholar/data_processing/processed_journal_data/phat-giao-viet-nam-1956-09-10/full_OCR_phat-giao-viet-nam-1956-09-10.xml
# 2024-12-03 19:24:57,995 - gpt_interface - INFO - batch info: batch_674fcb89da8c8191bd9bfcd8482dc4e7, 1733282697, file-W394E3sSVEmPw4Lk9dLXUW
# 2024-12-03 19:24:57,996 - gpt_interface - INFO - Batch started: attempt 1.
# 2024-12-03 19:24:57,996 - gpt_interface - INFO - Polling batch status for batch ID batch_674fcb89da8c8191bd9bfcd8482dc4e7 ...
# 2024-12-03 19:25:09,566 - gpt_interface - DEBUG - Batch ID batch_674fcb89da8c8191bd9bfcd8482dc4e7 status: in_progress
# 2024-12-03 19:25:09,568 - gpt_interface - INFO - Batch status: in_progress. Retrying in 10 seconds...
# 2024-12-03 19:25:23,373 - gpt_interface - DEBUG - Batch ID batch_674fcb89da8c8191bd9bfcd8482dc4e7 status: in_progress
# 2024-12-03 19:25:23,374 - gpt_interface - INFO - Batch status: in_progress. Retrying in 13 seconds...
# 2024-12-03 19:25:39,657 - gpt_interface - DEBUG - Batch ID batch_674fcb89da8c8191bd9bfcd8482dc4e7 status: in_progress
# 2024-12-03 19:25:39,660 - gpt_interface - INFO - Batch status: in_progress. Retrying in 16 seconds...
# 2024-12-03 19:26:00,243 - gpt_interface - DEBUG - Batch ID batch_674fcb89da8c8191bd9bfcd8482dc4e7 status: in_progress
# 2024-12-03 19:26:00,244 - gpt_interface - INFO - Batch status: in_progress. Retrying in 20 seconds...
# 2024-12-03 19:26:26,853 - gpt_interface - DEBUG - Batch ID batch_674fcb89da8c8191bd9bfcd8482dc4e7 status: completed
# 2024-12-03 19:26:26,855 - gpt_interface - INFO - Batch processing for ID batch_674fcb89da8c8191bd9bfcd8482dc4e7 completed successfully.
# 2024-12-03 19:26:28,212 - gpt_interface - INFO - Batch completed successfully after 1 attempts.
# 2024-12-03 19:26:28,213 - journal_process - INFO - Saving cleaned content to XML for journal 'phat-giao-viet-nam-1956-09-10'.
# 2024-12-03 19:26:28,221 - journal_process - INFO - Cleaned journal saved successfully to:
# 	/Users/phapman/Desktop/tnh-scholar/data_processing/processed_journal_data/phat-giao-viet-nam-1956-09-10/full_cleaned_phat-giao-viet-nam-1956-09-10.xml
# XML file successfully saved at /Users/phapman/Desktop/tnh-scholar/data_processing/processed_journal_data/phat-giao-viet-nam-1956-09-10/full_cleaned_phat-giao-viet-nam-1956-09-10.xml

# %% [markdown]
# ### Sectioning

# %%
set_model_settings(model_settings_section)
metadata_serial_json = batch_section(cleaned_xml_path, section_batch_jsonl, system_message_section, journal_name) # run the section process
save_sectioning_data(section_metadata_path, raw_json_metadata_path, metadata_serial_json, journal_name)
# Out:
# 2024-12-03 19:26:28,231 - journal_process - INFO - Starting sectioning batch for phat-giao-viet-nam-1956-09-10 with file:
# 	/Users/phapman/Desktop/tnh-scholar/data_processing/processed_journal_data/phat-giao-viet-nam-1956-09-10/full_cleaned_phat-giao-viet-nam-1956-09-10.xml
# 2024-12-03 19:26:28,234 - gpt_interface - INFO - Creating JSONL batch file with 5000 requested tokens:
# 	/Users/phapman/Desktop/tnh-scholar/data_processing/processed_journal_data/phat-giao-viet-nam-1956-09-10/processing_batch_files/section_batch.jsonl
# 2024-12-03 19:26:28,234 - gpt_interface - DEBUG - Batch request details: Method=POST, URL=/v1/chat/completions
# 2024-12-03 19:26:28,234 - gpt_interface - DEBUG - Batch parameters:
#     model: gpt-4o
#     max_tokens: 5000
#     temperature: 0.25
#     response_format: {'type': 'json_object'}
# 2024-12-03 19:30:57,723 - gpt_interface - INFO - Batch processing for ID batch_674fcc4f05ec8191934799b429e97831 completed successfully.
# 2024-12-03 19:30:58,464 - gpt_interface - INFO - Batch completed successfully after 7 attempts.
# 2024-12-03 19:30:58,465 - journal_process - INFO - Successfully batch sectioned journal 'phat-giao-viet-nam-1956-09-10' with input file: /Users/phapman/Desktop/tnh-scholar/data_processing/processed_journal_data/phat-giao-viet-nam-1956-09-10/full_cleaned_phat-giao-viet-nam-1956-09-10.xml.
# 2024-12-03 19:30:58,471 - journal_process - INFO - Parsed and validated metadata successfully written to /Users/phapman/Desktop/tnh-scholar/data_processing/processed_journal_data/phat-giao-viet-nam-1956-09-10/section_metadata.json
# PosixPath('/Users/phapman/Desktop/tnh-scholar/data_processing/processed_journal_data/phat-giao-viet-nam-1956-09-10/section_metadata.json')

# %% [markdown]
# ### Translating

# %%
set_model_settings(model_settings_translate)
translation_data = batch_translate(cleaned_xml_path, translate_batch_jsonl, section_metadata_path, system_message_translate, journal_name)
save_translation_data(translation_xml_path, translation_data, journal_name)
# Out:
# 2024-12-04 11:33:21,268 - journal_process - INFO - Starting translation batch for journal 'phat-giao-viet-nam-1956-11':
# 	with file: /Users/phapman/Desktop/tnh-scholar/data_processing/processed_journal_data/phat-giao-viet-nam-1956-11/full_cleaned_phat-giao-viet-nam-1956-11.xml
# 	metadata: /Users/phapman/Desktop/tnh-scholar/data_processing/processed_journal_data/phat-giao-viet-nam-1956-11/section_metadata.json
# 2024-12-04 11:33:21,271 - journal_process - DEBUG - page groups found: [(1, 1), (2, 2), (3, 4), (5, 7), (8, 14), (15, 19), (20, 20), (21, 25), (26, 28), (29, 35), (36, 40), (41, 43), (44, 45), (46, 49), (50, 50), (51, 51), (52, 52)]
# 2024-12-04 11:33:21,273 - journal_process - DEBUG - section_contents[0]:
# PHẬT GIÁO
# NAM
# HUỆ QUANG
# AM DỊCH
# 2
# THUẬT HẠN
# SỐ II RA NGÀY 15 THÁNG 6 ĐINH - DẬU
# HUẾ CÙNG NG-HỘI PHẬT GIÁO VIỆT NAM XUẤT-BẢN
# NGUYỆT-SAN
# <pagebreak page='1' />
# 2024-12-04 11:33:21,275 - journal_process - DEBUG - section 0: VIETNAMESE BUDDHISM NAM HUỆ QUANG TRANSLATION added for batch processing.
# 2024-12-04 11:33:21,276 - journal_process - DEBUG - section 1: blank page added for batch processing.
# 2024-12-04 11:33:21,276 - journal_process - DEBUG - section 2: IMPLEMENTATION added for batch processing.
# 2024-12-04 11:33:21,279 - journal_process - DEBUG - section 3: THE ISSUE OF KNOWLEDGE AND ACTION added for batch processing.
# 2024-12-04 11:33:21,284 - journal_process - DEBUG - section 4: THE TEACHINGS OF VIETNAMESE BUDDHISM added for batch processing.
# 2024-12-04 11:33:21,287 - journal_process - DEBUG - section 5: THE ISSUE OF TRAINING MONKS added for batch processing.
# 2024-12-04 11:33:21,288 - journal_process - DEBUG - section 6: THE BOAT RETURNS TO THE OLD SHORE added for batch processing.
# 2024-12-04 11:33:21,291 - journal_process - DEBUG - section 7: SOCIETY AND HUMANITY ON THE PRINCIPLE OF SELF-TRANSFORMATION AND COLLECTIVE TRANSFORMATION added for batch processing.
# 2024-12-04 11:33:21,293 - journal_process - DEBUG - section 8: THE DANGER OF ATTACHMENT TO VIEWS added for batch processing.
# 2024-12-04 11:33:21,297 - journal_process - DEBUG - section 9: THE FIRST WOUND added for batch processing.
# 2024-12-04 11:33:21,300 - journal_process - DEBUG - section 10: UNDERSTANDING IS PRACTICING THE DHARMA added for batch processing.
# 2024-12-04 11:33:21,302 - journal_process - DEBUG - section 11: METHODS OF BUDDHIST STUDY added for batch processing.
# 2024-12-04 11:33:21,303 - journal_process - DEBUG - section 12: ALL SENTIENT BEINGS added for batch processing.
# 2024-12-04 11:33:21,305 - journal_process - DEBUG - section 13: UNDERSTANDING BUDDHISM added for batch processing.
# 2024-12-04 11:33:21,305 - journal_process - DEBUG - section 14: NEWS added for batch processing.
# 2024-12-04 11:33:21,306 - journal_process - DEBUG - section 15: blank page added for batch processing.
# 2024-12-04 11:33:21,308 - journal_process - INFO - Running batch processing for journal 'phat-giao-viet-nam-1956-11'.
# 2024-12-04 11:33:21,308 - gpt_interface - INFO - Creating JSONL batch file with 60182 requested tokens:
# 	/Users/phapman/Desktop/tnh-scholar/data_processing/processed_journal_data/phat-giao-viet-nam-1956-11/processing_batch_files/translation_batch.jsonl
# 2024-12-04 11:33:21,309 - gpt_interface - DEBUG - Batch request details: Method=POST, URL=/v1/chat/completions
# 2024-12-04 11:33:21,309 - gpt_interface - DEBUG - Batch parameters:
#     model: gpt-4o
#     max_tokens: 1120
#     temperature: 0.75
# 2024-12-04 11:33:21,311 - gpt_interface - INFO - JSONL file created at: /Users/phapman/Desktop/tnh-scholar/data_processing/processed_journal_data/phat-giao-viet-nam-1956-11/processing_batch_files/translation_batch.jsonl
# 2024-12-04 11:33:23,588 - gpt_interface - INFO - Batch Initiated with description: 12-04-2024 11:33:21 PST | translation_batch.jsonl | Batch for translating journal 'phat-giao-viet-nam-1956-11'
# 2024-12-04 11:33:23,589 - gpt_interface - INFO - batch info: batch_6750ae831eac819187eaee425334c78f, 1733340803, file-G6HDu9WCuhuaiGEHD1YJb8
# 2024-12-04 11:33:23,590 - gpt_interface - INFO - Batch started: attempt 1.
# 2024-12-04 11:33:23,590 - gpt_interface - INFO - Polling batch status for batch ID batch_6750ae831eac819187eaee425334c78f ...
# 2024-12-04 11:33:34,092 - gpt_interface - DEBUG - Batch ID batch_6750ae831eac819187eaee425334c78f status: in_progress
# 2024-12-04 11:33:34,093 - gpt_interface - INFO - Batch status: in_progress. Retrying in 10 seconds...
# 2024-12-04 11:33:47,284 - gpt_interface - DEBUG - Batch ID batch_6750ae831eac819187eaee425334c78f status: in_progress
# 2024-12-04 11:33:47,285 - gpt_interface - INFO - Batch status: in_progress. Retrying in 13 seconds...
# 2024-12-04 11:34:03,496 - gpt_interface - DEBUG - Batch ID batch_6750ae831eac819187eaee425334c78f status: in_progress
# 2024-12-04 11:34:03,497 - gpt_interface - INFO - Batch status: in_progress. Retrying in 16 seconds...
# 2024-12-04 11:34:23,886 - gpt_interface - DEBUG - Batch ID batch_6750ae831eac819187eaee425334c78f status: in_progress
# 2024-12-04 11:34:23,888 - gpt_interface - INFO - Batch status: in_progress. Retrying in 20 seconds...
# 2024-12-04 11:34:50,125 - gpt_interface - DEBUG - Batch ID batch_6750ae831eac819187eaee425334c78f status: in_progress
# 2024-12-04 11:34:50,127 - gpt_interface - INFO - Batch status: in_progress. Retrying in 26 seconds...
# 2024-12-04 11:35:23,316 - gpt_interface - DEBUG - Batch ID batch_6750ae831eac819187eaee425334c78f status: finalizing
# 2024-12-04 11:35:23,317 - gpt_interface - INFO - Batch status: finalizing. Retrying in 33 seconds...
# 2024-12-04 11:36:05,534 - gpt_interface - DEBUG - Batch ID batch_6750ae831eac819187eaee425334c78f status: finalizing
# 2024-12-04 11:36:05,535 - gpt_interface - INFO - Batch status: finalizing. Retrying in 42 seconds...
# 2024-12-04 11:36:59,777 - gpt_interface - DEBUG - Batch ID batch_6750ae831eac819187eaee425334c78f status: completed
# 2024-12-04 11:36:59,777 - gpt_interface - INFO - Batch processing for ID batch_6750ae831eac819187eaee425334c78f completed successfully.
# 2024-12-04 11:37:00,784 - gpt_interface - INFO - Batch completed successfully after 1 attempts.
# 2024-12-04 11:37:00,784 - journal_process - INFO - Batch translation completed for journal 'phat-giao-viet-nam-1956-11'.
# 2024-12-04 11:37:00,785 - journal_process - DEBUG - section 16: Decree No. 200/P3 dated 1-8 1956 added for batch processing.
# 2024-12-04 11:37:00,786 - journal_process - INFO - Running batch processing for journal 'phat-giao-viet-nam-1956-11'.
# 2024-12-04 11:37:00,787 - gpt_interface - INFO - Creating JSONL batch file with 1014 requested tokens:
# 	/Users/phapman/Desktop/tnh-scholar/data_processing/processed_journal_data/phat-giao-viet-nam-1956-11/processing_batch_files/translation_batch.jsonl
# 2024-12-04 11:37:00,787 - gpt_interface - DEBUG - Batch request details: Method=POST, URL=/v1/chat/completions
# 2024-12-04 11:37:00,788 - gpt_interface - DEBUG - Batch parameters:
#     model: gpt-4o
#     max_tokens: 1014
#     temperature: 0.75
# 2024-12-04 11:37:00,789 - gpt_interface - INFO - JSONL file created at: /Users/phapman/Desktop/tnh-scholar/data_processing/processed_journal_data/phat-giao-viet-nam-1956-11/processing_batch_files/translation_batch.jsonl
# 2024-12-04 11:37:01,744 - gpt_interface - INFO - Batch Initiated with description: 12-04-2024 11:37:00 PST | translation_batch.jsonl | Batch for translating journal 'phat-giao-viet-nam-1956-11'
# 2024-12-04 11:37:01,746 - gpt_interface - INFO - batch info: batch_6750af5d992c81919e1b9e1b52dbfb73, 1733341021, file-HgNjtQR26GpDAw5vk2VpMq
# 2024-12-04 11:37:01,747 - gpt_interface - INFO - Batch started: attempt 1.
# 2024-12-04 11:37:01,747 - gpt_interface - INFO - Polling batch status for batch ID batch_6750af5d992c81919e1b9e1b52dbfb73 ...
# 2024-12-04 11:37:11,944 - gpt_interface - DEBUG - Batch ID batch_6750af5d992c81919e1b9e1b52dbfb73 status: failed
# 2024-12-04 11:37:11,945 - gpt_interface - ERROR - Batch processing for ID batch_6750af5d992c81919e1b9e1b52dbfb73 failed.
# 2024-12-04 11:37:11,945 - gpt_interface - ERROR - Attempt 1 failed. Retrying batch process in 5 seconds...
# 2024-12-04 11:37:17,969 - gpt_interface - INFO - Batch Initiated with description: 12-04-2024 11:37:16 PST | translation_batch.jsonl | Batch for translating journal 'phat-giao-viet-nam-1956-11'
# 2024-12-04 11:37:17,971 - gpt_interface - INFO - batch info: batch_6750af6dbb0c81919705eba57885f727, 1733341037, file-3jPnv8AjEsZRJ8z3ygkvot
# 2024-12-04 11:37:17,972 - gpt_interface - INFO - Batch started: attempt 2.
# 2024-12-04 11:37:17,973 - gpt_interface - INFO - Polling batch status for batch ID batch_6750af6dbb0c81919705eba57885f727 ...
# 2024-12-04 11:37:28,222 - gpt_interface - DEBUG - Batch ID batch_6750af6dbb0c81919705eba57885f727 status: failed
# 2024-12-04 11:37:28,224 - gpt_interface - ERROR - Batch processing for ID batch_6750af6dbb0c81919705eba57885f727 failed.
# 2024-12-04 11:37:28,225 - gpt_interface - ERROR - Attempt 2 failed. Retrying batch process in 5 seconds...
# 2024-12-04 11:37:35,029 - gpt_interface - INFO - Batch Initiated with description: 12-04-2024 11:37:33 PST | translation_batch.jsonl | Batch for translating journal 'phat-giao-viet-nam-1956-11'
# 2024-12-04 11:37:35,030 - gpt_interface - INFO - batch info: batch_6750af7e750c8191b632039d49aeca84, 1733341054, file-8HBNxfLfsHrKvWBbXDNs4y
# 2024-12-04 11:37:35,031 - gpt_interface - INFO - Batch started: attempt 3.
# 2024-12-04 11:37:35,032 - gpt_interface - INFO - Polling batch status for batch ID batch_6750af7e750c8191b632039d49aeca84 ...
# 2024-12-04 11:37:45,230 - gpt_interface - DEBUG - Batch ID batch_6750af7e750c8191b632039d49aeca84 status: failed
# 2024-12-04 11:37:45,231 - gpt_interface - ERROR - Batch processing for ID batch_6750af7e750c8191b632039d49aeca84 failed.
# 2024-12-04 11:37:45,232 - gpt_interface - ERROR - Attempt 3 failed. Retrying batch process in 5 seconds...
# 2024-12-04 11:37:51,359 - gpt_interface - INFO - Batch Initiated with description: 12-04-2024 11:37:50 PST | translation_batch.jsonl | Batch for translating journal 'phat-giao-viet-nam-1956-11'
# 2024-12-04 11:37:51,361 - gpt_interface - INFO - batch info: batch_6750af8f117c819198e1e49cf22433e0, 1733341071, file-2kTwLYRU8fixPGL563wnqc
# 2024-12-04 11:37:51,362 - gpt_interface - INFO - Batch started: attempt 4.
# 2024-12-04 11:37:51,363 - gpt_interface - INFO - Polling batch status for batch ID batch_6750af8f117c819198e1e49cf22433e0 ...
# 2024-12-04 11:38:01,577 - gpt_interface - DEBUG - Batch ID batch_6750af8f117c819198e1e49cf22433e0 status: failed
# 2024-12-04 11:38:01,579 - gpt_interface - ERROR - Batch processing for ID batch_6750af8f117c819198e1e49cf22433e0 failed.
# 2024-12-04 11:38:01,579 - gpt_interface - ERROR - Attempt 4 failed. Retrying batch process in 5 seconds...
# 2024-12-04 11:38:07,665 - gpt_interface - INFO - Batch Initiated with description: 12-04-2024 11:38:06 PST | translation_batch.jsonl | Batch for translating journal 'phat-giao-viet-nam-1956-11'
# 2024-12-04 11:38:07,665 - gpt_interface - INFO - batch info: batch_6750af9f7d44819194271ade7eaf5f51, 1733341087, file-MH2zmiFSDqSxxAiRaVfVHB
# 2024-12-04 11:38:07,666 - gpt_interface - INFO - Batch started: attempt 5.
# 2024-12-04 11:38:07,666 - gpt_interface - INFO - Polling batch status for batch ID batch_6750af9f7d44819194271ade7eaf5f51 ...
# 2024-12-04 11:38:17,865 - gpt_interface - DEBUG - Batch ID batch_6750af9f7d44819194271ade7eaf5f51 status: failed
# 2024-12-04 11:38:17,866 - gpt_interface - ERROR - Batch processing for ID batch_6750af9f7d44819194271ade7eaf5f51 failed.
# 2024-12-04 11:38:17,867 - gpt_interface - ERROR - Attempt 5 failed. Retrying batch process in 5 seconds...
# 2024-12-04 11:38:23,918 - gpt_interface - INFO - Batch Initiated with description: 12-04-2024 11:38:22 PST | translation_batch.jsonl | Batch for translating journal 'phat-giao-viet-nam-1956-11'
# 2024-12-04 11:38:23,919 - gpt_interface - INFO - batch info: batch_6750afafc2cc8191996bec590c37cc71, 1733341103, file-AESaXyMcbQ76EUCyK47NNB
# 2024-12-04 11:38:23,920 - gpt_interface - INFO - Batch started: attempt 6.
# 2024-12-04 11:38:23,922 - gpt_interface - INFO - Polling batch status for batch ID batch_6750afafc2cc8191996bec590c37cc71 ...
# 2024-12-04 11:38:34,124 - gpt_interface - DEBUG - Batch ID batch_6750afafc2cc8191996bec590c37cc71 status: failed
# 2024-12-04 11:38:34,125 - gpt_interface - ERROR - Batch processing for ID batch_6750afafc2cc8191996bec590c37cc71 failed.
# 2024-12-04 11:38:34,126 - gpt_interface - ERROR - Attempt 6 failed. Retrying batch process in 5 seconds...
# 2024-12-04 11:38:40,095 - gpt_interface - INFO - Batch Initiated with description: 12-04-2024 11:38:39 PST | translation_batch.jsonl | Batch for translating journal 'phat-giao-viet-nam-1956-11'
# 2024-12-04 11:38:40,099 - gpt_interface - INFO - batch info: batch_6750afbfd8f88191a8b09f09d01d84ee, 1733341119, file-DWhSyaEcZkEpqVqVh7mYbH
# 2024-12-04 11:38:40,100 - gpt_interface - INFO - Batch started: attempt 7.
# 2024-12-04 11:38:40,101 - gpt_interface - INFO - Polling batch status for batch ID batch_6750afbfd8f88191a8b09f09d01d84ee ...
# 2024-12-04 11:38:50,344 - gpt_interface - DEBUG - Batch ID batch_6750afbfd8f88191a8b09f09d01d84ee status: failed
# 2024-12-04 11:38:50,347 - gpt_interface - ERROR - Batch processing for ID batch_6750afbfd8f88191a8b09f09d01d84ee failed.
# 2024-12-04 11:38:50,348 - gpt_interface - ERROR - Attempt 7 failed. Retrying batch process in 5 seconds...
# 2024-12-04 11:38:56,294 - gpt_interface - INFO - Batch Initiated with description: 12-04-2024 11:38:55 PST | translation_batch.jsonl | Batch for translating journal 'phat-giao-viet-nam-1956-11'
# 2024-12-04 11:38:56,295 - gpt_interface - INFO - batch info: batch_6750afd020a88191b2c20a1d5aed7de5, 1733341136, file-UnCCMVsrotfrJfoC1tcwzA
# 2024-12-04 11:38:56,296 - gpt_interface - INFO - Batch started: attempt 8.
# 2024-12-04 11:38:56,296 - gpt_interface - INFO - Polling batch status for batch ID batch_6750afd020a88191b2c20a1d5aed7de5 ...
# 2024-12-04 11:39:06,521 - gpt_interface - DEBUG - Batch ID batch_6750afd020a88191b2c20a1d5aed7de5 status: failed
# 2024-12-04 11:39:06,522 - gpt_interface - ERROR - Batch processing for ID batch_6750afd020a88191b2c20a1d5aed7de5 failed.
# 2024-12-04 11:39:06,523 - gpt_interface - ERROR - Attempt 8 failed. Retrying batch process in 5 seconds...
# 2024-12-04 11:39:12,653 - gpt_interface - INFO - Batch Initiated with description: 12-04-2024 11:39:11 PST | translation_batch.jsonl | Batch for translating journal 'phat-giao-viet-nam-1956-11'
# 2024-12-04 11:39:12,654 - gpt_interface - INFO - batch info: batch_6750afe074f48191baa71bab8f073a5a, 1733341152, file-AyVB72JSuSDR8qFVcTKMtb
# 2024-12-04 11:39:12,655 - gpt_interface - INFO - Batch started: attempt 9.
# 2024-12-04 11:39:12,655 - gpt_interface - INFO - Polling batch status for batch ID batch_6750afe074f48191baa71bab8f073a5a ...
# 2024-12-04 11:39:22,867 - gpt_interface - DEBUG - Batch ID batch_6750afe074f48191baa71bab8f073a5a status: failed
# 2024-12-04 11:39:22,868 - gpt_interface - ERROR - Batch processing for ID batch_6750afe074f48191baa71bab8f073a5a failed.
# 2024-12-04 11:39:22,868 - gpt_interface - ERROR - Attempt 9 failed. Retrying batch process in 5 seconds...
# 2024-12-04 11:39:29,656 - gpt_interface - INFO - Batch Initiated with description: 12-04-2024 11:39:27 PST | translation_batch.jsonl | Batch for translating journal 'phat-giao-viet-nam-1956-11'
# 2024-12-04 11:39:29,658 - gpt_interface - INFO - batch info: batch_6750aff12acc8191ab36f613a2aabf8e, 1733341169, file-KkAMD6umHdWJsK5TBW6Av6
# 2024-12-04 11:39:29,659 - gpt_interface - INFO - Batch started: attempt 10.
# 2024-12-04 11:39:29,660 - gpt_interface - INFO - Polling batch status for batch ID batch_6750aff12acc8191ab36f613a2aabf8e ...
# 2024-12-04 11:39:39,891 - gpt_interface - DEBUG - Batch ID batch_6750aff12acc8191ab36f613a2aabf8e status: failed
# 2024-12-04 11:39:39,892 - gpt_interface - ERROR - Batch processing for ID batch_6750aff12acc8191ab36f613a2aabf8e failed.
# 2024-12-04 11:39:39,893 - gpt_interface - ERROR - Attempt 10 failed. Retrying batch process in 5 seconds...
# 2024-12-04 11:39:46,039 - gpt_interface - INFO - Batch Initiated with description: 12-04-2024 11:39:44 PST | translation_batch.jsonl | Batch for translating journal 'phat-giao-viet-nam-1956-11'
# 2024-12-04 11:39:46,041 - gpt_interface - INFO - batch info: batch_6750b001c208819187bbf9a0445d2814, 1733341185, file-XFf52pWeUBKoMMAMd21Hzv
# 2024-12-04 11:39:46,041 - gpt_interface - INFO - Batch started: attempt 11.
# 2024-12-04 11:39:46,042 - gpt_interface - INFO - Polling batch status for batch ID batch_6750b001c208819187bbf9a0445d2814 ...
# 2024-12-04 11:39:56,236 - gpt_interface - DEBUG - Batch ID batch_6750b001c208819187bbf9a0445d2814 status: failed
# 2024-12-04 11:39:56,239 - gpt_interface - ERROR - Batch processing for ID batch_6750b001c208819187bbf9a0445d2814 failed.
# 2024-12-04 11:39:56,240 - gpt_interface - ERROR - Attempt 11 failed. Retrying batch process in 5 seconds...
# 2024-12-04 11:40:02,627 - gpt_interface - INFO - Batch Initiated with description: 12-04-2024 11:40:01 PST | translation_batch.jsonl | Batch for translating journal 'phat-giao-viet-nam-1956-11'
# 2024-12-04 11:40:02,629 - gpt_interface - INFO - batch info: batch_6750b0125c148191b9c7db3fa3538422, 1733341202, file-Ub9aQ7AMjPApme8yPiMB9A
# 2024-12-04 11:40:02,630 - gpt_interface - INFO - Batch started: attempt 12.
# 2024-12-04 11:40:02,630 - gpt_interface - INFO - Polling batch status for batch ID batch_6750b0125c148191b9c7db3fa3538422 ...
# 2024-12-04 11:40:12,904 - gpt_interface - DEBUG - Batch ID batch_6750b0125c148191b9c7db3fa3538422 status: failed
# 2024-12-04 11:40:12,905 - gpt_interface - ERROR - Batch processing for ID batch_6750b0125c148191b9c7db3fa3538422 failed.
# 2024-12-04 11:40:12,906 - gpt_interface - ERROR - Attempt 12 failed. Retrying batch process in 5 seconds...
# 2024-12-04 11:40:19,005 - gpt_interface - INFO - Batch Initiated with description: 12-04-2024 11:40:17 PST | translation_batch.jsonl | Batch for translating journal 'phat-giao-viet-nam-1956-11'
# 2024-12-04 11:40:19,007 - gpt_interface - INFO - batch info: batch_6750b022adf08191a24aa2b4fec28e69, 1733341218, file-EEzuwsYqKdNuReG6SgLjwt
# 2024-12-04 11:40:19,007 - gpt_interface - INFO - Batch started: attempt 13.
# 2024-12-04 11:40:19,008 - gpt_interface - INFO - Polling batch status for batch ID batch_6750b022adf08191a24aa2b4fec28e69 ...
# 2024-12-04 11:40:29,246 - gpt_interface - DEBUG - Batch ID batch_6750b022adf08191a24aa2b4fec28e69 status: failed
# 2024-12-04 11:40:29,248 - gpt_interface - ERROR - Batch processing for ID batch_6750b022adf08191a24aa2b4fec28e69 failed.
# 2024-12-04 11:40:29,249 - gpt_interface - ERROR - Attempt 13 failed. Retrying batch process in 5 seconds...
# 2024-12-04 11:40:35,403 - gpt_interface - INFO - Batch Initiated with description: 12-04-2024 11:40:34 PST | translation_batch.jsonl | Batch for translating journal 'phat-giao-viet-nam-1956-11'
# 2024-12-04 11:40:35,404 - gpt_interface - INFO - batch info: batch_6750b0332cbc8191b8b688562c4c3a74, 1733341235, file-YT15qJskfezNwJMAv3MCaN
# 2024-12-04 11:40:35,404 - gpt_interface - INFO - Batch started: attempt 14.
# 2024-12-04 11:40:35,406 - gpt_interface - INFO - Polling batch status for batch ID batch_6750b0332cbc8191b8b688562c4c3a74 ...
# 2024-12-04 11:40:45,607 - gpt_interface - DEBUG - Batch ID batch_6750b0332cbc8191b8b688562c4c3a74 status: failed
# 2024-12-04 11:40:45,609 - gpt_interface - ERROR - Batch processing for ID batch_6750b0332cbc8191b8b688562c4c3a74 failed.
# 2024-12-04 11:40:45,610 - gpt_interface - ERROR - Attempt 14 failed. Retrying batch process in 5 seconds...
# 2024-12-04 11:40:51,747 - gpt_interface - INFO - Batch Initiated with description: 12-04-2024 11:40:50 PST | translation_batch.jsonl | Batch for translating journal 'phat-giao-viet-nam-1956-11'
# 2024-12-04 11:40:51,748 - gpt_interface - INFO - batch info: batch_6750b04367308191bff828bc5937408b, 1733341251, file-XBXmF6dcMRx5WuiKrGzP4x
# 2024-12-04 11:40:51,748 - gpt_interface - INFO - Batch started: attempt 15.
# 2024-12-04 11:40:51,749 - gpt_interface - INFO - Polling batch status for batch ID batch_6750b04367308191bff828bc5937408b ...
# 2024-12-04 11:41:01,960 - gpt_interface - DEBUG - Batch ID batch_6750b04367308191bff828bc5937408b status: failed
# 2024-12-04 11:41:01,961 - gpt_interface - ERROR - Batch processing for ID batch_6750b04367308191bff828bc5937408b failed.
# 2024-12-04 11:41:01,963 - gpt_interface - ERROR - Attempt 15 failed. Retrying batch process in 5 seconds...
# 2024-12-04 11:41:07,755 - gpt_interface - INFO - Batch Initiated with description: 12-04-2024 11:41:06 PST | translation_batch.jsonl | Batch for translating journal 'phat-giao-viet-nam-1956-11'
# 2024-12-04 11:41:07,756 - gpt_interface - INFO - batch info: batch_6750b05388408191a1b976ee0f7ff599, 1733341267, file-EhvQDgzETauGoEpr171DgW
# 2024-12-04 11:41:07,758 - gpt_interface - INFO - Batch started: attempt 16.
# 2024-12-04 11:41:07,758 - gpt_interface - INFO - Polling batch status for batch ID batch_6750b05388408191a1b976ee0f7ff599 ...
# 2024-12-04 11:41:17,946 - gpt_interface - DEBUG - Batch ID batch_6750b05388408191a1b976ee0f7ff599 status: failed
# 2024-12-04 11:41:17,947 - gpt_interface - ERROR - Batch processing for ID batch_6750b05388408191a1b976ee0f7ff599 failed.
# 2024-12-04 11:41:17,948 - gpt_interface - ERROR - Attempt 16 failed. Retrying batch process in 5 seconds...
# 2024-12-04 11:41:24,079 - gpt_interface - INFO - Batch Initiated with description: 12-04-2024 11:41:22 PST | translation_batch.jsonl | Batch for translating journal 'phat-giao-viet-nam-1956-11'
# 2024-12-04 11:41:24,080 - gpt_interface - INFO - batch info: batch_6750b063e478819197ba85506998558e, 1733341284, file-4mTKee2FYaMZuxgjk1GYB4
# 2024-12-04 11:41:24,081 - gpt_interface - INFO - Batch started: attempt 17.
# 2024-12-04 11:41:24,083 - gpt_interface - INFO - Polling batch status for batch ID batch_6750b063e478819197ba85506998558e ...
# 2024-12-04 11:41:34,317 - gpt_interface - DEBUG - Batch ID batch_6750b063e478819197ba85506998558e status: in_progress
# 2024-12-04 11:41:34,318 - gpt_interface - INFO - Batch status: in_progress. Retrying in 10 seconds...
# 2024-12-04 11:41:47,516 - gpt_interface - DEBUG - Batch ID batch_6750b063e478819197ba85506998558e status: in_progress
# 2024-12-04 11:41:47,517 - gpt_interface - INFO - Batch status: in_progress. Retrying in 13 seconds...
# 2024-12-04 11:42:03,716 - gpt_interface - DEBUG - Batch ID batch_6750b063e478819197ba85506998558e status: in_progress
# 2024-12-04 11:42:03,717 - gpt_interface - INFO - Batch status: in_progress. Retrying in 16 seconds...
# 2024-12-04 11:42:23,920 - gpt_interface - DEBUG - Batch ID batch_6750b063e478819197ba85506998558e status: in_progress
# 2024-12-04 11:42:23,921 - gpt_interface - INFO - Batch status: in_progress. Retrying in 20 seconds...
# 2024-12-04 11:42:50,126 - gpt_interface - DEBUG - Batch ID batch_6750b063e478819197ba85506998558e status: completed
# 2024-12-04 11:42:50,128 - gpt_interface - INFO - Batch processing for ID batch_6750b063e478819197ba85506998558e completed successfully.
# 2024-12-04 11:42:50,767 - gpt_interface - INFO - Batch completed successfully after 17 attempts.
# 2024-12-04 11:42:50,769 - journal_process - INFO - Batch translation completed for journal 'phat-giao-viet-nam-1956-11'.
# 2024-12-04 11:42:50,770 - journal_process - INFO - Saving translated content to XML for journal 'phat-giao-viet-nam-1956-11'.
# 2024-12-04 11:42:50,773 - journal_process - INFO - Translated journal saved successfully to:
# 	/Users/phapman/Desktop/tnh-scholar/data_processing/processed_journal_data/phat-giao-viet-nam-1956-11/translation_phat-giao-viet-nam-1956-11.xml

# %% [markdown]
# ### Cleanup

# %%
confirmation = input("Are you sure you want to delete API files? 'y' to confirm: ").strip().lower()
if confirmation == 'y':
    delete_api_files(datetime.now())
    print("Files deleted successfully.")
else:
    print("Deletion canceled.")
# Out:
# Deleted file: file-DNemfvfXHVd4NQRJ3juN63 (created on 2024-12-03 15:30:42)
# Deleted file: file-Lw3LPdUTfVhxKWXufsGRSF (created on 2024-12-03 15:29:49)
# Deleted file: file-VHdECWSKXUyH9PWgU5XNem (created on 2024-12-03 15:24:02)
# Deleted file: file-X1efeiL6iRFwo1Hi2XzZsm (created on 2024-12-03 15:23:45)
# Deleted file: file-Qu4EEAEh7BdqGM3AtHgRZq (created on 2024-12-03 15:23:28)
# Deleted file: file-Scs1FgJoDAscTyx8dNJwza (created on 2024-12-03 15:23:11)
# Deleted file: file-JmAoAUNQzvPBd2k6xtGt6j (created on 2024-12-03 15:22:55)
# Deleted file: file-H8qi8GxrvtCdEyHK54bxFH (created on 2024-12-03 15:22:38)
# Deleted file: file-4k94obuu1tCAtYqXwPidYX (created on 2024-12-03 15:21:45)
# Deleted file: file-GkeUQV9243TKpDyAtF7EKU (created on 2024-12-03 13:36:39)
# Deleted file: file-TcH8VchQ5gogkDk2aAhaH9 (created on 2024-12-03 13:36:23)
# Deleted file: file-1fmZy7TR7yNRovkzfycZn1 (created on 2024-12-03 13:36:02)
# Deleted file: file-PeYciMgS1yMQsL28YTZiUs (created on 2024-12-03 13:34:22)
# Deleted file: file-3abTXqd3gubv2mzfKpzcBW (created on 2024-12-03 13:34:05)
# Deleted file: file-3VAY16Jw2eVtheBQuGhEDg (created on 2024-12-03 13:33:49)
# Deleted file: file-DJsuccRH28iRjpEX1rtNrr (created on 2024-12-03 13:33:33)
# Deleted file: file-REtp1aUuihcW72kBfuPxZP (created on 2024-12-03 13:33:17)
# Deleted file: file-BBhi9iaEwM7NyvKZapiUfu (created on 2024-12-03 13:33:00)
# Deleted file: file-UYD4kb8kaWEMRMAhh7Ayq8 (created on 2024-12-03 13:32:35)
