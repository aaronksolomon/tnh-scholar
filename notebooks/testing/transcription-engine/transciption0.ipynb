# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Import necessary modules
from pathlib import Path

import pandas as pd

from IPython.core.display import HTML
from IPython.display import display

from dotenv import load_dotenv

# Import the transcription service modules
from tnh_scholar.audio_processing.transcription_service import (
    TranscriptionServiceFactory,
)

# Load environment variables from .env file
load_dotenv()
# Out:
# True

# %%
def test_transcription(audio_file_path, provider="whisper", options=None):
    """
    Test transcription with the specified provider.
    
    Args:
        audio_file_path: Path to the audio file
        provider: 'whisper' or 'assemblyai'
    
    Returns:
        Transcription result
    """
    if options is None:
        options = {}
    # Create the transcription service
    service = TranscriptionServiceFactory.create_service(provider=provider)

    # Print some info
    print(f"Testing transcription with {provider} service...")
    print(f"Audio file: {audio_file_path}")

    # Transcribe the audio file
    result = service.transcribe(audio_file_path, options)

    # Print the transcription text
    print("\nTranscription result:")
    print("-" * 80)
    print(result["text"])
    print("-" * 80)

    # Return the full result for further inspection
    return result

# %%
def test_format_generation(audio_file_path, provider="whisper", format_type="srt"):
    """
    Test generation of formatted transcription (SRT or VTT).
    
    Args:
        audio_file_path: Path to the audio file
        provider: 'whisper' or 'assemblyai'
        format_type: 'srt' or 'vtt'
    
    Returns:
        Formatted transcription as string
    """
    # Create the transcription service
    service = TranscriptionServiceFactory.create_service(provider=provider)
    
    # Print some info
    print(f"Testing {format_type.upper()} generation with {provider} service...")
    print(f"Audio file: {audio_file_path}")
    
    # Generate the formatted transcription
    formatted_result = service.transcribe_to_format(
        audio_file_path, 
        format_type=format_type
    )
    
    # Print a sample of the formatted output
    print(f"\nSample {format_type.upper()} output:")
    print("-" * 80)
    lines = formatted_result.splitlines()
    sample_lines = lines[:min(20, len(lines))]  # First 20 lines or all if fewer
    print("\n".join(sample_lines))
    print("...")
    print("-" * 80)
    
    # Save the formatted output to a file
    output_file = Path(f"transcription_output_{provider}_{format_type}.{format_type}")
    with open(output_file, "w", encoding="utf-8") as f:
        f.write(formatted_result)
    print(f"Full output saved to: {output_file}")
    
    return formatted_result

# %%
# Replace with your audio file path
working_dir = Path.home() / "Desktop" / "wouter_video"
audio_file = working_dir / "dt_trim_enh_short.wav"
if not audio_file.exists:
    raise FileNotFoundError("Not found.")

# %%
# Test Whisper transcription
options = {
    "language": "vi",
           }
whisper_result = test_transcription(audio_file, provider="whisper", options=options)
# Out:
# Testing transcription with whisper service...
# Audio file: /Users/phapman/Desktop/wouter_video/dt_trim_enh_short.wav
#
# Transcription result:
# --------------------------------------------------------------------------------
# Thưa đại chúng, vừa rồi Tù Viện có mấy ngày trong khóa tu nấu ăn online Mục đích là để giới thiệu cho cộng đồng những người ăn chay những món ăn được nấu ở trong Tù Viện Thế nên đã đại chúng khuyến khích phẫu hội chia sẻ ngày hôm nay về cước ăn và đi chợ Đó cũng có một chút đặc biệt là bởi vì chúng ta là một cộng đồng ăn chay Chay ở đây bao gồm veggie và bacon Và mọi người cũng rất nhiều người có hương thú xem là các thầy, các sư cô họ ăn cái gì hằng ngày ở trong Tù Viện Và cũng cả họ đi chợ như thế nào nữa Thì có lẽ là bởi vì phẫu hội có thâm niên đi chợ lâu nhất so với đại chúng Thế nên xin cảm ơn đại chúng những kinh nghiệm kinh tưởng để chia sẻ cho lĩnh vực này Nó cũng thú vị và nó cũng là một cái gì đó rất thiết thực với đời sống tu học Mặc dù khi vào chùa người ta hướng về những sự thực tập cao nhất, những sự hướng dẫn có giá trị nhất Tâm bản phải được dựa trên tuệ giá và của kinh nghiệm Nhưng đồng thời những hệ tu trước, nhiều thế hệ trước cũng truyền lại một câu rất là chi lý Không có thật không vượt được đảo À, có nghĩa là bên cạnh những cái điều cao siêu, những điều lý tưởng rất là tuyệt vời Thì chúng ta vẫn phải đối diện với những cái rất là bình dị, rất là con người trong quá trình tu học của mình Và vì thế nó ảnh hưởng rất nhiều đến thành quả tu học của chúng ta Và nếu chúng ta phải biết cách làm sao để sử dụng nó và nâng cấp nó mỗi ngày qua mỗi thế hệ Thì nó mới có cái lợi lạc nhiều nhất được Với trí thức một loài người bây giờ Thì chúng ta thấy rõ rằng là thức ăn nó có ảnh hưởng đến không chỉ thân và tâm của chúng ta Nó còn là một cái sự an toàn của chúng ta nữa Nó không phải chỉ là cái thưởng thức hay theo đuổi Mà nó còn là một cái yêu cầu của cuộc sống Như thế nào mới là tốt, nó còn tùy cái nhận thức Nhưng đồng thời nó gần gần cũng có đạt đến cái nhận thức chung Rằng điều đó rất quan trọng Ngày xưa khi mà chúng ta chưa có hiểu biết nhiều về thức ăn Về các loại thức ăn nó ảnh hưởng đến cơ thể như thế nào, đến tâm thức như thế nào, đến cộng đồng, đến giống như thế nào Thì cái sự chọn lửa và nhận thức của thức ăn nó cũng khác Còn bây giờ nó được tông cấp nhiều hơn Và đồng thời cũng vì thế nó sinh ra nhiều nhận thức mới Và cũng khá là khác biệt Bởi vậy khi chúng tôi nghĩ Phụ nói về 4 loại thức ăn Thầy Vô có thể phải đề nghị cho chúng là nên đi tìm những bài giảng của Sông về 4 loại thức ăn Đó là một hướng dẫn ở mức tuyệt vời nhất Nó dựa trên tuổi giác và táo lý của cửa sự thực tập Nhưng ở đây các thầy cũng đề nghị chia sẻ ở mức độ nó gần sát với cuộc sống của chúng ta nhiều hơn Để chúng ta có cái nhìn gần gũi và có càng đảm tham dự vào cái đội sống tu học này Khi mà Người tham dự vào trong sống tu học theo truyền thống là Mai Thì gần như tất cả đều được sắp xếp vào trong cái đội luân phiên nước ăn Với cái trách nhiệm đó, cái vị trí để phục vụ đại chúng đó Thì chúng ta sẽ gần như là phải tiếp xúc với thức ăn gần như mỗi ngày Phải chuẩn bị mỗi ngày, bởi vì đó là cái công việc dễ dàng nhất để
# --------------------------------------------------------------------------------
# /Users/phapman/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages/pydantic/main.py:426: UserWarning: Pydantic serializer warnings:
#   Expected `str` but got `float` with value `320.0` - serialized value may not be as expected
#   return self.__pydantic_serializer__.to_python(

# %%
# Examine specific parts of the result
print("\nExamining detailed result:")
print(f"Language: {whisper_result['language']}")
print(f"Audio duration: {whisper_result.get('audio_duration', 'Not available')} milliseconds")
print(f"Word count: {len(whisper_result.get('words', []))}")
# Out:
# Examining detailed result:
# Language: vietnamese
# Audio duration: Not available milliseconds
# Word count: 697

# %%
# Test AssemblyAI transcription
options = {
    "language_code": "vi", 
    "language_detection": False, 
    "speaker_labels": False, 
}
assemblyai_result = test_transcription(audio_file, provider="assemblyai", options=options)
# Out:
# Testing transcription with assemblyai service...
# Audio file: /Users/phapman/Desktop/wouter_video/dt_trim_enh_short.wav
#
# Transcription result:
# --------------------------------------------------------------------------------
# Chính thưa đại chúng, vừa rồi Tù Viện có mấy ngày trong khóa tu nấu ăn online. Mục đích là để giới thiệu cho cộng đồng những người ăn chay, những món ăn được nấu ở trong Tù Viện. Thế nên đã đại chúng đề nghị phẫu hội chia sẻ ngày hôm nay về cước ăn và đi chợ. Đó cũng có một chút đặc biệt là bởi vì chúng ta là một cộng đồng ăn chay. Chay ở đây có bao gồm veggie và bacon. Và mọi người cũng rất nhiều người có hứng thú xem là các thầy, các sư cô họ ăn cái gì hằng ngày ở trong tú biển. và cũng cả họ đi chợ như thế nào nữa. Thì... có lẽ là bởi vì Pháp hội là người có... có thâm niên đi chợ lâu nhất so với đại chúng. Cho nên xin cảm ơn đại chúng những kiên tượng để chia sẻ cho lĩnh vực này. Nó cũng thú vị và nó... cũng là một cái gì đó rất là thiết thực với đời sống tu học. Mặc dù khi vào chùa, người ta hướng về những sự thực tập cao nhất, những sự hướng dẫn có giá trị nhất. Căn bản phải được dựa trên tuyển giác và của kinh nghiệm. Nhưng đồng thời, những hệ tu trước, nhiều thế hệ trước cũng truyền lại một câu rất là chi lý. À, có nghĩa là bên cạnh những cái... những cái điều cao siêu, những cái điều lý tưởng rất là tuyệt vời thì chúng ta vẫn phải đối diện với những cái rất là bình dị, rất là con người ở trong cái quá trình tu học của mình. Và vì thế nó ảnh hưởng rất nhiều đến cái thành quả tu học của chúng ta. Và nếu chúng ta phải biết cách làm sao để giúp nó và nâng cấp nó mỗi ngày qua mỗi thế hệ thì nó mới có cái lợi lạc nhiều nhất được. Với trí thức của loài người bây giờ thì chúng ta thấy rõ rằng là thức ăn nó có ảnh hưởng đến không chỉ thân và tâm của chúng ta. Nó còn là cái sự an toàn của chúng ta nữa. Nó không phải chỉ là cái thưởng thức hay theo đuổi mà nó còn là một cái yêu cầu của cuộc sống. Như thế nào mới là tốt? Nó còn tùy cái nhận thức nhưng đồng thời nó dần dần cũng có đạt đến cái nhận thức chung rằng điều đó rất quan trọng. Ngày xưa khi mà chúng ta chưa có hiểu biết nhiều về thức ăn, các loại thức ăn nó ảnh hưởng đến cơ thể như thế nào, đến tâm thức như thế nào, đến cộng đồng, đến sống như thế nào thì cái sự chọn lựa và nhận thức của thức ăn, nó cũng khác. Còn bây giờ nó được cung cấp nhiều hơn và đồng thời cũng vì thế nó sinh ra nhiều nhận thức mới và cũng khá là khác biệt. Bởi vậy khi Đại chúng đề nghị Phụ nói về 4 loại thức ăn Thưa Phụ, phải đề nghị Đại chúng là nên đi tìm những bài giảng của Sông về 4 loại thức ăn. Ngoại hướng dẫn ở mức tuyệt vời nhất, nó dựa trên tuổi đác và giáo lý của cửa sự thực tập Nhưng ở đây, các thầy cũng đề nghị chia sẻ ở mức độ gần sát với cuộc sống của chúng ta nhiều hơn Để chúng ta có cái gìn gần gũi và có can đảm tham dự vào đời sống của chúng ta Khi mà một người tham dự vào trong chúng thu học theo truyền thống là Mai thì gần như tất cả đều được sắp xếp vào trong đội luân phiên Ngoan. Với họ thì cũng thế hết. À, với cái trách nhiệm đó, cái vị trí để phục vụ đại chúng đó thì chúng ta sẽ gần như là phải tiếp xúc với phải chuẩn bị mỗi ngày bởi vì đó là cái công việc dễ dàng nhất
# --------------------------------------------------------------------------------

# %%
# Examine specific parts of the result
print("\nExamining detailed result:")
print(f"Language: {assemblyai_result['language']}")
print(f"Audio duration: {assemblyai_result['audio_duration_ms']} milliseconds")
print(f"Word count: {len(assemblyai_result['words'])}")
print(f"Utterance count: {len(assemblyai_result['utterances'])}")

# Look at the first few utterances if available
if assemblyai_result['utterances']:
    print("\nSample utterances:")
    for i, utterance in enumerate(assemblyai_result['utterances'][:3]):
        print(f"Speaker {utterance['speaker']}: {utterance['text'][:100]}...")
        if i >= 2:
            break
# Out:
# Examining detailed result:
# Language: auto
# Audio duration: 320 milliseconds
# Word count: 538
# Utterance count: 0

# %%
def replace_html_header(html_string: str) -> str:
    """
    Replaces the entire <head>...</head> section of an HTML string
    with a new header containing custom CSS for diff display.

    Args:
        html_string (str): The original HTML string.

    Returns:
        str: The modified HTML string with the replaced <head> section.
    """
    new_head = """
<head>
    <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
    <title></title>
    <style type="text/css">
        table.diff { font-family: Courier; border: medium; }
        .diff_header { background-color: #e0e0e0; }
        td.diff_header { text-align: right; }
        .diff_next { background-color: #c0c0c0; }
        .diff_add { background-color: lightgreen; color: black; }
        .diff_chg { background-color: lightyellow; color: black; }
        .diff_sub { background-color: lightcoral; color: black; }
    </style>
</head>
"""

    # Replace only the <head>...</head> section using non-greedy matching
    return re.sub(r"<head>.*?</head>", new_head, html_string, flags=re.DOTALL | re.IGNORECASE)

# %%
def compare_transcripts_high_contrast(whisper_result, assemblyai_result):
    # Clean transcripts
    whisper_text = re.sub(r'[^\w\s]', '', whisper_result['text']).lower()
    assemblyai_text = re.sub(r'[^\w\s]', '', assemblyai_result['text']).lower()
    
    # Split into words
    whisper_words = whisper_text.split()
    assemblyai_words = assemblyai_text.split()
    
    # Generate diff with custom colors
    d = difflib.HtmlDiff()
    
    # Get the standard diff table
    html_diff = d.make_file(whisper_words, assemblyai_words, "Whisper", "AssemblyAI")
    
    html_diff = replace_html_header(html_diff)

    # Calculate match statistics
    matcher = difflib.SequenceMatcher(None, whisper_words, assemblyai_words)
    matching = sum(b.size for b in matcher.get_matching_blocks())
    
    print(f"Whisper words: {len(whisper_words)}")
    print(f"AssemblyAI words: {len(assemblyai_words)}")
    print(f"Matching words: {matching}")
    print(f"Match percentage: {matching/len(whisper_words)*100:.2f}% (of Whisper)")
    print(f"Match percentage: {matching/len(assemblyai_words)*100:.2f}% (of AssemblyAI)")
    
    display(HTML(html_diff))
    return html_diff

# Run the comparison
html_result = compare_transcripts_high_contrast(whisper_result, assemblyai_result)

# %%
def get_word_duration(row, time_system='assemblyai'):
    """
    Calculate the duration of a word in milliseconds.
    
    Args:
        row: DataFrame row containing start and end times
        time_system: Which time system to use ('assemblyai' or 'whisper')
        
    Returns:
        Duration in milliseconds
    """
    prefix = f"{time_system}_"
    start_key = f"{prefix}start"
    end_key = f"{prefix}end"
    
    # Make sure we have valid times
    if start_key not in row or end_key not in row:
        return 0
        
    return row[end_key] - row[start_key]


def adjust_add_timestamps(df, add_row_index):
    """
    Adjust timestamps for an 'add' row using a simple algorithm:
    1. Adjust previous word end time to match its AssemblyAI duration
    2. Set add word start time to be the adjusted end time of previous word
    3. Set add word end time to be the start time of next word
    
    Args:
        df: DataFrame containing the comparison results
        add_row_index: Index of the 'add' row that needs timestamps
        
    Returns:
        Tuple of (start_time_ms, end_time_ms) in milliseconds
    """
    # Get the add row
    add_row = df.iloc[add_row_index]
    
    # Get rows before and after (if they exist)
    has_prev_row = add_row_index > 0
    has_next_row = add_row_index < len(df) - 1
    
    # Calculate new start time (based on previous word)
    if has_prev_row:
        prev_row_index = add_row_index - 1
        prev_row = df.iloc[prev_row_index]
        prev_duration = get_word_duration(prev_row, 'assemblyai')
        new_start = prev_row['whisper_start'] + prev_duration
        
        # Modify the previous word's end time in the DataFrame
        df.at[prev_row_index, 'whisper_end'] = new_start
    else:
        # First word in transcript - use next word start time minus duration
        next_row = df.iloc[add_row_index + 1]
        added_word_duration = get_word_duration(add_row, 'assemblyai')
        new_start = max(0, next_row['whisper_start'] - added_word_duration)
    
    # Calculate new end time (based on next word)
    if has_next_row:
        next_row = df.iloc[add_row_index + 1]
        new_end = next_row['whisper_start']
    else:
        # Last word in transcript - use start time plus duration
        added_word_duration = get_word_duration(add_row, 'assemblyai')
        new_end = new_start + added_word_duration
    
    return int(new_start), int(new_end)

# %%
def ms_to_min_sec(ms):
    """Convert milliseconds to 'MM:SS.sss' format."""
    if pd.isnull(ms):
        return ""
    
    # Convert to seconds
    total_seconds = ms / 1000
    
    # Calculate minutes and seconds
    minutes = int(total_seconds // 60)
    seconds = total_seconds % 60
    
    # Format as MM:SS.sss
    return f"{minutes:02d}:{seconds:.3f}"

def compare_transcripts_with_timings(whisper_result, assemblyai_result):
    # Create arrays of word data
    whisper_words = []
    for word_data in whisper_result['words']:
        word = re.sub(r'[^\w\s]', '', word_data['word']).lower()
        whisper_words.append({
            'word': word,
            'start_ms': word_data['start_ms'],
            'end_ms': word_data['end_ms']
        })
    
    assemblyai_words = []
    for word_data in assemblyai_result['words']:
        # Handle multi-word entries
        raw_word = word_data['word'].lower()
        words = re.sub(r'[^\w\s]', '', raw_word).split()
        
        if len(words) == 1:
            # Single word - use timing as is
            assemblyai_words.append({
                'word': words[0],
                'start_ms': word_data['start_ms'],
                'end_ms': word_data['end_ms']
            })
        else:
            # Multiple words - split the timing
            word_count = len(words)
            time_span = word_data['end_ms'] - word_data['start_ms']
            time_per_word = time_span / word_count
            
            for i, word in enumerate(words):
                start_time = word_data['start_ms'] + (i * time_per_word)
                end_time = start_time + time_per_word
                
                assemblyai_words.append({
                    'word': word,
                    'start_ms': int(start_time),
                    'end_ms': int(end_time)
                })
    
    # Extract word sequences for diff
    whisper_sequence = [word_data['word'] for word_data in whisper_words]
    assemblyai_sequence = [word_data['word'] for word_data in assemblyai_words]
    
    # Get diff information
    matcher = difflib.SequenceMatcher(None, whisper_sequence, assemblyai_sequence)
    
    # Build data for the table
    table_data = []
    
    for tag, i1, i2, j1, j2 in matcher.get_opcodes():
        if tag == 'equal':
            # Matching words - add with timing data
            for k in range(i2 - i1):
                w_idx = i1 + k
                a_idx = j1 + k
                
                w_word = whisper_words[w_idx]
                a_word = assemblyai_words[a_idx]
                
                offset = a_word['start_ms'] - w_word['start_ms']
                
                table_data.append({
                    'status': 'match',
                    'whisper_idx': w_idx,
                    'whisper_word': w_word['word'],
                    'whisper_start': w_word['start_ms'],
                    'whisper_end': w_word['end_ms'],
                    'assemblyai_idx': a_idx,
                    'assemblyai_word': a_word['word'],
                    'assemblyai_start': a_word['start_ms'],
                    'assemblyai_end': a_word['end_ms'],
                    'time_diff_ms': offset
                })
                
        elif tag == 'replace':
            # For replacements, create a single row showing both sides together
            whisper_words_list = []
            whisper_idx_list = []
            whisper_start_list = []
            whisper_end_list = []
            
            assemblyai_words_list = []
            assemblyai_idx_list = []
            assemblyai_start_list = []
            assemblyai_end_list = []
            
            # Gather Whisper words
            for i in range(i1, i2):
                w_word = whisper_words[i]
                whisper_words_list.append(w_word['word'])
                whisper_idx_list.append(i)
                whisper_start_list.append(w_word['start_ms'])
                whisper_end_list.append(w_word['end_ms'])
            
            # Gather AssemblyAI words
            for j in range(j1, j2):
                a_word = assemblyai_words[j]
                assemblyai_words_list.append(a_word['word'])
                assemblyai_idx_list.append(j)
                assemblyai_start_list.append(a_word['start_ms'])
                assemblyai_end_list.append(a_word['end_ms'])
            
            # Calculate time difference if possible
            time_diff = None
            if whisper_start_list and assemblyai_start_list:
                time_diff = assemblyai_start_list[0] - whisper_start_list[0]
            
            # Add a single 'change' row
            table_data.append({
                'status': 'change',
                'whisper_idx': whisper_idx_list[0] if whisper_idx_list else None,
                'whisper_word': " ".join(whisper_words_list),
                'whisper_start': whisper_start_list[0] if whisper_start_list else None,
                'whisper_end': whisper_end_list[-1] if whisper_end_list else None,
                'assemblyai_idx': assemblyai_idx_list[0] if assemblyai_idx_list else None,
                'assemblyai_word': " ".join(assemblyai_words_list),
                'assemblyai_start': assemblyai_start_list[0] if assemblyai_start_list else None,
                'assemblyai_end': assemblyai_end_list[-1] if assemblyai_end_list else None,
                'time_diff_ms': time_diff
            })
                
        elif tag == 'delete':
            # Words only in whisper - consolidate into one row if multiple consecutive words
            whisper_words_list = []
            whisper_idx_first = None
            whisper_start_first = None
            whisper_end_last = None
            
            for i in range(i1, i2):
                w_word = whisper_words[i]
                if whisper_idx_first is None:
                    whisper_idx_first = i
                    whisper_start_first = w_word['start_ms']
                whisper_words_list.append(w_word['word'])
                whisper_end_last = w_word['end_ms']
            
            table_data.append({
                'status': 'delete',
                'whisper_idx': whisper_idx_first,
                'whisper_word': " ".join(whisper_words_list),
                'whisper_start': whisper_start_first,
                'whisper_end': whisper_end_last,
                'assemblyai_idx': None,
                'assemblyai_word': '',
                'assemblyai_start': None,
                'assemblyai_end': None,
                'time_diff_ms': None
            })
                
        elif tag == 'insert':
            # Words only in assemblyai - consolidate into one row if multiple consecutive words
            assemblyai_words_list = []
            assemblyai_idx_first = None
            assemblyai_start_first = None
            assemblyai_end_last = None
            
            for j in range(j1, j2):
                a_word = assemblyai_words[j]
                if assemblyai_idx_first is None:
                    assemblyai_idx_first = j
                    assemblyai_start_first = a_word['start_ms']
                assemblyai_words_list.append(a_word['word'])
                assemblyai_end_last = a_word['end_ms']
            
            table_data.append({
                'status': 'add',
                'whisper_idx': None,
                'whisper_word': '',
                'whisper_start': None,
                'whisper_end': None,
                'assemblyai_idx': assemblyai_idx_first,
                'assemblyai_word': " ".join(assemblyai_words_list),
                'assemblyai_start': assemblyai_start_first,
                'assemblyai_end': assemblyai_end_last,
                'time_diff_ms': None
            })
    
    # Create DataFrame from the table data
    df = pd.DataFrame(table_data)
    
    # Post-processing: Interpolate timestamps for 'add' rows
    for index, row in df.iterrows():
        if row['status'] == 'add':
            # Get interpolated timestamps
            start_ms, end_ms = adjust_add_timestamps(df, index)
            
            # Update the DataFrame with interpolated values
            df.at[index, 'whisper_start'] = start_ms
            df.at[index, 'whisper_end'] = end_ms
            
            # Calculate time difference
            if pd.notnull(row['assemblyai_start']):
                time_diff_ms = start_ms - row['assemblyai_start']
                df.at[index, 'time_diff_ms'] = time_diff_ms
                
    # Calculate match statistics
    match_count = len(df[df['status'] == 'match'])
    whisper_count = len(whisper_sequence)
    assemblyai_count = len(assemblyai_sequence)
    
    print(f"Whisper words: {whisper_count}")
    print(f"AssemblyAI words: {assemblyai_count}")
    print(f"Matching words: {match_count}")
    print(f"Match percentage: {match_count/whisper_count*100:.2f}% (of Whisper)")
    print(f"Match percentage: {match_count/assemblyai_count*100:.2f}% (of AssemblyAI)")
    
    return df
    
def format_transcript_display(df):
    """
    Format the raw dataframe for display with appropriate time formats.
    
    Args:
        df: Raw dataframe from compare_transcripts_with_timings
        
    Returns:
        Formatted display dataframe
    """
    # Create a copy to avoid modifying the original
    display_df = df.copy()
    
    # Format timestamp columns to minutes:seconds.milliseconds format
    for col in ['whisper_start', 'whisper_end', 'assemblyai_start', 'assemblyai_end']:
        display_df[col] = df[col].apply(lambda x: ms_to_min_sec(x) if pd.notnull(x) else "")
    
    # Format index columns to integers
    for col in ['whisper_idx', 'assemblyai_idx']:
        display_df[col] = df[col].apply(lambda x: f"{int(x)}" if pd.notnull(x) else "")
    
    # Format time difference
    if 'time_diff_ms' in df.columns:
        display_df['time_diff'] = df['time_diff_ms'].apply(
            lambda x: f"{x/1000:.3f}s" if pd.notnull(x) else ""
        )
        # Remove the original column
        display_df = display_df.drop('time_diff_ms', axis=1)
    
    return display_df

def style_transcript_display(display_df):
    """
    Apply styling to the formatted display dataframe.
    
    Args:
        display_df: Formatted dataframe from format_transcript_display
        
    Returns:
        Styled dataframe ready for display
    """
    def style_row(row):
        # Using a color-blind friendly palette
        status_colors = {
            'match': 'background-color: #FFFFFF',  # White
            'add': 'background-color: #CCEBC5; color: black',  # Light green
            'delete': 'background-color: #FBB4AE; color: black',  # Light red/salmon
            'change': 'background-color: #B3CDE3; color: black',  # Light blue
        }
        
        color_style = status_colors.get(row['status'], 'background-color: white')
        return [color_style] * len(row)
    
    return display_df.style.apply(style_row, axis=1)

# Usage example:
df = compare_transcripts_with_timings(whisper_result, assemblyai_result)
display_df = format_transcript_display(df)
styled_df = style_transcript_display(display_df)

styled_df
# Out:
# Whisper words: 697
# AssemblyAI words: 691
# Matching words: 632
# Match percentage: 90.67% (of Whisper)
# Match percentage: 91.46% (of AssemblyAI)
# <style type="text/css">
# #T_84ef5_row0_col0, #T_84ef5_row0_col1, #T_84ef5_row0_col2, #T_84ef5_row0_col3, #T_84ef5_row0_col4, #T_84ef5_row0_col5, #T_84ef5_row0_col6, #T_84ef5_row0_col7, #T_84ef5_row0_col8, #T_84ef5_row0_col9, #T_84ef5_row79_col0, #T_84ef5_row79_col1, #T_84ef5_row79_col2, #T_84ef5_row79_col3, #T_84ef5_row79_col4, #T_84ef5_row79_col5, #T_84ef5_row79_col6, #T_84ef5_row79_col7, #T_84ef5_row79_col8, #T_84ef5_row79_col9, #T_84ef5_row129_col0, #T_84ef5_row129_col1, #T_84ef5_row129_col2, #T_84ef5_row129_col3, #T_84ef5_row129_col4, #T_84ef5_row129_col5, #T_84ef5_row129_col6, #T_84ef5_row129_col7, #T_84ef5_row129_col8, #T_84ef5_row129_col9, #T_84ef5_row170_col0, #T_84ef5_row170_col1, #T_84ef5_row170_col2, #T_84ef5_row170_col3, #T_84ef5_row170_col4, #T_84ef5_row170_col5, #T_84ef5_row170_col6, #T_84ef5_row170_col7, #T_84ef5_row170_col8, #T_84ef5_row170_col9, #T_84ef5_row239_col0, #T_84ef5_row239_col1, #T_84ef5_row239_col2, #T_84ef5_row239_col3, #T_84ef5_row239_col4, #T_84ef5_row239_col5, #T_84ef5_row239_col6, #T_84ef5_row239_col7, #T_84ef5_row239_col8, #T_84ef5_row239_col9, #T_84ef5_row246_col0, #T_84ef5_row246_col1, #T_84ef5_row246_col2, #T_84ef5_row246_col3, #T_84ef5_row246_col4, #T_84ef5_row246_col5, #T_84ef5_row246_col6, #T_84ef5_row246_col7, #T_84ef5_row246_col8, #T_84ef5_row246_col9, #T_84ef5_row272_col0, #T_84ef5_row272_col1, #T_84ef5_row272_col2, #T_84ef5_row272_col3, #T_84ef5_row272_col4, #T_84ef5_row272_col5, #T_84ef5_row272_col6, #T_84ef5_row272_col7, #T_84ef5_row272_col8, #T_84ef5_row272_col9, #T_84ef5_row274_col0, #T_84ef5_row274_col1, #T_84ef5_row274_col2, #T_84ef5_row274_col3, #T_84ef5_row274_col4, #T_84ef5_row274_col5, #T_84ef5_row274_col6, #T_84ef5_row274_col7, #T_84ef5_row274_col8, #T_84ef5_row274_col9, #T_84ef5_row290_col0, #T_84ef5_row290_col1, #T_84ef5_row290_col2, #T_84ef5_row290_col3, #T_84ef5_row290_col4, #T_84ef5_row290_col5, #T_84ef5_row290_col6, #T_84ef5_row290_col7, #T_84ef5_row290_col8, #T_84ef5_row290_col9, #T_84ef5_row603_col0, #T_84ef5_row603_col1, #T_84ef5_row603_col2, #T_84ef5_row603_col3, #T_84ef5_row603_col4, #T_84ef5_row603_col5, #T_84ef5_row603_col6, #T_84ef5_row603_col7, #T_84ef5_row603_col8, #T_84ef5_row603_col9 {
#   background-color: #CCEBC5;
#   color: black;
# }
# #T_84ef5_row1_col0, #T_84ef5_row1_col1, #T_84ef5_row1_col2, #T_84ef5_row1_col3, #T_84ef5_row1_col4, #T_84ef5_row1_col5, #T_84ef5_row1_col6, #T_84ef5_row1_col7, #T_84ef5_row1_col8, #T_84ef5_row1_col9, #T_84ef5_row2_col0, #T_84ef5_row2_col1, #T_84ef5_row2_col2, #T_84ef5_row2_col3, #T_84ef5_row2_col4, #T_84ef5_row2_col5, #T_84ef5_row2_col6, #T_84ef5_row2_col7, #T_84ef5_row2_col8, #T_84ef5_row2_col9, #T_84ef5_row3_col0, #T_84ef5_row3_col1, #T_84ef5_row3_col2, #T_84ef5_row3_col3, #T_84ef5_row3_col4, #T_84ef5_row3_col5, #T_84ef5_row3_col6, #T_84ef5_row3_col7, #T_84ef5_row3_col8, #T_84ef5_row3_col9, #T_84ef5_row4_col0, #T_84ef5_row4_col1, #T_84ef5_row4_col2, #T_84ef5_row4_col3, #T_84ef5_row4_col4, #T_84ef5_row4_col5, #T_84ef5_row4_col6, #T_84ef5_row4_col7, #T_84ef5_row4_col8, #T_84ef5_row4_col9, #T_84ef5_row5_col0, #T_84ef5_row5_col1, #T_84ef5_row5_col2, #T_84ef5_row5_col3, #T_84ef5_row5_col4, #T_84ef5_row5_col5, #T_84ef5_row5_col6, #T_84ef5_row5_col7, #T_84ef5_row5_col8, #T_84ef5_row5_col9, #T_84ef5_row6_col0, #T_84ef5_row6_col1, #T_84ef5_row6_col2, #T_84ef5_row6_col3, #T_84ef5_row6_col4, #T_84ef5_row6_col5, #T_84ef5_row6_col6, #T_84ef5_row6_col7, #T_84ef5_row6_col8, #T_84ef5_row6_col9, #T_84ef5_row7_col0, #T_84ef5_row7_col1, #T_84ef5_row7_col2, #T_84ef5_row7_col3, #T_84ef5_row7_col4, #T_84ef5_row7_col5, #T_84ef5_row7_col6, #T_84ef5_row7_col7, #T_84ef5_row7_col8, #T_84ef5_row7_col9, #T_84ef5_row8_col0, #T_84ef5_row8_col1, #T_84ef5_row8_col2, #T_84ef5_row8_col3, #T_84ef5_row8_col4, #T_84ef5_row8_col5, #T_84ef5_row8_col6, #T_84ef5_row8_col7, #T_84ef5_row8_col8, #T_84ef5_row8_col9, #T_84ef5_row9_col0, #T_84ef5_row9_col1, #T_84ef5_row9_col2, #T_84ef5_row9_col3, #T_84ef5_row9_col4, #T_84ef5_row9_col5, #T_84ef5_row9_col6, #T_84ef5_row9_col7, #T_84ef5_row9_col8, #T_84ef5_row9_col9, #T_84ef5_row10_col0, #T_84ef5_row10_col1, #T_84ef5_row10_col2, #T_84ef5_row10_col3, #T_84ef5_row10_col4, #T_84ef5_row10_col5, #T_84ef5_row10_col6, #T_84ef5_row10_col7, #T_84ef5_row10_col8, #T_84ef5_row10_col9, #T_84ef5_row11_col0, #T_84ef5_row11_col1, #T_84ef5_row11_col2, #T_84ef5_row11_col3, #T_84ef5_row11_col4, #T_84ef5_row11_col5, #T_84ef5_row11_col6, #T_84ef5_row11_col7, #T_84ef5_row11_col8, #T_84ef5_row11_col9, #T_84ef5_row12_col0, #T_84ef5_row12_col1, #T_84ef5_row12_col2, #T_84ef5_row12_col3, #T_84ef5_row12_col4, #T_84ef5_row12_col5, #T_84ef5_row12_col6, #T_84ef5_row12_col7, #T_84ef5_row12_col8, #T_84ef5_row12_col9, #T_84ef5_row13_col0, #T_84ef5_row13_col1, #T_84ef5_row13_col2, #T_84ef5_row13_col3, #T_84ef5_row13_col4, #T_84ef5_row13_col5, #T_84ef5_row13_col6, #T_84ef5_row13_col7, #T_84ef5_row13_col8, #T_84ef5_row13_col9, #T_84ef5_row14_col0, #T_84ef5_row14_col1, #T_84ef5_row14_col2, #T_84ef5_row14_col3, #T_84ef5_row14_col4, #T_84ef5_row14_col5, #T_84ef5_row14_col6, #T_84ef5_row14_col7, #T_84ef5_row14_col8, #T_84ef5_row14_col9, #T_84ef5_row15_col0, #T_84ef5_row15_col1, #T_84ef5_row15_col2, #T_84ef5_row15_col3, #T_84ef5_row15_col4, #T_84ef5_row15_col5, #T_84ef5_row15_col6, #T_84ef5_row15_col7, #T_84ef5_row15_col8, #T_84ef5_row15_col9, #T_84ef5_row16_col0, #T_84ef5_row16_col1, #T_84ef5_row16_col2, #T_84ef5_row16_col3, #T_84ef5_row16_col4, #T_84ef5_row16_col5, #T_84ef5_row16_col6, #T_84ef5_row16_col7, #T_84ef5_row16_col8, #T_84ef5_row16_col9, #T_84ef5_row17_col0, #T_84ef5_row17_col1, #T_84ef5_row17_col2, #T_84ef5_row17_col3, #T_84ef5_row17_col4, #T_84ef5_row17_col5, #T_84ef5_row17_col6, #T_84ef5_row17_col7, #T_84ef5_row17_col8, #T_84ef5_row17_col9, #T_84ef5_row18_col0, #T_84ef5_row18_col1, #T_84ef5_row18_col2, #T_84ef5_row18_col3, #T_84ef5_row18_col4, #T_84ef5_row18_col5, #T_84ef5_row18_col6, #T_84ef5_row18_col7, #T_84ef5_row18_col8, #T_84ef5_row18_col9, #T_84ef5_row19_col0, #T_84ef5_row19_col1, #T_84ef5_row19_col2, #T_84ef5_row19_col3, #T_84ef5_row19_col4, #T_84ef5_row19_col5, #T_84ef5_row19_col6, #T_84ef5_row19_col7, #T_84ef5_row19_col8, #T_84ef5_row19_col9, #T_84ef5_row20_col0, #T_84ef5_row20_col1, #T_84ef5_row20_col2, #T_84ef5_row20_col3, #T_84ef5_row20_c ...

# %%
transcript = assemblyai_result['raw_result']

# %%
srt_out = transcript.export_subtitles_srt(chars_per_caption=32)

# %%
print(srt_out)
# Out:
# 1
# 00:00:00,008 --> 00:00:46,315
# Chuông Chuông Chuông
#
# 2
# 00:01:33,766 --> 00:01:34,306
# Tính thưa Đại chúng, vừa rồi
#
# 3
# 00:01:34,326 --> 00:01:34,826
# Tù Viện có mấy ngày trong
#
# 4
# 00:01:34,846 --> 00:01:35,446
# khóa tu nấu ăn online. Mục đích
#
# 5
# 00:01:35,466 --> 00:01:36,067
# là để giới thiệu cho cộng đồng
#
# 6
# 00:01:36,087 --> 00:01:36,727
# những người ăn chay những món ăn
#
# 7
# 00:01:36,747 --> 00:01:37,307
# được nấu ở trong Tù Viện. Thế
#
# 8
# 00:01:37,327 --> 00:01:37,927
# nên Đại chúng đề nghị phẫu hội
#
# 9
# 00:02:02,386 --> 00:02:03,006
# chia sẻ ngày hôm nay về thức ăn
#
# 10
# 00:02:03,026 --> 00:02:03,607
# và đi chợ. Đó cũng có một chút
#
# 11
# 00:02:03,627 --> 00:02:04,227
# đặc biệt là bởi vì chúng ta là
#
# 12
# 00:02:04,247 --> 00:02:04,807
# một cộng đồng ăn chay. Chay ở
#
# 13
# 00:02:04,827 --> 00:02:05,427
# đây có bao gồm veggie và bacon.
#
# 14
# 00:02:05,447 --> 00:02:05,988
# Và mọi người cũng rất nhiều
#
# 15
# 00:02:06,008 --> 00:02:06,568
# người có hứng thú xem là các
#
# 16
# 00:02:06,588 --> 00:02:07,128
# thầy, các sư cô họ ăn cái gì
#
# 17
# 00:02:07,148 --> 00:02:07,649
# hằng ngày ở trong tú biển.
#
# 18
# 00:02:33,807 --> 00:02:34,448
# và cũng cả họ đi chợ như thế nào
#
# 19
# 00:02:34,468 --> 00:02:35,008
# nữa. Thì... có lẽ là bởi vì các
#
# 20
# 00:02:35,028 --> 00:02:35,548
# hội có... có thâm niên đi chợ
#
# 21
# 00:02:35,568 --> 00:02:36,069
# lâu nhất so với đại chúng.
#
# 22
# 00:02:36,089 --> 00:02:36,649
# Cho nên xin cảm ơn đại chúng
#
# 23
# 00:02:36,669 --> 00:02:37,310
# cái nghiệm kiên tưởng để chia sẻ
#
# 24
# 00:02:37,330 --> 00:02:37,890
# cho cái lĩnh vực này. Nó cũng
#
# 25
# 00:02:37,910 --> 00:02:38,151
# thú vị và nó...
#
# 26
# 00:03:03,963 --> 00:03:04,523
# cũng là một cái gì đó rất là
#
# 27
# 00:03:04,543 --> 00:03:05,143
# thiết thực với đời sống tu học.
#
# 28
# 00:03:05,163 --> 00:03:05,724
# Mặc dù khi vào chùa, người ta
#
# 29
# 00:03:05,744 --> 00:03:06,344
# hướng về những sự thực tập cao
#
# 30
# 00:03:06,364 --> 00:03:06,884
# nhất, những sự hướng dẫn có
#
# 31
# 00:03:06,904 --> 00:03:07,504
# giá trị nhất. Căn bản phải được
#
# 32
# 00:03:07,524 --> 00:03:08,005
# dựa trên tuổi giá và của
#
# 33
# 00:03:08,025 --> 00:03:08,565
# kinh nghiệm. Nhưng đồng thời,
#
# 34
# 00:03:08,585 --> 00:03:09,125
# những thế hệ tu trước, nhiều
#
# 35
# 00:03:09,145 --> 00:03:09,785
# thế hệ trước cũng truyền lại một
#
# 36
# 00:03:09,805 --> 00:03:10,146
# câu rất là chi lý.
#
# 37
# 00:03:37,612 --> 00:03:38,172
# À! Có nghĩa là bên cạnh những
#
# 38
# 00:03:38,192 --> 00:03:38,732
# cái... những cái điều cao siêu,
#
# 39
# 00:03:38,752 --> 00:03:39,353
# những cái điều lý tưởng rất là
#
# 40
# 00:03:39,373 --> 00:03:39,993
# tuyệt vời thì chúng ta vẫn phải
#
# 41
# 00:03:40,013 --> 00:03:40,593
# đối diện với những cái rất là
#
# 42
# 00:03:40,613 --> 00:03:41,133
# bình dị, rất là con người ở
#
# 43
# 00:03:41,153 --> 00:03:41,754
# trong cái quá trình tu học của
#
# 44
# 00:03:41,774 --> 00:03:42,394
# mình. Và vì thế nó ảnh hưởng rất
#
# 45
# 00:03:42,414 --> 00:03:43,014
# nhiều đến cái thành quả tu học
#
# 46
# 00:03:43,034 --> 00:03:43,594
# của chúng ta. Và nếu chúng ta
#
# 47
# 00:03:43,614 --> 00:03:44,215
# phải biết cách làm sao để giúp
#
# 48
# 00:03:44,235 --> 00:03:44,835
# nó và nâng cấp nó mỗi ngày qua
#
# 49
# 00:03:44,855 --> 00:04:08,468
# mỗi thế hệ thì
#
# 50
# 00:04:08,488 --> 00:04:09,129
# nó mới có cái lợi lạc nhiều nhất
#
# 51
# 00:04:09,149 --> 00:04:09,569
# được. Với trí thức của
#
# 52
# 00:04:09,589 --> 00:04:10,210
# loài người bây giờ thì chúng ta
#
# 53
# 00:04:10,230 --> 00:04:10,810
# thấy rõ rằng là thức ăn nó có
#
# 54
# 00:04:10,830 --> 00:04:11,451
# ảnh hưởng đến không chỉ thân và
#
# 55
# 00:04:11,471 --> 00:04:12,071
# tâm của chúng ta. Nó còn là cái
#
# 56
# 00:04:12,091 --> 00:04:12,692
# sự an toàn của chúng ta nữa. Nó
#
# 57
# 00:04:12,712 --> 00:04:13,132
# không phải chỉ là cái
#
# 58
# 00:04:13,152 --> 00:04:13,773
# thưởng thức hay theo đuổi mà nó
#
# 59
# 00:04:13,793 --> 00:04:14,313
# còn là một cái yêu cầu của
#
# 60
# 00:04:14,333 --> 00:04:14,894
# cuộc sống. Như thế nào mới là
#
# 61
# 00:04:14,914 --> 00:04:15,474
# tốt? Nó còn tùy cái nhận thức
#
# 62
# 00:04:36,607 --> 00:04:37,227
# nhưng đồng thời nó dần dần cũng
#
# 63
# 00:04:37,247 --> 00:04:37,848
# có đạt đến cái nhận thức chung
#
# 64
# 00:04:37,868 --> 00:04:38,408
# rằng điều đó rất quan trọng.
#
# 65
# 00:04:38,428 --> 00:04:39,069
# Ngày xưa khi mà chúng ta chưa có
#
# 66
# 00:04:39,089 --> 00:04:39,689
# hiểu biết nhiều về thức ăn, các
#
# 67
# 00:04:39,709 --> 00:04:40,290
# loại thức ăn nó ảnh hưởng đến
#
# 68
# 00:04:40,310 --> 00:04:40,930
# cơ thể như thế nào, đến tâm thức
#
# 69
# 00:04:40,950 --> 00:04:41,530
# như thế nào, đến cộng đồng, đến
#
# 70
# 00:04:41,550 --> 00:04:42,091
# sống như thế nào thì cái sự
#
# 71
# 00:04:42,111 --> 00:05:01,812
# chọn lựa và nhận thức
#
# 72
# 00:05:01,832 --> 00:05:02,393
# của thức ăn nó cũng khác. Còn
#
# 73
# 00:05:02,413 --> 00:05:03,033
# bây giờ nó được tương cấp nhiều
#
# 74
# 00:05:03,053 --> 00:05:03,674
# hơn và đồng thời cũng vì thế nó
#
# 75
# 00:05:03,694 --> 00:05:04,294
# sinh ra nhiều nhận thức mới và
#
# 76
# 00:05:04,314 --> 00:05:04,894
# cũng khá là khác biệt. Bởi vậy
#
# 77
# 00:05:04,914 --> 00:05:05,555
# khi đại chúng đề nghị phụ nói về
#
# 78
# 00:05:05,575 --> 00:05:06,175
# bốn loại thức ăn Thưa phụ, phải
#
# 79
# 00:05:06,195 --> 00:05:06,816
# đề nghị đại chúng là nên đi tìm
#
# 80
# 00:05:06,836 --> 00:05:07,456
# những bài giảng của Sông về bốn
#
# 81
# 00:05:07,476 --> 00:05:07,716
# loại thức ăn.
#
# 82
# 00:05:32,075 --> 00:05:32,695
# Ngoại hướng dẫn ở mức tuyệt vời
#
# 83
# 00:05:32,715 --> 00:05:33,276
# nhất, nó dựa trên tuổi đác và
#
# 84
# 00:05:33,296 --> 00:05:33,836
# giáo lý của cửa sự thực tập
#
# 85
# 00:05:33,856 --> 00:05:34,356
# Nhưng ở đây, các thầy cũng
#
# 86
# 00:05:34,376 --> 00:05:35,016
# đề nghị chia sẻ ở mức độ gần sát
#
# 87
# 00:05:35,036 --> 00:05:35,677
# với cuộc sống của chúng ta nhiều
#
# 88
# 00:05:35,697 --> 00:05:36,237
# hơn để chúng ta có cái nhìn
#
# 89
# 00:05:36,257 --> 00:05:36,837
# gần gũi và có can đảm tham dự
#
# 90
# 00:05:36,857 --> 00:06:05,176
# vào Khi
#
# 91
# 00:06:05,196 --> 00:06:05,796
# mà một người tham dự vào trong
#
# 92
# 00:06:05,816 --> 00:06:06,436
# chúng thu học theo truyền thống
#
# 93
# 00:06:06,456 --> 00:06:07,036
# là Mai thì gần như tất cả đều
#
# 94
# 00:06:07,056 --> 00:06:07,577
# được sắp xếp vào trong đội
#
# 95
# 00:06:07,597 --> 00:06:08,137
# Luân phiên Ngoan. Với họ thì
#
# 96
# 00:06:08,157 --> 00:06:08,657
# cũng thế hết. À! Và với cái
#
# 97
# 00:06:08,677 --> 00:06:09,237
# trách nhiệm đó, cái vị trí để
#
# 98
# 00:06:09,257 --> 00:06:09,737
# phục vụ đại chúng đó thì
#
# 99
# 00:06:09,757 --> 00:06:10,297
# chúng ta sẽ gần như là phải
#
# 100
# 00:06:10,317 --> 00:06:40,448
# tiếp xúc với thức ăn phải
#
# 101
# 00:06:40,468 --> 00:06:41,068
# chuẩn bị mỗi ngày bởi vì đó là
#
# 102
# 00:06:41,088 --> 00:06:41,668
# cái công việc dễ dàng nhất để
#
# 103
# 00:06:41,688 --> 00:06:42,308
# cảm nhận cái đời sống trôi ngày
#
# 104
# 00:06:42,328 --> 00:06:42,928
# như thế nào bên cạnh những cái
#
# 105
# 00:06:42,948 --> 00:06:43,569
# lý tưởng cao đẹp bên cạnh những
#
# 106
# 00:06:43,589 --> 00:06:44,069
# cái thủy chính những cái
#
# 107
# 00:06:44,089 --> 00:06:44,649
# vá trạng hàng ngày những cái
#
# 108
# 00:06:44,669 --> 00:06:45,129
# hành xử những cái xử lý
#
# 109
# 00:06:45,149 --> 00:06:45,669
# như thế nào trong cùng một
#
# 110
# 00:06:45,689 --> 00:07:09,382
# môi trường làm việc và tu học nó
#
# 111
# 00:07:09,402 --> 00:07:10,002
# nuôi lớn chúng ta rất là nhiều.
#
# 112
# 00:07:10,022 --> 00:07:10,583
# Với một bàn nội trợ, một mình
#
# 113
# 00:07:10,603 --> 00:07:11,183
# ta quản cái bếp được, nó không
#
# 114
# 00:07:11,203 --> 00:07:11,784
# thành vấn đề. Ông chồng mà vào
#
# 115
# 00:07:11,804 --> 00:07:12,404
# mà quậy trong bếp là có thể ta
#
# 116
# 00:07:12,424 --> 00:07:12,924
# gạt ra được. Nhưng với bạn
#
# 117
# 00:07:12,944 --> 00:07:13,505
# nồng tu thì ta không làm thế
#
# 118
# 00:07:13,525 --> 00:07:13,965
# được. Ta phải chấp nhận
#
# 119
# 00:07:13,985 --> 00:07:14,506
# quan điểm của người đó khi
#
# 120
# 00:07:14,526 --> 00:07:15,126
# làm việc trong bếp nữa. Ta phải
#
# 121
# 00:07:15,146 --> 00:07:43,149
# tự điều chỉnh nó
#
# 122
# 00:07:43,169 --> 00:07:43,790
# là một môi trường chung cho nên
#
# 123
# 00:07:43,810 --> 00:07:44,390
# ngay từ đầu chúng ta phải học
#
# 124
# 00:07:44,410 --> 00:07:45,011
# cái kỹ năng để rung hòa tất cả
#
# 125
# 00:07:45,031 --> 00:07:45,631
# những cái thứ đó nấu ăn là một
#
# 126
# 00:07:45,651 --> 00:07:46,252
# cái công việc rất là thú vị nó
#
# 127
# 00:07:46,272 --> 00:07:46,912
# nuôi dưỡng chúng ta rất là nhiều
#
# 128
# 00:07:46,932 --> 00:07:47,513
# nhiều năm trước khi mà Phượng
#
# 129
# 00:07:47,533 --> 00:08:13,983
# đọc về những cái bài
#
# 130
# 00:08:14,003 --> 00:08:14,503
# báo của những hoa học gia
#
# 131
# 00:08:14,523 --> 00:08:15,044
# nghiên cứu về một đời sống
#
# 132
# 00:08:15,064 --> 00:08:15,604
# như thế nào là lành mạnh và
#
# 133
# 00:08:15,624 --> 00:08:16,164
# hướng thiện, đẹp. Trong đó có
#
# 134
# 00:08:16,184 --> 00:08:16,764
# những tiêu chuẩn thích dụ nhà
#
# 135
# 00:08:16,784 --> 00:08:17,325
# phải ở gần tiệm bán thức ăn
#
# 136
# 00:08:17,345 --> 00:08:17,945
# lành mạnh. Nhà ở gần trường học
#
# 137
# 00:08:17,965 --> 00:08:18,545
# để đến mức bố mẹ có thể đi bộ
#
# 138
# 00:08:18,565 --> 00:08:19,026
# với con đến trường được.
#
# 139
# 00:08:45,817 --> 00:08:46,297
# xa những nơi nó không có
#
# 140
# 00:08:46,317 --> 00:08:46,777
# lành mạnh thì đó là một
#
# 141
# 00:08:46,797 --> 00:08:47,297
# tiêu chuẩn tốt đẹp có thể
#
# 142
# 00:08:47,318 --> 00:08:47,878
# tập thể dục, có thể nghỉ ngơi
#
# 143
# 00:08:47,898 --> 00:08:48,518
# trong tỉnh lạc về sau, nhiều năm
#
# 144
# 00:08:48,538 --> 00:08:49,178
# sau tăng thêm một tiêu chuẩn nữa
#
# 145
# 00:08:49,198 --> 00:08:49,818
# là nếu như có thể tự nấu ăn cho
#
# 146
# 00:08:49,838 --> 00:08:50,419
# chính mình thì đó cũng là một
#
# 147
# 00:08:50,439 --> 00:08:51,019
# điều kiện của đời sống luxury
#
# 148
# 00:08:51,039 --> 00:08:51,639
# Vậy thì thấy khá là ngạc nhiên
#
# 149
# 00:09:15,820 --> 00:09:16,420
# Câu chuẩn đó mình được áp dụng
#
# 150
# 00:09:16,440 --> 00:09:17,021
# từ rất lâu rồi Thường thì sau
#
# 151
# 00:09:17,041 --> 00:09:17,571
# mỗi một mùa ăn cư kéo dài 3
#
# 152
# 00:09:17,581 --> 00:09:18,192
# tháng Thầy chúng sẽ có khoảng 1
#
# 153
# 00:09:18,202 --> 00:09:18,622
# đến 2 tuần mà cái vòng
#
# 154
# 00:09:18,642 --> 00:09:19,282
# luân phiên nó được cắt bỏ Và mỗi
#
# 155
# 00:09:19,302 --> 00:09:19,923
# người sẽ phải tự nấu ăn thức ăn
#
# 156
# 00:09:19,943 --> 00:09:20,463
# cho chính mình Tự ở bếp mà
#
# 157
# 00:09:20,483 --> 00:09:21,083
# nấu ăn Nấu cho chính mình hoặc
#
# 158
# 00:09:21,103 --> 00:09:21,524
# nấu cho một vài người,
#
# 159
# 00:09:21,544 --> 00:09:46,222
# tùy thích Và lúc
#
# 160
# 00:09:46,242 --> 00:09:46,842
# đó ở trong bếp nó sôi động hơn
#
# 161
# 00:09:46,862 --> 00:09:47,442
# hẳn. Nó có những cái khuôn mặt
#
# 162
# 00:09:47,462 --> 00:09:48,002
# rất là hứng thú. Bình thường
#
# 163
# 00:09:48,022 --> 00:09:48,603
# trong bếp chỉ vài, ba người. Nó
#
# 164
# 00:09:48,623 --> 00:09:49,243
# người. Nhưng mà khoảng thời gian
#
# 165
# 00:09:49,263 --> 00:09:49,863
# làm viên có khi tới 20 người hơn
#
# 166
# 00:09:49,883 --> 00:09:50,463
# ở trong bếp. Mỗi người nấu món
#
# 167
# 00:09:50,483 --> 00:09:51,043
# ăn của mình. Và mình quan sát
#
# 168
# 00:09:51,063 --> 00:09:51,623
# thấy có nhiều cái phong cách
#
# 169
# 00:09:51,643 --> 00:09:52,223
# nấu ăn khác nhau. Có những cái
#
# 170
# 00:09:52,243 --> 00:10:18,054
# quan sát thấy những
#
# 171
# 00:10:18,074 --> 00:10:18,695
# khách thức của người đó nó được
#
# 172
# 00:10:18,715 --> 00:10:19,215
# truyền lại từ mẹ, từ bố, từ
#
# 173
# 00:10:19,235 --> 00:10:19,776
# ông bà hay của những thế hệ
#
# 174
# 00:10:19,796 --> 00:10:20,376
# trước. Những khách thức mà khi
#
# 175
# 00:10:20,396 --> 00:10:20,937
# nấu ăn cho đông người không
#
# 176
# 00:10:20,957 --> 00:10:21,577
# thực hiện được, thế nhưng mà khi
#
# 177
# 00:10:21,597 --> 00:10:22,138
# nấu cho 1-2 người, họ hoàn toàn
#
# 178
# 00:10:22,158 --> 00:10:22,738
# có dư dàng thời gian hay loại
#
# 179
# 00:10:22,758 --> 00:10:23,359
# nguyên liệu để nấu được. Và khi
#
# 180
# 00:10:23,379 --> 00:10:23,959
# thưởng thức thấy chúng rất là
#
# 181
# 00:10:23,979 --> 00:10:24,160
# hạnh phúc.
#
# 182
# 00:10:47,519 --> 00:10:48,029
# Bởi vì khi mà nấu ăn cho 30
#
# 183
# 00:10:48,039 --> 00:10:48,540
# người hay 300 người, nó không
#
# 184
# 00:10:48,560 --> 00:10:48,960
# dễ dàng, kể cả khi có
#
# 185
# 00:10:48,980 --> 00:10:49,541
# nguyên liệu đầy đủ. Là bởi vì
#
# 186
# 00:10:49,561 --> 00:10:50,181
# cái khẩu vị của mỗi người nó có
#
# 187
# 00:10:50,201 --> 00:10:50,702
# khác nhau. Những món ăn mà,
#
# 188
# 00:10:50,722 --> 00:10:51,322
# những cái khẩu vị về món ăn mà
#
# 189
# 00:10:51,342 --> 00:10:51,943
# chúng ta yêu thích, phần lớn nó
#
# 190
# 00:10:51,963 --> 00:10:52,483
# sẽ đi theo với chúng ta cả
#
# 191
# 00:10:52,503 --> 00:10:53,063
# cuộc đời. Đối với ông thầy Tu
#
# 192
# 00:10:53,083 --> 00:10:53,664
# cũng vậy. Bất kể là Tu bao lâu,
#
# 193
# 00:10:53,684 --> 00:10:54,264
# cái đó nó cũng vẫn cứ đi theo
#
# 194
# 00:10:54,284 --> 00:10:54,485
# như thường.
#
# 195
# 00:11:20,965 --> 00:11:21,505
# Đối với một số truyền thống
#
# 196
# 00:11:21,525 --> 00:11:22,085
# thu học, họ nhận định rằng để
#
# 197
# 00:11:22,105 --> 00:11:22,705
# cho mình lũy vào, chạy theo cái
#
# 198
# 00:11:22,725 --> 00:11:23,325
# khẩu vị của thức ăn, nó cản trở
#
# 199
# 00:11:23,345 --> 00:11:23,826
# rất nhiều cho cái chuyện
#
# 200
# 00:11:23,846 --> 00:11:24,466
# giải thoát. Họ coi đó là một cái
#
# 201
# 00:11:24,486 --> 00:11:25,046
# vướng mắt. Thế nhưng mà trong
#
# 202
# 00:11:25,066 --> 00:11:25,686
# sự thật thì những thứ đó vẫn đi
#
# 203
# 00:11:25,706 --> 00:11:26,206
# theo chúng ta cả cuộc đời.
#
# 204
# 00:11:26,226 --> 00:11:26,826
# Có thể đến bây giờ chúng ta đã
#
# 205
# 00:11:26,846 --> 00:11:49,173
# rất lớn tuổi hay
#
# 206
# 00:11:49,193 --> 00:11:49,713
# con trẻ, nhưng chúng ta vẫn
#
# 207
# 00:11:49,734 --> 00:11:50,234
# có thể nhớ được những cái
#
# 208
# 00:11:50,254 --> 00:11:50,834
# khẩu vị thức ăn mà mẹ nấu cho
#
# 209
# 00:11:50,854 --> 00:11:51,335
# lúc con nhỏ. Tại vì nó đã
#
# 210
# 00:11:51,355 --> 00:11:51,915
# trở thành một phần yêu thích,
#
# 211
# 00:11:51,935 --> 00:11:52,556
# một phần trong cái tâm thức của
#
# 212
# 00:11:52,576 --> 00:11:53,116
# chúng ta. Thế cho nên nếu mà
#
# 213
# 00:11:53,136 --> 00:11:53,677
# bảo gạt bỏ nó hoàn toàn thì
#
# 214
# 00:11:53,697 --> 00:11:54,217
# không được. Thì khi mà sống
#
# 215
# 00:11:54,237 --> 00:12:18,568
# trong cộng đồng chúng ta
#
# 216
# 00:12:18,588 --> 00:12:19,229
# sẽ phải học cách rung hòa tất cả
#
# 217
# 00:12:19,249 --> 00:12:19,689
# những cái khác biệt đó.
#
# 218
# 00:12:19,709 --> 00:12:20,269
# Ngày xưa khi Đức Thế Tôn mới
#
# 219
# 00:12:20,289 --> 00:12:20,910
# bước chân vào con đường thu học,
#
# 220
# 00:12:20,930 --> 00:12:21,570
# Ngài cũng bị ảnh hưởng bởi những
#
# 221
# 00:12:21,590 --> 00:12:22,211
# cái nhận thức rằng là cái đó là
#
# 222
# 00:12:22,231 --> 00:12:22,811
# một loại trở ngại. Phải gạt bỏ
#
# 223
# 00:12:22,831 --> 00:12:23,371
# nó ra. Ăn uống khăn khổ. Ngài
#
# 224
# 00:12:23,391 --> 00:12:48,258
# đẩy nó đến mức đau nhất nhưng
#
# 225
# 00:12:48,278 --> 00:12:48,819
# rồi cũng không có thành quả
#
# 226
# 00:12:48,839 --> 00:12:49,379
# tụ học cho nó. Cuối cùng thì
#
# 227
# 00:12:49,399 --> 00:12:50,000
# ngài phải chọn cái con đường ở
#
# 228
# 00:12:50,020 --> 00:12:50,601
# mức đó giữa, nó trung hòa được
#
# 229
# 00:12:50,621 --> 00:12:51,221
# những cái đó để cho hai bên nó
#
# 230
# 00:12:51,241 --> 00:12:51,882
# không trở thành một cái trở ngại
#
# 231
# 00:12:51,902 --> 00:12:52,422
# nữa. Và sau này khi ngài có
#
# 232
# 00:12:52,442 --> 00:12:52,543
# đệ tử,
#
# 233
# 00:13:17,318 --> 00:13:17,858
# Những ai mà làm thị giả cho
#
# 234
# 00:13:17,878 --> 00:13:18,519
# Sương cũng thấy rõ điều đó Mà dù
#
# 235
# 00:13:18,539 --> 00:13:19,160
# Sương hiểu rất rõ về giá lý của
#
# 236
# 00:13:19,180 --> 00:13:19,660
# sự thuật Nhưng mà cái sự
#
# 237
# 00:13:19,680 --> 00:13:20,220
# thưởng thức món ăn ngon của
#
# 238
# 00:13:20,240 --> 00:13:20,861
# Sương nó vẫn cứ còn đó Và Sương
#
# 239
# 00:13:20,881 --> 00:13:21,501
# không bài bác nó Thị giả mà nấu
#
# 240
# 00:13:21,521 --> 00:13:22,122
# được món ngon thì cũng sẽ được
#
# 241
# 00:13:22,142 --> 00:13:22,783
# Sương khen rất là rõ Thì Đối với
#
# 242
# 00:13:22,803 --> 00:13:23,383
# chúng ta cho đến bây giờ cũng
#
# 243
# 00:13:23,403 --> 00:13:47,638
# vậy Khi mà nhìn
#
# 244
# 00:13:47,658 --> 00:13:48,238
# lên bàn ăn được phục vụ những
#
# 245
# 00:13:48,258 --> 00:13:48,858
# món ăn rất là ngon trong đó có
#
# 246
# 00:13:48,878 --> 00:13:49,499
# những món nó rất là hợp khẩu vị
#
# 247
# 00:13:49,519 --> 00:13:50,159
# với mình nhưng mà cũng có thể có
#
# 248
# 00:13:50,179 --> 00:13:50,779
# những món mà mình nhìn thấy nó
#
# 249
# 00:13:50,799 --> 00:13:51,399
# không có hấp dẫn gì mấy mặc dù
#
# 250
# 00:13:51,419 --> 00:13:51,979
# nó cũng được bỏ công sức rất
#
# 251
# 00:13:51,999 --> 00:13:52,620
# nhiều bởi người nấu ăn nhưng mà
#
# 252
# 00:13:52,640 --> 00:13:53,260
# vì nó không phải là khẩu vị của
#
# 253
# 00:13:53,280 --> 00:13:53,900
# ta thôi chứ không phải là vì nó
#
# 254
# 00:13:53,920 --> 00:13:54,520
# chất lượng kém hay là nó không
#
# 255
# 00:13:54,540 --> 00:13:55,140
# được nấu đến hết lòng nhưng mà
#
# 256
# 00:13:55,160 --> 00:14:17,450
# chắc cũng vẫn sẽ
#
# 257
# 00:14:17,470 --> 00:14:18,070
# phải ăn thôi chứ à đâu thể nào
#
# 258
# 00:14:18,090 --> 00:14:18,710
# nhịp về rồi sang bữa sau mới ăn
#
# 259
# 00:14:18,730 --> 00:14:19,270
# được thì khi mà ở trong đội
#
# 260
# 00:14:19,290 --> 00:14:19,931
# nấu ăn thì chúng ta sẽ đối thiện
#
# 261
# 00:14:19,951 --> 00:14:20,531
# với những nguồn thể đó khi mà
#
# 262
# 00:14:46,553 --> 00:14:47,153
# Nấu ăn mà được cái màu sắc tốt,
#
# 263
# 00:14:47,173 --> 00:14:47,713
# nhiều người thích, những cái
#
# 264
# 00:14:47,734 --> 00:14:48,314
# hương vị nó hấp dẫn, nó có mùi
#
# 265
# 00:14:48,334 --> 00:14:48,894
# rất là thơm, nó sẽ được nhiều
#
# 266
# 00:14:48,914 --> 00:14:49,494
# người chấp nhận hơn. Và có thể
#
# 267
# 00:14:49,514 --> 00:14:50,055
# người ta sẽ múc thêm một tí.
#
# 268
# 00:14:50,075 --> 00:14:50,655
# Với những cái món mà nó không
#
# 269
# 00:14:50,675 --> 00:14:51,255
# hợp khẩu, có thể ta sẽ múc lại
#
# 270
# 00:14:51,275 --> 00:14:51,735
# ít lại một tí. Và vì thế,
#
# 271
# 00:14:51,755 --> 00:14:52,275
# thức ăn nó có khi nó dư, nó
#
# 272
# 00:14:52,295 --> 00:14:52,396
# thiếu.
#
# 273
# 00:15:14,752 --> 00:15:15,192
# là những người đến đây
#
# 274
# 00:15:15,212 --> 00:15:15,753
# thường xuyên cho những ngày
#
# 275
# 00:15:15,773 --> 00:15:16,353
# chủ nhật cũng đã thấy có ngày
#
# 276
# 00:15:16,373 --> 00:15:16,954
# thức ăn nó dư ra rất là nhiều,
#
# 277
# 00:15:16,974 --> 00:15:17,594
# cũng có ngày nó thiếu quá nhiều
#
# 278
# 00:15:17,614 --> 00:15:18,195
# đấy. Đấy là bởi vì khẩu vị của
#
# 279
# 00:15:18,215 --> 00:15:18,815
# người ta nó khác nhau. Nó không
#
# 280
# 00:15:18,835 --> 00:15:19,456
# phải là bởi vì các vị trong đội
#
# 281
# 00:15:19,476 --> 00:15:20,076
# đồ ăn làm không hết lầm. Đây là
#
# 282
# 00:15:20,096 --> 00:15:20,716
# cái phở, cái điều mà phở nhận ra
#
# 283
# 00:15:20,736 --> 00:15:20,917
# trong cái...
#
# 284
# 00:15:46,257 --> 00:15:46,897
# Đối với nhiều người nghĩ rằng để
#
# 285
# 00:15:46,917 --> 00:15:47,538
# tốt cho cơ thể thì thức ăn phải
#
# 286
# 00:15:47,558 --> 00:15:48,158
# là cái chất lượng tốt nhất mới
#
# 287
# 00:15:48,178 --> 00:15:48,759
# được. Nó phải đắt tiền hoặc là
#
# 288
# 00:15:48,779 --> 00:15:49,379
# được tình nguyện phải ở mức độ
#
# 289
# 00:15:49,399 --> 00:15:49,980
# rất là cao mới được. Thế nhưng
#
# 290
# 00:15:50,000 --> 00:15:50,620
# trong sự thực tập của ta nó còn
#
# 291
# 00:15:50,640 --> 00:15:51,220
# kèm theo cái sự hiểu biết, cái
#
# 292
# 00:15:51,241 --> 00:16:18,751
# tuệ giác Cái
#
# 293
# 00:16:18,771 --> 00:16:19,391
# thân thể chúng ta nó không phải
#
# 294
# 00:16:19,411 --> 00:16:20,052
# chỉ dưới hạn trong cái hình thức
#
# 295
# 00:16:20,072 --> 00:16:20,712
# này mà nó còn là bao trùm cả cái
#
# 296
# 00:16:20,732 --> 00:16:21,333
# vũ trụ này, cả cái đất nước này
#
# 297
# 00:16:21,353 --> 00:16:21,913
# là không khí, là dòng sông, là
#
# 298
# 00:16:21,933 --> 00:16:22,453
# năng lượng của những người
#
# 299
# 00:16:22,473 --> 00:16:23,094
# xung quanh nữa. Nếu chúng ta chỉ
#
# 300
# 00:16:23,114 --> 00:16:23,734
# lo cho cái thân thể này nó được
#
# 301
# 00:16:23,754 --> 00:16:24,194
# tốt không mà những cái
#
# 302
# 00:16:24,214 --> 00:16:24,855
# thành phần khác của cái thân thể
#
# 303
# 00:16:24,875 --> 00:16:48,971
# lớn này nó
#
# 304
# 00:16:48,991 --> 00:16:49,551
# không được lành mạnh thì sớm
#
# 305
# 00:16:49,571 --> 00:16:50,192
# muộn nó cũng trở thành ống mạnh
#
# 306
# 00:16:50,212 --> 00:16:50,832
# có nghĩa là cái môi trường sống
#
# 307
# 00:16:50,852 --> 00:16:51,453
# của chúng ta nếu nó không được
#
# 308
# 00:16:51,473 --> 00:16:51,973
# làm cho lành mạnh, làm cho
#
# 309
# 00:16:51,993 --> 00:16:52,633
# chất lượng cao thì nó cũng không
#
# 310
# 00:16:52,653 --> 00:16:53,274
# dẫn đến cái quả tốt thế nên cái
#
# 311
# 00:16:53,294 --> 00:16:53,814
# cách thức mà chúng ta chọn
#
# 312
# 00:16:53,834 --> 00:16:54,434
# thức ăn nó cũng sẽ đi theo cái
#
# 313
# 00:16:54,454 --> 00:17:16,055
# hướng đó Có
#
# 314
# 00:17:16,075 --> 00:17:16,635
# một lần sau khi đi chợ về và
#
# 315
# 00:17:16,655 --> 00:17:17,236
# đang khiêng thức ăn xuống Hội
#
# 316
# 00:17:17,256 --> 00:17:17,836
# làm trí khổ nên có khi đi chợ
#
# 317
# 00:17:17,856 --> 00:17:18,496
# một chợ xe thức ăn rất là đầy về
#
# 318
# 00:17:18,516 --> 00:17:19,117
# Phải nhờ các vị khá khiết giúp
#
# 319
# 00:17:19,137 --> 00:17:19,757
# khiêng xuống để cho vào kho Thì
#
# 320
# 00:17:19,777 --> 00:17:20,377
# có một vị kiến xin hỏi tại sao
#
# 321
# 00:17:20,396 --> 00:17:20,917
# mua cái loại thức ăn đó Nó
#
# 322
# 00:17:20,938 --> 00:17:21,558
# như vậy Vị đó nghĩ mình nên mua
#
# 323
# 00:17:21,578 --> 00:17:22,137
# ở cái tiệm đó thì nó tốt hơn
#
# 324
# 00:17:46,812 --> 00:17:47,312
# Đúng như vậy. Nhưng mà Phụ
#
# 325
# 00:17:47,332 --> 00:17:47,953
# trả lời, tại vì mình cũng còn có
#
# 326
# 00:17:47,973 --> 00:17:48,553
# cả thực tập bảo vệ môi trường
#
# 327
# 00:17:48,573 --> 00:17:49,053
# nữa. Trong khi đi chợ mua
#
# 328
# 00:17:49,073 --> 00:17:49,614
# thức ăn, nó cũng là một loại
#
# 329
# 00:17:49,634 --> 00:17:50,234
# thực tập. Cách thức mà chúng ta
#
# 330
# 00:17:50,254 --> 00:17:50,874
# chọn lựa thức ăn, nó cũng tạo ra
#
# 331
# 00:17:50,894 --> 00:17:51,435
# cái chất lượng của đời sống.
#
# 332
# 00:18:13,913 --> 00:18:14,513
# không phải vì bản thân của cái
#
# 333
# 00:18:14,533 --> 00:18:15,033
# chất lượng thức ăn mà cái
#
# 334
# 00:18:15,053 --> 00:18:15,674
# cách thức chúng ta chọn được nó
#
# 335
# 00:18:15,694 --> 00:18:16,234
# cũng khác Tôi giải thích là
#
# 336
# 00:18:16,254 --> 00:18:16,874
# tại sao mua cái loại rau cải đó
#
# 337
# 00:18:16,894 --> 00:18:17,474
# Tại vì nó đóng bằng cái thùng
#
# 338
# 00:18:17,494 --> 00:18:18,095
# cát tâm cùng một lượng thức ăn
#
# 339
# 00:18:18,115 --> 00:18:18,735
# nhưng nếu mình mua cái loại rau
#
# 340
# 00:18:18,755 --> 00:18:19,355
# cải đó mà đóng trong cái thùng
#
# 341
# 00:18:19,375 --> 00:18:19,875
# nhựa thì nó không tốt cho
#
# 342
# 00:18:19,895 --> 00:18:45,553
# môi trường sống trong
#
# 343
# 00:18:45,573 --> 00:18:46,103
# cùng một tiệm, nhưng mà có 2
#
# 344
# 00:18:46,113 --> 00:18:46,753
# loại thức ăn ta sẽ lưu tiên chọn
#
# 345
# 00:18:46,773 --> 00:18:47,393
# cái loại mà nó có ý thức bảo vệ
#
# 346
# 00:18:47,413 --> 00:18:47,934
# môi trường trong đó thì vị
#
# 347
# 00:18:47,954 --> 00:18:48,534
# thiền sinh đó rất là hài lòng
#
# 348
# 00:18:48,554 --> 00:18:49,134
# với câu trả lời đó bởi vì khi
#
# 349
# 00:18:49,154 --> 00:18:49,734
# tâm mua một lượng lớn thức ăn
#
# 350
# 00:18:49,754 --> 00:18:50,394
# thì đồng thời cũng có nghĩa rằng
#
# 351
# 00:18:50,414 --> 00:19:15,179
# chúng ta đang trả
#
# 352
# 00:19:15,199 --> 00:19:15,799
# ra rất là nhiều. Và nếu toàn bộ
#
# 353
# 00:19:15,819 --> 00:19:16,460
# cái lượng thức ăn đó mà được bọc
#
# 354
# 00:19:16,480 --> 00:19:17,060
# trong lây lâm hay trong thùng
#
# 355
# 00:19:17,080 --> 00:19:17,680
# nhựa thì nó không có dễ thương
#
# 356
# 00:19:17,700 --> 00:19:18,280
# với đất mẹ. Thì vị Thiền Thinh
#
# 357
# 00:19:18,300 --> 00:19:18,841
# nó thông cảm liền, hiểu liền.
#
# 358
# 00:19:18,861 --> 00:19:19,441
# Và cũng nói rằng trong án của
#
# 359
# 00:19:19,461 --> 00:19:20,021
# anh ta cũng đang đi theo cái
#
# 360
# 00:19:20,041 --> 00:19:20,201
# hướng đó.
#
# 361
# 00:19:45,157 --> 00:19:45,797
# Những cái bàn chải bằng nhựa hay
#
# 362
# 00:19:45,817 --> 00:19:46,437
# những vật động nhựa phải chuyển
#
# 363
# 00:19:46,457 --> 00:19:47,078
# sang dùng cái loại mà nó có thể
#
# 364
# 00:19:47,098 --> 00:19:47,638
# nhanh chóng tiêu hóa được ở
#
# 365
# 00:19:47,658 --> 00:19:48,238
# trong đất Để nó không làm hại
#
# 366
# 00:19:48,258 --> 00:19:48,758
# đất, đất mẹ Nghĩa là vì đó,
#
# 367
# 00:19:48,778 --> 00:19:49,358
# bởi vì cùng cái tâm thức cũng
#
# 368
# 00:19:49,378 --> 00:19:50,019
# hiểu được tầm quan trọng của cái
#
# 369
# 00:19:50,039 --> 00:19:50,659
# việc Thứ khác nó không phải chỉ
#
# 370
# 00:19:50,679 --> 00:20:10,323
# ở trong cái hình được mà
#
# 371
# 00:20:10,343 --> 00:20:10,823
# nó còn là những thứ khác
#
# 372
# 00:20:10,843 --> 00:20:11,404
# nuôi dưỡng mà ý thức được là
#
# 373
# 00:20:11,424 --> 00:20:11,984
# thật thể nó không phải chỉ ở
#
# 374
# 00:20:12,004 --> 00:20:12,644
# trong cái thật thể này thì xí đo
#
# 375
# 00:20:12,664 --> 00:20:13,264
# nó sẽ chấp nhận được những cái
#
# 376
# 00:20:13,284 --> 00:20:13,905
# tiêu chuẩn mà trước đó người ta
#
# 377
# 00:20:13,925 --> 00:20:14,525
# nhất thiết phải hỏi nó thế mới
#
# 378
# 00:20:14,545 --> 00:20:15,145
# là tốt để có thể rung hòa được
#
# 379
# 00:20:15,165 --> 00:20:15,685
# những cái khác to hơn cũng
#
# 380
# 00:20:15,705 --> 00:20:42,753
# như vậy có thể
#
# 381
# 00:20:42,773 --> 00:20:43,193
# chúng ta có quan niệm,
#
# 382
# 00:20:43,213 --> 00:20:43,834
# nhận thức rằng cái loại thức ăn
#
# 383
# 00:20:43,854 --> 00:20:44,454
# nó không có tốt cho cơ thể đâu
#
# 384
# 00:20:44,474 --> 00:20:45,115
# chúng ta phải loại trừ hoàn toàn
#
# 385
# 00:20:45,135 --> 00:20:45,715
# nó ra. Tuy nhiên mà nếu nó lại
#
# 386
# 00:20:45,735 --> 00:20:46,295
# là cái nguyên liệu để tạo ra
#
# 387
# 00:20:46,315 --> 00:20:46,896
# những cái khẩu vị mà có những
#
# 388
# 00:20:46,916 --> 00:20:47,496
# người khác trong chúng rất là
#
# 389
# 00:20:47,516 --> 00:20:48,136
# yêu thích thì sao? Thì công việc
#
# 390
# 00:20:48,157 --> 00:20:48,737
# của trí khấu là phải dùng hòa
#
# 391
# 00:20:48,757 --> 00:21:13,813
# hết những cái đó Thưa
#
# 392
# 00:21:13,833 --> 00:21:14,373
# quý vị, chi khố là một trong
#
# 393
# 00:21:14,393 --> 00:21:14,973
# những công việc tương đối khó
#
# 394
# 00:21:14,993 --> 00:21:15,613
# nhận ở trong chúng, đặc biệt khi
#
# 395
# 00:21:15,633 --> 00:21:16,254
# ở trong cộng đồng tu học cầy mở
#
# 396
# 00:21:16,274 --> 00:21:16,754
# như của chúng ta. Nó cũng
#
# 397
# 00:21:16,774 --> 00:21:17,394
# tương đương như việc chi sự vậy.
#
# 398
# 00:21:17,414 --> 00:21:18,014
# Phải đối diện với tâm thức của
#
# 399
# 00:21:18,034 --> 00:21:18,514
# rất là nhiều người để mà
#
# 400
# 00:21:18,534 --> 00:21:19,114
# hoàn thành nó. Mà đặc biệt lại
#
# 401
# 00:21:19,134 --> 00:21:19,634
# không được dùng quyền lực.
#
# 402
# 00:21:19,654 --> 00:21:20,235
# Chủ trì cũng vậy. Nó phải dùng
#
# 403
# 00:21:20,255 --> 00:21:20,895
# bản lĩnh và cái khéo của mình để
#
# 404
# 00:21:20,915 --> 00:21:21,515
# hoàn thành nó chứ không có thể
#
# 405
# 00:21:21,535 --> 00:21:22,075
# nào mà chỉ giá lệnh mà được.
#
# 406
# 00:21:43,957 --> 00:21:44,537
# cộng đồng ta nó không đi theo
#
# 407
# 00:21:44,557 --> 00:21:45,138
# được nó và vì thế nó đòi phải
#
# 408
# 00:21:45,158 --> 00:21:45,738
# cái sự khỏe và kém lại có thể
#
# 409
# 00:21:45,758 --> 00:21:46,358
# dung hòa rất nhiều có người sẽ
#
# 410
# 00:21:46,378 --> 00:21:46,978
# muốn đẩy nó theo càng gần nhất
#
# 411
# 00:21:46,998 --> 00:21:47,539
# về cái lý tưởng càng tốt và
#
# 412
# 00:21:47,559 --> 00:21:48,179
# vì thế cái quan điểm về thức ăn
#
# 413
# 00:21:48,199 --> 00:21:48,739
# của họ cũng vậy họ sẵn sàng
#
# 414
# 00:21:48,759 --> 00:21:49,400
# bỏ qua cái khẩu vị yêu thích của
#
# 415
# 00:21:49,420 --> 00:22:16,143
# họ để đẩy cái sự tự lập nó
#
# 416
# 00:22:16,163 --> 00:22:16,723
# cũng muốn, các bạn thấy không?
#
# 417
# 00:22:16,743 --> 00:22:17,324
# Cũng phải nên làm như vậy. Thế
#
# 418
# 00:22:17,344 --> 00:22:17,904
# nhưng mà cũng có người, không,
#
# 419
# 00:22:17,924 --> 00:22:18,504
# thuật tập thì thuật tập, nhưng
#
# 420
# 00:22:18,524 --> 00:22:19,165
# cũng vẫn phải muốn giữ lại những
#
# 421
# 00:22:19,185 --> 00:22:19,805
# cái mình đã yêu thích, những cái
#
# 422
# 00:22:19,825 --> 00:22:20,446
# làm cho mình thoải mái. Kịch giờ
#
# 423
# 00:22:20,466 --> 00:22:21,066
# thì mình đã đủ như vậy. Thì mỗi
#
# 424
# 00:22:21,086 --> 00:22:21,666
# cái mức độ nó sẽ có khác nhau,
#
# 425
# 00:22:21,686 --> 00:22:22,307
# hoặc cuối cùng nó tập trung lại
#
# 426
# 00:22:22,327 --> 00:22:22,707
# ở trong cái bếp hết.
#
# 427
# 00:22:44,926 --> 00:22:45,526
# và các vị tổ ngày xưa có những
#
# 428
# 00:22:45,546 --> 00:22:46,146
# vị thầy chủ trì họ nói cái bếp
#
# 429
# 00:22:46,166 --> 00:22:46,807
# phải yên thì cái chùa nó mới yên
#
# 430
# 00:22:46,827 --> 00:22:47,427
# được nó đúng vậy các bạn ở chợ
#
# 431
# 00:22:47,447 --> 00:22:48,067
# cũng biết mà trong một dàng đứa
#
# 432
# 00:22:48,087 --> 00:22:48,727
# con chứ đâu phải đứa nào nó cũng
#
# 433
# 00:22:48,747 --> 00:22:49,387
# thích cái khẩu vị giống nhau đâu
#
# 434
# 00:22:49,407 --> 00:22:49,927
# khẩu vị của ông trồng khác
#
# 435
# 00:22:49,947 --> 00:22:50,488
# có khi khác của đứa con nếu
#
# 436
# 00:22:50,508 --> 00:22:51,088
# trong một bữa mà làm cho được
#
# 437
# 00:22:51,108 --> 00:22:51,588
# cái đó thì là thành công
#
# 438
# 00:22:51,608 --> 00:22:52,228
# tuyệt vời rồi thì cộng đồng ông
#
# 439
# 00:22:52,248 --> 00:23:14,631
# ta may mắn
#
# 440
# 00:23:14,651 --> 00:23:15,131
# là được ngay từ đầu được
#
# 441
# 00:23:15,151 --> 00:23:15,752
# đạo luyện để chọn cái đó. Chính
#
# 442
# 00:23:15,772 --> 00:23:16,372
# có rất nhiều người đã thu được
#
# 443
# 00:23:16,392 --> 00:23:17,012
# cái thành quả rất là tốt. Khi mà
#
# 444
# 00:23:17,032 --> 00:23:17,653
# Phố ấy đi chợ, chợ này chúng thu
#
# 445
# 00:23:17,673 --> 00:23:18,233
# thiệt với quý vị. Lúc đầu Phố
#
# 446
# 00:23:18,253 --> 00:23:18,853
# cũng bừng bừng, những cái ý chí
#
# 447
# 00:23:18,873 --> 00:23:19,354
# rất là mạnh mẽ, những cái
#
# 448
# 00:23:19,374 --> 00:23:19,854
# mong muốn làm sao cho nó
#
# 449
# 00:23:19,874 --> 00:23:44,908
# tuyệt vời nhất Nhưng mà
#
# 450
# 00:23:44,928 --> 00:23:45,528
# sớm cũng nhận ra quá đắng liền
#
# 451
# 00:23:45,548 --> 00:23:46,168
# Đi chợ thì hụt tiền Còn lúc thì
#
# 452
# 00:23:46,189 --> 00:23:46,769
# đại chúng thức ăn không thích
#
# 453
# 00:23:46,789 --> 00:23:47,349
# cái loại đó Có lúc thì dư cả
#
# 454
# 00:23:47,369 --> 00:23:47,969
# đống, có loại khác thì nó thiếu
#
# 455
# 00:23:47,989 --> 00:23:48,569
# Tại vì mình không sớm nhận ra
#
# 456
# 00:23:48,589 --> 00:23:49,230
# những sự khác biệt Trong cái đảo
#
# 457
# 00:23:49,250 --> 00:23:49,810
# là về thức ăn của 30 con người
#
# 458
# 00:23:49,830 --> 00:23:50,370
# hay 300 con người Con người họ
#
# 459
# 00:23:50,390 --> 00:23:51,010
# không được vào bếp nhưng họ vẫn
#
# 460
# 00:23:51,030 --> 00:23:51,630
# thông qua cái cách thức của họ
#
# 461
# 00:24:14,583 --> 00:24:14,983
# để thể hiện họ thích
#
# 462
# 00:24:15,003 --> 00:24:15,544
# như thế nào. Nó giống như cô
#
# 463
# 00:24:15,564 --> 00:24:16,144
# nói, cái món đó họ không thích,
#
# 464
# 00:24:16,164 --> 00:24:16,725
# họ búc cái nửa bụng thôi. Thế
#
# 465
# 00:24:16,745 --> 00:24:17,345
# nên người trong bếp mà căn nấu
#
# 466
# 00:24:17,365 --> 00:24:17,906
# cho 300 người thì dư có khi cả
#
# 467
# 00:24:17,926 --> 00:24:18,486
# trăm phần ăn. Bởi vì nó không
#
# 468
# 00:24:18,506 --> 00:24:19,047
# đúng với cái khẩu vị này. Có
#
# 469
# 00:24:19,067 --> 00:24:19,707
# những món mình lượn ra là nấu đã
#
# 470
# 00:24:19,727 --> 00:24:20,188
# dư giản lắm rồi đấy. Thế
#
# 471
# 00:24:20,208 --> 00:24:20,848
# nhưng mà đến cuối bữa thì nó vẫn
#
# 472
# 00:24:20,868 --> 00:24:21,409
# cứ thiếu như được. Là bởi vì
#
# 473
# 00:24:21,429 --> 00:24:21,929
# người ta thích cái món đó.
#
# 474
# 00:24:44,232 --> 00:24:44,872
# sẽ múc thêm một tí mỗi người thì
#
# 475
# 00:24:44,892 --> 00:24:45,513
# không bao nhiêu mà cả hàng trăm
#
# 476
# 00:24:45,533 --> 00:24:46,173
# người cộng lại thì cái phía đằng
#
# 477
# 00:24:46,193 --> 00:24:46,813
# sau có khi không còn được miếng
#
# 478
# 00:24:46,833 --> 00:24:47,413
# nào đó là lý do vì sao quý vị
#
# 479
# 00:24:47,433 --> 00:24:48,014
# đang thấy những trường hợp nó
#
# 480
# 00:24:48,034 --> 00:24:48,574
# xảy ra thường xuyên thì mọi
#
# 481
# 00:24:48,594 --> 00:24:49,234
# người cứ nghĩ rằng là cái đó chỉ
#
# 482
# 00:24:49,254 --> 00:24:49,894
# không phải gánh hết tổi thiếu là
#
# 483
# 00:25:15,097 --> 00:25:15,677
# Thế nhưng nó cũng là một điều
#
# 484
# 00:25:15,697 --> 00:25:16,317
# thú vị để học hỏi và nó tạo cho
#
# 485
# 00:25:16,337 --> 00:25:16,917
# mình có thêm bản lĩnh qua mỗi
#
# 486
# 00:25:16,937 --> 00:25:17,538
# năm tháng Nếu mà vượt qua được
#
# 487
# 00:25:17,558 --> 00:25:17,978
# hết những tâm thức đó,
#
# 488
# 00:25:17,998 --> 00:25:18,538
# dung hòa, khéo khéo dung hòa
#
# 489
# 00:25:18,558 --> 00:25:19,198
# được những tâm thức khác nhau đó
#
# 490
# 00:25:19,218 --> 00:25:19,858
# để đi về được cùng một hướng thì
#
# 491
# 00:25:19,878 --> 00:25:20,458
# nó tạo ra rất nhiều hạnh phúc
#
# 492
# 00:25:20,478 --> 00:25:21,118
# cho đại chúng Đại chúng cũng rất
#
# 493
# 00:25:21,138 --> 00:25:21,718
# là dễ thương Không phải là họ
#
# 494
# 00:25:21,738 --> 00:25:22,278
# đòi hỏi cái gì nó cũng phải
#
# 495
# 00:25:22,298 --> 00:25:22,879
# tuyệt vời mà họ mới hạnh phúc
#
# 496
# 00:25:45,117 --> 00:25:45,758
# cũng có cái sự thực tập trong đó
#
# 497
# 00:25:45,778 --> 00:25:46,398
# thế cho nên không phải là không
#
# 498
# 00:25:46,418 --> 00:25:47,019
# nhất thiết là phải đạt đến mức
#
# 499
# 00:25:47,039 --> 00:25:47,499
# tuyệt hảo thì họ mới có
#
# 500
# 00:25:47,519 --> 00:25:48,140
# hạnh phúc không phải như vậy họ
#
# 501
# 00:25:48,160 --> 00:25:48,780
# cũng biết cách làm sao để trong
#
# 502
# 00:25:48,800 --> 00:25:49,421
# cái điều kiện đó họ cũng làm ra
#
# 503
# 00:25:49,441 --> 00:25:50,041
# được những món ngon nhất những
#
# 504
# 00:25:50,061 --> 00:26:15,181
# cái thứ thật đó và vì thế Khi
#
# 505
# 00:26:15,201 --> 00:26:15,742
# mà đi làm chi khổ, một trong
#
# 506
# 00:26:15,762 --> 00:26:16,402
# những yêu cầu rất là cao là phải
#
# 507
# 00:26:16,422 --> 00:26:16,983
# tiết kiệm. Bởi vì đối với ông
#
# 508
# 00:26:17,003 --> 00:26:17,523
# Thầy Tú, đạo đức không được
#
# 509
# 00:26:17,543 --> 00:26:18,104
# phung phí. Nó phải sống ở mức
#
# 510
# 00:26:18,124 --> 00:26:18,644
# chi túc và phải ở dưới mức
#
# 511
# 00:26:18,664 --> 00:26:19,265
# trung bình của xã hội để mà nó
#
# 512
# 00:26:19,285 --> 00:26:19,885
# giữ bền sự thực tập. Vừa rồi đi
#
# 513
# 00:26:19,905 --> 00:26:19,965
# chợ,
#
# 514
# 00:26:42,779 --> 00:26:43,419
# thì người đứng kiểm soát hóa đơn
#
# 515
# 00:26:43,439 --> 00:26:44,060
# ở ngoài cửa họ khen các thầy đi
#
# 516
# 00:26:44,080 --> 00:26:44,680
# chợ mua thức ăn rất là healthy.
#
# 517
# 00:26:44,700 --> 00:26:45,301
# Tại vì hàng ngày có hàng nghìn
#
# 518
# 00:26:45,321 --> 00:26:45,921
# người đi chợ trong một cái chợ
#
# 519
# 00:26:45,941 --> 00:26:46,521
# đó. Thì người ta nhìn quen mắt,
#
# 520
# 00:26:46,542 --> 00:26:47,182
# người ta cũng thấy được những sự
#
# 521
# 00:26:47,202 --> 00:26:47,802
# khác nhau, xong rồi sự chọn lựa
#
# 522
# 00:26:47,822 --> 00:26:48,403
# của những người đi chợ. Và khi
#
# 523
# 00:26:48,423 --> 00:26:49,003
# mình được những người nó khen
#
# 524
# 00:26:49,023 --> 00:26:49,624
# như vậy, mình cũng cảm thấy rất
#
# 525
# 00:26:49,644 --> 00:26:49,764
# là vui.
#
# 526
# 00:27:12,682 --> 00:27:13,322
# để đôi khi có những người đứng ở
#
# 527
# 00:27:13,342 --> 00:27:13,963
# cái chỗ tính tiền họ nói quý vị
#
# 528
# 00:27:13,983 --> 00:27:14,583
# mua thức ăn rất là luxury Mình
#
# 529
# 00:27:14,603 --> 00:27:15,244
# cũng vui nữa bởi vì thực ra mình
#
# 530
# 00:27:15,264 --> 00:27:15,804
# không có chi nhiều tiền cho
#
# 531
# 00:27:15,824 --> 00:27:16,364
# thức ăn hàng ngày Mỗi người
#
# 532
# 00:27:16,384 --> 00:27:16,905
# trong tu viện chỉ được gọt
#
# 533
# 00:27:16,925 --> 00:27:17,485
# trên dưới 5 đồng cho một ngày
#
# 534
# 00:27:17,505 --> 00:27:18,145
# thôi Tiền chi cho thức ăn chỉ là
#
# 535
# 00:27:18,165 --> 00:27:18,646
# trên dưới 5 đồng một ngày
#
# 536
# 00:27:42,584 --> 00:27:43,225
# lành mạnh và chất lượng cũng khá
#
# 537
# 00:27:43,245 --> 00:27:43,685
# cao. Là bởi vì công sức
#
# 538
# 00:27:43,705 --> 00:27:44,286
# đồng lòng của nhiều người. Tại
#
# 539
# 00:27:44,306 --> 00:27:44,926
# vì chúng ta cùng đồng lòng chọn
#
# 540
# 00:27:44,946 --> 00:27:45,487
# về cái hướng sống lành mạnh.
#
# 541
# 00:27:45,507 --> 00:27:46,127
# Tất nhiên nó cũng giống như cái
#
# 542
# 00:27:46,147 --> 00:27:46,768
# việc đi chợ, không thể nào không
#
# 543
# 00:27:46,788 --> 00:27:47,388
# có xả rét. Nấu ăn không thể nào
#
# 544
# 00:27:47,408 --> 00:27:48,049
# không là hoàn hảo và khẩu vị cho
#
# 545
# 00:27:48,069 --> 00:27:48,609
# tất cả mọi người. Cũng không
#
# 546
# 00:27:48,629 --> 00:27:49,170
# phải lúc nào cũng là đầy đủ,
#
# 547
# 00:27:49,190 --> 00:27:49,770
# không dư thừa hay không thiếu.
#
# 548
# 00:28:12,908 --> 00:28:13,468
# Để gân dư nhiều quá, nó không
#
# 549
# 00:28:13,488 --> 00:28:14,069
# phải là một cái bảo vệ đất mẹ,
#
# 550
# 00:28:14,089 --> 00:28:14,669
# nó không có dễ thương Một bao
#
# 551
# 00:28:14,689 --> 00:28:15,230
# rau, nó cần 200 gallon nước Một
#
# 552
# 00:28:15,250 --> 00:28:15,770
# bao đậu, nó cần từ 400 cho đến
#
# 553
# 00:28:15,780 --> 00:28:16,290
# 2.000 gallon nước Trước khi nó
#
# 554
# 00:28:16,310 --> 00:28:16,931
# thành thành phẩm đến với bản ăn
#
# 555
# 00:28:16,951 --> 00:28:41,437
# của chúng ta nếu
#
# 556
# 00:28:41,457 --> 00:28:42,017
# là thịt thì nó còn cần nhiều
#
# 557
# 00:28:42,037 --> 00:28:42,678
# hơn nữa mà nếu như trong một bữa
#
# 558
# 00:28:42,698 --> 00:28:43,278
# ăn mà chúng ta nấu dưa ra vài
#
# 559
# 00:28:43,298 --> 00:28:43,898
# chục bao tức ăn có nghĩa là có
#
# 560
# 00:28:43,918 --> 00:28:44,559
# hàng chục nghìn gallon nước phải
#
# 561
# 00:28:44,579 --> 00:28:45,179
# bị tiêu phí chưa kể những loại
#
# 562
# 00:28:45,199 --> 00:28:45,799
# năng lượng khác giống như điếc,
#
# 563
# 00:28:45,819 --> 00:28:46,320
# gà và như vậy là không có
#
# 564
# 00:28:46,340 --> 00:28:46,920
# dễ thương với đất mẹ bên cạnh
#
# 565
# 00:28:46,940 --> 00:28:47,580
# cái đạo đức của ông thầy Tu rằng
#
# 566
# 00:28:47,600 --> 00:29:14,615
# là không có được Tuy nhiên
#
# 567
# 00:29:14,635 --> 00:29:15,235
# mà, ông cũng sớm nhận ra, nếu mà
#
# 568
# 00:29:15,255 --> 00:29:15,876
# mình là người nấu ăn, cứ nấu cho
#
# 569
# 00:29:15,896 --> 00:29:16,476
# thoải mái, hoặc nấu thiếu cũng
#
# 570
# 00:29:16,496 --> 00:29:17,036
# không phải là con đường tốt.
#
# 571
# 00:29:17,056 --> 00:29:17,657
# Tại vì khi mình phải nấu ăn, mà
#
# 572
# 00:29:17,677 --> 00:29:18,317
# tự dưng có nhiều người phía đằng
#
# 573
# 00:29:18,337 --> 00:29:18,817
# sau bị thiếu thức ăn quá,
#
# 574
# 00:29:18,837 --> 00:29:19,378
# thật ra nó cũng cảm thấy nó
#
# 575
# 00:29:19,398 --> 00:29:19,718
# khó chịu vô cùng.
#
# 576
# 00:29:47,594 --> 00:29:48,234
# Mình cảm thấy nó không đếch chịu
#
# 577
# 00:29:48,254 --> 00:29:48,835
# chút nào. Hoặc có thể là không
#
# 578
# 00:29:48,855 --> 00:29:49,395
# ai trách mình, nhưng mà mình
#
# 579
# 00:29:49,415 --> 00:29:49,975
# cảm thấy nó không yên tâm. Và
#
# 580
# 00:29:49,995 --> 00:29:50,595
# vì thế, mình cũng thông cảm cho
#
# 581
# 00:29:50,615 --> 00:29:51,176
# những người phải nấu ăn cùng
#
# 582
# 00:29:51,196 --> 00:29:51,656
# mình, Chủ nhật. Mình cũng
#
# 583
# 00:29:51,676 --> 00:29:52,316
# không thể nào đòi hỏi rằng là nó
#
# 584
# 00:29:52,336 --> 00:29:52,916
# không được dư thừa được. Nhưng
#
# 585
# 00:29:52,936 --> 00:29:53,517
# cũng không thể nào để cho cái
#
# 586
# 00:29:53,537 --> 00:29:54,097
# chuyện nấu ăn mà nó không có
#
# 587
# 00:29:54,117 --> 00:29:54,517
# dễ thương với đất mẹ,
#
# 588
# 00:30:17,783 --> 00:30:18,263
# với cái thân thể lớn của
#
# 589
# 00:30:18,283 --> 00:30:18,843
# chúng ta như vậy thì nó phải
#
# 590
# 00:30:18,863 --> 00:30:19,464
# dung hòa thôi để cho mỗi người
#
# 591
# 00:30:19,484 --> 00:30:20,084
# trong cái quá trình đó học hỏi
#
# 592
# 00:30:20,104 --> 00:30:20,704
# nó sẽ có những cái bất toàn để
#
# 593
# 00:30:20,724 --> 00:30:21,364
# mà lớn lên thì những kinh nghiệm
#
# 594
# 00:30:21,384 --> 00:30:22,025
# đó phải dùng nhiều năm để học và
#
# 595
# 00:30:46,876 --> 00:30:47,396
# Vì thế Phậu có niềm tin từ
#
# 596
# 00:30:47,416 --> 00:30:47,997
# Đại chúng và từ chính mình để
#
# 597
# 00:30:48,017 --> 00:30:48,637
# có thể chia sẻ lại và hướng dẫn
#
# 598
# 00:30:48,657 --> 00:30:49,237
# cho những vị chi khấu kế tiếp
#
# 599
# 00:30:49,257 --> 00:30:49,817
# trong chúng. Trong khi đi chợ,
#
# 600
# 00:30:49,837 --> 00:30:50,438
# mình thấy có nhiều danh mục để
#
# 601
# 00:30:50,458 --> 00:30:50,998
# thực tập. Tiền thì nó là vừa
#
# 602
# 00:30:51,018 --> 00:30:51,618
# nhiều hơn, đồng thời nó cũng là
#
# 603
# 00:30:51,638 --> 00:30:51,758
# ít hơn.
#
# 604
# 00:31:17,251 --> 00:31:17,832
# Tại vì tập trung cái tiền của
#
# 605
# 00:31:17,852 --> 00:31:18,492
# rất là nhiều người lại để đi chợ
#
# 606
# 00:31:18,512 --> 00:31:18,953
# thì nó là dễ hơn. Nhưng
#
# 607
# 00:31:18,973 --> 00:31:19,553
# đồng thời nó cũng hạn chế bởi
#
# 608
# 00:31:19,573 --> 00:31:20,094
# cái số lượng số người được
#
# 609
# 00:31:20,114 --> 00:31:20,694
# chi tiêu cho mỗi người thì nó
#
# 610
# 00:31:20,714 --> 00:31:21,255
# cũng là ở cái mức thấp thôi.
#
# 611
# 00:31:21,275 --> 00:31:21,855
# Thế cho nên nó không có buông
#
# 612
# 00:31:21,875 --> 00:31:22,496
# tay quá chắn được. Nhưng mà cũng
#
# 613
# 00:31:22,516 --> 00:31:23,136
# đồng thời không được làm mất đi
#
# 614
# 00:31:23,157 --> 00:31:23,777
# những cái nhu cầu của đại chúng
#
# 615
# 00:31:23,797 --> 00:31:44,898
# về và
#
# 616
# 00:31:44,918 --> 00:31:45,498
# nó có hàng nghìn cái danh mục
#
# 617
# 00:31:45,518 --> 00:31:45,959
# phải mua, phải nhớ, phải
#
# 618
# 00:31:45,979 --> 00:31:46,559
# chăm sóc đến. Và nếu như không
#
# 619
# 00:31:46,579 --> 00:31:47,199
# có cái sự hứng thú trong đó thì
#
# 620
# 00:31:47,219 --> 00:31:47,739
# sẽ thấy đó là một cái nặng.
#
# 621
# 00:31:47,759 --> 00:31:48,320
# Nhưng mà khi mà thấy rằng nó
#
# 622
# 00:31:48,340 --> 00:31:48,920
# cũng chỉ là một cái vị trí để
#
# 623
# 00:31:48,940 --> 00:31:49,480
# thực tập, phụng sự như những
#
# 624
# 00:31:49,500 --> 00:31:50,141
# vị trí khác ở trong chúng thì sẽ
#
# 625
# 00:31:50,161 --> 00:31:50,721
# thấy nó có nhiều hứng thú, có
#
# 626
# 00:31:50,741 --> 00:31:51,301
# cái động lực, có cái niềm vui
#
# 627
# 00:31:51,321 --> 00:31:51,822
# trong đó để mình được gặp.
#
# 628
# 00:31:51,842 --> 00:31:52,442
# Bên cạnh những sự tòa học mình
#
# 629
# 00:32:20,330 --> 00:32:20,830
# đi chợ trước mình, hoặc đã
#
# 630
# 00:32:20,850 --> 00:32:21,371
# cố gắng làm như thế nào để
#
# 631
# 00:32:21,391 --> 00:32:21,971
# truyền lại cho mình những cái
#
# 632
# 00:32:21,991 --> 00:32:22,552
# kinh nghiệm tốt nhất. Và mình
#
# 633
# 00:32:22,572 --> 00:32:23,152
# cũng đang tích lũy được những
#
# 634
# 00:32:23,172 --> 00:32:23,672
# cái điều rất là thú vị để
#
# 635
# 00:32:23,692 --> 00:32:24,253
# chia sẻ cho những người khác.
#
# 636
# 00:32:24,273 --> 00:32:24,873
# Và cũng để giải thích được với
#
# 637
# 00:32:24,893 --> 00:32:25,514
# đại chúng rằng tại sao mình lại
#
# 638
# 00:32:25,534 --> 00:32:26,134
# đi chợ như vậy. Tại sao mình sẽ
#
# 639
# 00:32:26,154 --> 00:32:26,734
# đi chợ ở những cái chợ đó chứ
#
# 640
# 00:32:26,754 --> 00:32:27,355
# không phải là chợ bên kia. Chạy
#
# 641
# 00:32:27,375 --> 00:32:50,342
# xuống phố, có nhiều chợ Nhưng mà
#
# 642
# 00:32:50,362 --> 00:32:50,942
# mình sẽ phải đi chợ những cái
#
# 643
# 00:32:50,962 --> 00:32:51,523
# chỗ mà nó thích hợp nhất cho
#
# 644
# 00:32:51,543 --> 00:32:52,163
# đại chúng chứ không phải là chợ
#
# 645
# 00:32:52,183 --> 00:32:52,803
# nào cũng dễ vào được Mình không
#
# 646
# 00:32:52,823 --> 00:32:53,303
# thành tu mà Nó có cái sự
#
# 647
# 00:32:53,323 --> 00:32:53,804
# quan sát bên cạnh cái sự
#
# 648
# 00:32:53,824 --> 00:32:54,444
# tiêu thụ hàng hóa của mình mình
#
# 649
# 00:32:54,464 --> 00:32:55,084
# cũng còn có có thể quan sát xem
#
# 650
# 00:32:55,104 --> 00:32:55,665
# những người khác có tiêu thụ
#
# 651
# 00:32:55,685 --> 00:32:56,325
# theo cái khuyên hướng nào nữa Để
#
# 652
# 00:32:56,345 --> 00:33:19,303
# cho mình cũng
#
# 653
# 00:33:19,323 --> 00:33:19,923
# giống như cái người đứng thính
#
# 654
# 00:33:19,943 --> 00:33:20,523
# tiền kia hay cái vị kiểm soát
#
# 655
# 00:33:20,543 --> 00:33:21,083
# hoa đơn ở ngoài cửa. Họ cũng
#
# 656
# 00:33:21,103 --> 00:33:21,684
# nhận ra được cái khuyên hướng
#
# 657
# 00:33:21,704 --> 00:33:22,304
# của những người đi chợ là khác
#
# 658
# 00:33:22,324 --> 00:33:22,884
# nhau như thế nào. Thì mình sẽ
#
# 659
# 00:33:22,904 --> 00:33:23,484
# dựa vào chuyện đó. Nó cũng vậy.
#
# 660
# 00:33:23,504 --> 00:33:24,104
# Nếu như mình quan sát tâm thức
#
# 661
# 00:33:24,124 --> 00:33:49,425
# mình rất có thể Mình
#
# 662
# 00:33:49,445 --> 00:33:50,066
# thích đi cái chợ đó bởi vì mình
#
# 663
# 00:33:50,086 --> 00:33:50,686
# thích những loại thức ăn trong
#
# 664
# 00:33:50,706 --> 00:33:51,186
# chợ đó chứ không phải là
#
# 665
# 00:33:51,206 --> 00:33:51,827
# đại chúng thích. Vậy là không có
#
# 666
# 00:33:51,847 --> 00:33:52,307
# thích hợp rồi. Mình phải
#
# 667
# 00:33:52,327 --> 00:33:52,808
# đối tiên cái khảo vệ của
#
# 668
# 00:33:52,828 --> 00:33:53,268
# đại chúng trước. Cái sự
#
# 669
# 00:33:53,288 --> 00:33:53,909
# thuận tiện nấu ăn của đại chúng
#
# 670
# 00:33:53,929 --> 00:33:54,549
# trước chứ không phải là là nghĩ
#
# 671
# 00:33:54,569 --> 00:33:55,210
# rằng là mình cái chợ thì mình có
#
# 672
# 00:33:55,230 --> 00:33:55,830
# quyền mua cái gì thì đại chúng
#
# 673
# 00:33:55,850 --> 00:33:56,430
# phải nấu cái đó. Nó không phải
#
# 674
# 00:33:56,450 --> 00:33:56,591
# như vậy.
#
# 675
# 00:34:21,982 --> 00:34:22,581
# Đó là một sự chạch hướng trong
#
# 676
# 00:34:22,601 --> 00:34:23,181
# sự tập của vị trí khổ. Nó phải
#
# 677
# 00:34:23,202 --> 00:34:23,842
# là ưu tiên cái đại chúng hơn các
#
# 678
# 00:34:23,862 --> 00:34:24,443
# cậu chính mình. Chứ không phải
#
# 679
# 00:34:24,463 --> 00:34:25,043
# mình có quyền tự do tiêu tiền
#
# 680
# 00:34:25,063 --> 00:34:25,583
# phía nào. Thì thấy không? Nó
#
# 681
# 00:34:25,603 --> 00:34:26,183
# không phải như thế. Có một lần,
#
# 682
# 00:34:26,203 --> 00:34:26,822
# có một vị trí khổ khoe với xông
#
# 683
# 00:34:26,842 --> 00:34:27,402
# là đi chợ mấy năm rồi mà giữ
#
# 684
# 00:34:27,422 --> 00:34:27,862
# được tiền rất là nhiều.
#
# 685
# 00:34:52,777 --> 00:34:53,277
# xong mới siền trách bị đó.
#
# 686
# 00:34:53,297 --> 00:34:53,859
# Như vậy là không có đúng đâu
#
# 687
# 00:34:53,879 --> 00:34:54,438
# cậu. Nếu có giữ tiền thì phải
#
# 688
# 00:34:54,458 --> 00:34:55,079
# mua được thực ăn chất lượng tốt
#
# 689
# 00:34:55,099 --> 00:34:55,739
# hơn cho đại chúng chứ không phải
#
# 690
# 00:34:55,760 --> 00:34:56,199
# là giữ tiền là một cái
#
# 691
# 00:34:56,219 --> 00:34:56,800
# thành quả. Giữ tiền đi chợ, giữ
#
# 692
# 00:34:56,820 --> 00:34:57,441
# tiền thì rồi trí khấu được khen
#
# 693
# 00:34:57,461 --> 00:34:58,101
# nhưng mà rồi chúng thì phải chịu
#
# 694
# 00:34:58,121 --> 00:34:58,641
# được cái thiệt thòi lớn đó.
#
# 695
# 00:34:58,661 --> 00:34:59,262
# Bài học đó phải có nhớ đến tận
#
# 696
# 00:34:59,282 --> 00:34:59,762
# bây giờ. Nó không phải là
#
# 697
# 00:34:59,782 --> 00:35:00,402
# trường hợp của mình nhưng nó là
#
# 698
# 00:35:00,422 --> 00:35:01,003
# một bài học của mình. Phải đặt
#
# 699
# 00:35:01,023 --> 00:35:01,563
# quyền lợi của đại chúng lên
#
# 700
# 00:35:01,583 --> 00:35:01,663
# trên.
#
# 701
# 00:35:24,773 --> 00:35:25,293
# Tất nhiên nó sẽ không được
#
# 702
# 00:35:25,313 --> 00:35:25,914
# hoàn hảo. Tại vì giống như Pháp
#
# 703
# 00:35:25,934 --> 00:35:26,414
# Bộ nói trước đó, có người
#
# 704
# 00:35:26,434 --> 00:35:26,994
# quan điệp như thế này mới là
#
# 705
# 00:35:27,014 --> 00:35:27,635
# tốt. Có người quan điệp trên kia
#
# 706
# 00:35:27,655 --> 00:35:28,255
# mới là tốt. Và nó thể tập trung
#
# 707
# 00:35:28,275 --> 00:35:28,836
# hết vào trong. Và bên cạnh đó
#
# 708
# 00:35:28,856 --> 00:35:29,316
# mình cũng còn phải chịu
#
# 709
# 00:35:29,336 --> 00:35:29,896
# trách nhiệm với người đi chợ
#
# 710
# 00:35:29,916 --> 00:35:30,457
# chung với mình. Tại vì trong
#
# 711
# 00:35:30,477 --> 00:35:31,057
# thực tập của đại chúng, đi chợ
#
# 712
# 00:35:31,077 --> 00:35:31,637
# hay đi ra ngoài là có second
#
# 713
# 00:35:31,658 --> 00:35:32,278
# body. Cái thân thứ hai để bảo hộ
#
# 714
# 00:35:32,298 --> 00:35:32,798
# cái sự tập của chính mình.
#
# 715
# 00:35:54,963 --> 00:35:55,543
# để cho mình không có thả lỏng
#
# 716
# 00:35:55,564 --> 00:35:56,204
# những tập khí của mình trong khi
#
# 717
# 00:35:56,224 --> 00:35:56,805
# đi ra ngoài ở trong chúng đây
#
# 718
# 00:35:56,825 --> 00:35:57,365
# chúng ta được bảo hộ rất là
#
# 719
# 00:35:57,385 --> 00:35:58,006
# tuyệt vời nhưng khi đi ra ngoài
#
# 720
# 00:35:58,026 --> 00:35:58,586
# thì môi trường bảo hộ cho sự
#
# 721
# 00:35:58,606 --> 00:35:59,167
# ngập nó ít hơn nó không được
#
# 722
# 00:35:59,187 --> 00:35:59,787
# toàn tuyệt vời như khi ở trong
#
# 723
# 00:35:59,807 --> 00:36:24,240
# chúng thì khi đi chợ không
#
# 724
# 00:36:24,260 --> 00:36:24,880
# kiểm soát được cái tâm thức của
#
# 725
# 00:36:24,900 --> 00:36:25,500
# mình thì đôi khi mình đánh mất
#
# 726
# 00:36:25,520 --> 00:36:26,161
# chính mình trong đó đôi khi mình
#
# 727
# 00:36:26,181 --> 00:36:26,801
# thích nói chuyện với cái cô bán
#
# 728
# 00:36:26,821 --> 00:36:27,461
# hàng kia nhiều hơn trong một dãy
#
# 729
# 00:36:27,481 --> 00:36:28,101
# xếp hàng đó đôi khi mình cứ chỉ
#
# 730
# 00:36:28,121 --> 00:36:28,741
# muốn đẩy xe sang cái chỗ đó cái
#
# 731
# 00:36:28,761 --> 00:36:29,301
# tâm thức mình nó lại nằm đó
#
# 732
# 00:36:29,321 --> 00:36:54,838
# như vậy thôi À
#
# 733
# 00:36:54,858 --> 00:36:55,398
# thì nếu như mình không được
#
# 734
# 00:36:55,418 --> 00:36:56,018
# trách nhiệm bảo họ thì mình dễ
#
# 735
# 00:36:56,038 --> 00:36:56,619
# sợ lắm Tại người bán hàng thì
#
# 736
# 00:36:56,639 --> 00:36:57,199
# nhiệm vụ của họ lúc nào cũng
#
# 737
# 00:36:57,219 --> 00:36:57,839
# phải tươi cười với mình Cho nên
#
# 738
# 00:36:57,859 --> 00:36:58,439
# mình dễ dàng cảm thấy dễ chịu,
#
# 739
# 00:36:58,459 --> 00:36:59,059
# dễ dàng bắt chuyện mà họ không
#
# 740
# 00:36:59,079 --> 00:36:59,439
# từ chối được À thì...
#
# 741
# 00:37:23,573 --> 00:37:24,193
# thì những tâm thức ấy nó sẽ lôi
#
# 742
# 00:37:24,213 --> 00:37:24,793
# mình đi Đôi khi mình mua hàng
#
# 743
# 00:37:24,813 --> 00:37:25,434
# chỉ để vừa ý cái người bán hàng
#
# 744
# 00:37:25,454 --> 00:37:26,074
# chẳng hạn Thế thì không phải là
#
# 745
# 00:37:26,094 --> 00:37:26,714
# sự cực tập của một người có vào
#
# 746
# 00:37:26,734 --> 00:37:27,354
# trong chúng Thì nếu như ta nhận
#
# 747
# 00:37:27,374 --> 00:37:28,015
# được những tâm thức đó trong khi
#
# 748
# 00:37:28,035 --> 00:37:52,695
# đi chợ phải
#
# ...
# nhỏ thì vẫn phải nổ thế nhưng
#
# 959
# 00:46:55,546 --> 00:46:56,167
# cũng phải có cái năng lượng của
#
# 960
# 00:46:56,187 --> 00:46:56,787
# sự tôn trọng đất đai của những
#
# 961
# 00:46:56,807 --> 00:47:16,823
# sinh vật sống của
#
# 962
# 00:47:16,843 --> 00:47:17,463
# những mạng sống nó đã cống hiến
#
# 963
# 00:47:17,483 --> 00:47:18,104
# cái năng lượng cho mảnh đất này,
#
# 964
# 00:47:18,124 --> 00:47:18,744
# nó cũng đã là một cái hình thức
#
# 965
# 00:47:18,764 --> 00:47:19,344
# của tổ tiên đất đai ở đây. Thì
#
# 966
# 00:47:19,364 --> 00:47:19,885
# mình cũng vậy, mình cũng sẽ
#
# 967
# 00:47:19,905 --> 00:47:20,485
# trở thành một phần của cái sự
#
# 968
# 00:47:20,505 --> 00:47:21,125
# sống trong cái dòng chảy lớn đó.
#
# 969
# 00:47:21,145 --> 00:47:21,726
# Mình vẫn được phép, được quyền
#
# 970
# 00:47:21,746 --> 00:47:22,326
# lấy những cái gì để nuôi được
#
# 971
# 00:47:22,346 --> 00:47:22,946
# mình, nhưng đồng thời cũng phải
#
# 972
# 00:47:22,966 --> 00:47:23,527
# tôn trọng những cái gì để nó
#
# 973
# 00:47:23,547 --> 00:47:46,341
# được tiếp tục, nó để được được
#
# 974
# 00:47:46,361 --> 00:47:46,921
# tiếp tục tốt nhất cho thế hệ
#
# 975
# 00:47:46,941 --> 00:47:47,542
# sau, cho chính mình. Mỗi cây rau
#
# 976
# 00:47:47,562 --> 00:47:48,122
# hay mỗi sản phẩm tạo ra mình
#
# 977
# 00:47:48,142 --> 00:47:48,702
# không phải chỉ coi đó là của
#
# 978
# 00:47:48,722 --> 00:47:49,343
# mình mà mình phải coi nó là của
#
# 979
# 00:47:49,363 --> 00:47:49,923
# đất trời và của tạc phẩm của
#
# 980
# 00:47:49,943 --> 00:47:50,563
# Tổ tiên, của đất ai và của những
#
# 981
# 00:47:50,583 --> 00:47:51,204
# năng lượng của những người khác
#
# 982
# 00:47:51,224 --> 00:47:51,764
# đóng góp vào đó để xây dựng.
#
# 983
# 00:47:51,784 --> 00:47:52,304
# Tất nhiên nó sẽ vất vả hơn
#
# 984
# 00:47:52,324 --> 00:47:52,965
# bởi vì đây là cái vùng đất mà nó
#
# 985
# 00:47:52,985 --> 00:47:53,505
# ra mạng, nó không thuận lợi
#
# 986
# 00:47:53,525 --> 00:47:54,085
# nhiều cho việc trồng rau. Thế
#
# 987
# 00:47:54,105 --> 00:48:16,831
# cho nên Khi
#
# 988
# 00:48:16,851 --> 00:48:17,391
# mà các thầy, các nạn đi theo
#
# 989
# 00:48:17,411 --> 00:48:18,032
# được nó thì cũng ý thức rằng nó
#
# 990
# 00:48:18,052 --> 00:48:18,652
# sẽ có nhiều cái sự khó khăn, nó
#
# 991
# 00:48:18,672 --> 00:48:19,233
# có sự trật lòng. Cái hiệu quả
#
# 992
# 00:48:19,253 --> 00:48:19,893
# chồng của nó sẽ không bằng những
#
# 993
# 00:48:19,913 --> 00:48:20,493
# nơi mà thuận tuyệt nghiệm cho
#
# 994
# 00:48:20,513 --> 00:48:21,134
# chồng giao khác. Tuy nhiên không
#
# 995
# 00:48:21,154 --> 00:48:21,734
# phải vì thế mà mình không dám
#
# 996
# 00:48:21,754 --> 00:48:22,374
# ngại. Mình cũng sẽ cùng nhau với
#
# 997
# 00:48:22,394 --> 00:48:22,895
# các vị khác học hỏi những
#
# 998
# 00:48:22,915 --> 00:48:23,455
# kinh nghiệm của những người.
#
# 999
# 00:48:23,475 --> 00:48:24,056
# Hồi nãy đến đây cũng có những
#
# 1000
# 00:48:24,076 --> 00:48:47,675
# cái fan nhỏ họ
#
# 1001
# 00:48:47,695 --> 00:48:48,295
# phải làm sao để bảo vệ đất này
#
# 1002
# 00:48:48,315 --> 00:48:48,896
# mà vẫn có được những sản phẩm
#
# 1003
# 00:48:48,916 --> 00:48:49,456
# tốt nhất, lành mạnh không có
#
# 1004
# 00:48:49,476 --> 00:48:50,056
# sử dụng nhiều chất đặc hòa để
#
# 1005
# 00:48:50,076 --> 00:48:50,597
# cho công nghiệp trong mình.
#
# 1006
# 00:48:50,617 --> 00:48:51,157
# Mình cũng thấy có những cái
#
# 1007
# 00:48:51,177 --> 00:48:51,798
# pharm họ cố gắng hết sức của họ
#
# 1008
# 00:48:51,818 --> 00:48:52,418
# nhưng rồi họ cũng vẫn thất bại.
#
# 1009
# 00:48:52,438 --> 00:48:52,938
# Có những cái pharm rất là
#
# 1010
# 00:48:52,958 --> 00:48:53,539
# thành công. Còn buồn, mình cũng
#
# 1011
# 00:48:53,559 --> 00:48:54,139
# có những lúc mình muốn hỗ trợ
#
# 1012
# 00:48:54,159 --> 00:48:54,779
# cho những cái pharm local ở đây.
#
# 1013
# 00:48:54,799 --> 00:48:55,400
# Nhưng rồi một vài năm sau thấy
#
# 1014
# 00:48:55,420 --> 00:48:56,000
# họ chuyển sang chồng Marizona
#
# 1015
# 00:48:56,020 --> 00:49:19,413
# mất rồi bởi vì
#
# 1016
# 00:49:19,433 --> 00:49:20,034
# lợi lạ của bên đó nó nhiều hơn
#
# 1017
# 00:49:20,054 --> 00:49:20,634
# cũng buồn, không trách được họ
#
# 1018
# 00:49:20,654 --> 00:49:21,094
# bởi vì họ cũng phải có
#
# 1019
# 00:49:21,114 --> 00:49:21,735
# cuộc sống, cũng có gia đình phải
#
# 1020
# 00:49:21,755 --> 00:49:22,295
# nuôi thì nó có cái tức cười
#
# 1021
# 00:49:22,315 --> 00:49:22,936
# như vậy nhưng không phải vì thế
#
# 1022
# 00:49:22,956 --> 00:49:23,536
# mà mình mạng lòng mình vẫn có
#
# 1023
# 00:49:23,556 --> 00:49:24,177
# ca đảm để tiếp tục và mình cũng
#
# 1024
# 00:49:24,197 --> 00:49:24,697
# dấn thân vào để mình hiểu
#
# 1025
# 00:49:47,322 --> 00:49:47,782
# cảm nhận nó có khó khăn
#
# 1026
# 00:49:47,802 --> 00:49:48,382
# như thế nào và mình cũng luôn
#
# 1027
# 00:49:48,402 --> 00:49:48,983
# tin tưởng là mình sẽ có vô số
#
# 1028
# 00:49:49,003 --> 00:49:49,603
# bàn tay để giúp chứ không phải
#
# 1029
# 00:49:49,623 --> 00:49:50,203
# chỉ có từ tay mình không mình
#
# 1030
# 00:49:50,223 --> 00:49:50,843
# cũng chấp nhận là thành công nó
#
# 1031
# 00:49:50,863 --> 00:49:51,484
# sẽ không phải chỉ ở trong riêng
#
# 1032
# 00:49:51,504 --> 00:49:52,124
# tay của mình mà còn ở trong thế
#
# 1033
# 00:49:52,144 --> 00:49:52,744
# của vô số bàn tay vô hình khác
#
# 1034
# 00:49:52,764 --> 00:49:53,404
# của những người hoặc là chỉ giúp
#
# 1035
# 00:49:53,424 --> 00:49:54,024
# một thời gian hoặc là muốn gắn
#
# 1036
# 00:49:54,044 --> 00:49:54,665
# đó hoặc là cũng muốn đến chỉ để
#
# 1037
# 00:49:54,685 --> 00:49:55,285
# học kinh nghiệm làm sao với nó
#
# 1038
# 00:49:55,305 --> 00:49:55,925
# nữa thì mời đại chúng mình sáng
#
# 1039
# 00:49:55,945 --> 00:49:56,565
# năm sẽ có thêm một cái danh mục
#
# 1040
# 00:49:56,585 --> 00:50:14,548
# để thực tập để
#
# 1041
# 00:50:14,568 --> 00:50:15,188
# mà học hỏi, để mà khẳng định với
#
# 1042
# 00:50:15,208 --> 00:50:15,849
# con cháu của mình mình cũng đang
#
# 1043
# 00:50:15,869 --> 00:50:16,469
# tham dự vào cái việc nuôi lượn
#
# 1044
# 00:50:16,489 --> 00:50:17,049
# nó bằng cái thân thể lớn chứ
#
# 1045
# 00:50:17,069 --> 00:50:17,690
# không phải chỉ bằng cái thức ăn
#
# 1046
# 00:50:17,710 --> 00:50:18,270
# trên bàn không phải chỉ bằng
#
# 1047
# 00:50:18,290 --> 00:50:18,910
# những cái mình mua mà chợ về nó
#
# 1048
# 00:50:18,930 --> 00:50:19,510
# còn bằng những cái năng lượng,
#
# 1049
# 00:50:19,531 --> 00:50:20,151
# bằng cái tâm thức bằng cái niềm
#
# 1050
# 00:50:20,171 --> 00:50:20,631
# tin cái thành quả, dù nó
#
# 1051
# 00:50:20,651 --> 00:50:21,211
# nhỏ nhói hay là lung lao của
#
# 1052
# 00:50:21,231 --> 00:50:21,812
# mình để khi mà mình ngồi trên
#
# 1053
# 00:50:21,832 --> 00:50:46,391
# bàn ăn mà
#
# 1054
# 00:50:46,411 --> 00:50:46,991
# đất mẹ là mình là cái thứ chỉ
#
# 1055
# 00:50:47,011 --> 00:50:47,652
# lấy từ đất mẹ mà không công hiến
#
# 1056
# 00:50:47,672 --> 00:50:48,292
# không, chúng ta công hiến rất là
#
# 1057
# 00:50:48,312 --> 00:50:48,872
# nhiều, chúng ta cũng có những
#
# 1058
# 00:50:48,892 --> 00:50:49,533
# trách nhiệm rất là nhiều và bằng
#
# 1059
# 00:50:49,553 --> 00:50:50,193
# cách đó chúng ta hiện viện không
#
# 1060
# 00:50:50,213 --> 00:50:50,793
# phải chỉ trong chừng 100 năm này
#
# 1061
# 00:50:50,813 --> 00:50:51,354
# không phải chỉ bằng một cái
#
# 1062
# 00:50:51,374 --> 00:50:51,994
# thọ mạng này mà nó còn bằng cái
#
# 1063
# 00:50:52,014 --> 00:50:52,614
# vô hạng này trong đó giống như
#
# 1064
# 00:50:52,634 --> 00:50:53,194
# tổ tiên đất đai của chúng ta
#
# 1065
# 00:50:53,214 --> 00:50:53,835
# như vậy những con người đã từng
#
# 1066
# 00:50:53,855 --> 00:50:54,455
# sống ở đất này họ để lại những
#
# 1067
# 00:50:54,475 --> 00:50:55,095
# dấu vết, để lại những năng lượng
#
# 1068
# 00:51:17,047 --> 00:51:17,647
# nhìn thấy nó trong nụ cười của
#
# 1069
# 00:51:17,667 --> 00:51:18,207
# người bạn đồng tú của những
#
# 1070
# 00:51:18,227 --> 00:51:18,788
# người đến đây có gặp ánh mắt
#
# 1071
# 00:51:18,808 --> 00:51:19,348
# tin tưởng sự trợ giúp và sự
#
# 1072
# 00:51:19,368 --> 00:51:19,808
# đồng cảm của họ cái sự
#
# 1073
# 00:51:19,828 --> 00:51:20,388
# chấp nhận lời giải thích của
#
# 1074
# 00:51:20,408 --> 00:51:21,028
# mình về những cái việc mình làm
#
# 1075
# 00:51:21,048 --> 00:51:21,648
# nó cũng là một loại thành công
#
# 1076
# 00:51:21,668 --> 00:51:22,229
# không nhất thiết là phải đạt
#
# 1077
# 00:51:22,249 --> 00:51:22,889
# được hết những cái tiêu chuẩn mà
#
# 1078
# 00:51:22,909 --> 00:51:23,509
# chúng ta muốn không nhất thiết
#
# 1079
# 00:51:23,529 --> 00:51:24,069
# phải đạt được hết những cái
#
# 1080
# 00:51:24,089 --> 00:51:24,729
# tiêu chuẩn mà người đó mong muốn
#
# 1081
# 00:51:24,749 --> 00:51:47,698
# nhưng đại thể nó đều là và
#
# 1082
# 00:51:47,718 --> 00:51:48,318
# chúng ta sẽ thấy cái hạnh phúc
#
# 1083
# 00:51:48,338 --> 00:51:48,978
# nó không phải chỉ là thức ăn đưa
#
# 1084
# 00:51:48,998 --> 00:51:49,578
# vào trong cơ thể mình đôi khi
#
# 1085
# 00:51:49,598 --> 00:51:50,179
# nhìn sang cái đĩa thức ăn của
#
# 1086
# 00:51:50,199 --> 00:51:50,759
# một bạn đồng tu thấy họ chọn
#
# 1087
# 00:51:50,779 --> 00:51:51,379
# được cái món ăn nó ngon quá mà
#
# 1088
# 00:51:51,399 --> 00:51:52,039
# mình có trí giác là món đó không
#
# 1089
# 00:51:52,059 --> 00:51:52,599
# ngon họ đổi gặp lại một cái...
#
# 1090
# 00:51:52,619 --> 00:51:53,259
# cái sự thân tình cái sự đồng cảm
#
# 1091
# 00:51:53,279 --> 00:51:53,899
# trong đó nó xuất hiện vào trong
#
# 1092
# 00:51:53,919 --> 00:51:54,379
# đó nó không phải chỉ là...
#
# 1093
# 00:51:54,399 --> 00:51:54,999
# cứng nhắc ở trong này ngày xưa
#
# 1094
# 00:51:55,019 --> 00:51:55,180
# khi mà ở...
#
# 1095
# 00:52:17,611 --> 00:52:18,231
# Tất nước châu Á, các ông thầy Tu
#
# 1096
# 00:52:18,251 --> 00:52:18,892
# có cái luật là chỉ được nhìn vào
#
# 1097
# 00:52:18,912 --> 00:52:19,532
# đĩa thức ăn của mình, không được
#
# 1098
# 00:52:19,552 --> 00:52:20,072
# nhìn sang cái đĩa bên cạnh.
#
# 1099
# 00:52:20,092 --> 00:52:20,552
# Bởi vì ngày xưa thức ăn
#
# 1100
# 00:52:20,572 --> 00:52:21,173
# thiếu thốn, trong chùa lại càng
#
# 1101
# 00:52:21,193 --> 00:52:21,793
# thiếu nữa. Thế một người nào đó
#
# 1102
# 00:52:21,813 --> 00:52:22,353
# mà múc thức ăn có loại ngon
#
# 1103
# 00:52:22,373 --> 00:52:22,933
# nhiều hơn đĩa của mình, nó sẽ
#
# 1104
# 00:52:22,953 --> 00:52:23,514
# sinh cái tâm không tốt. Nhưng
#
# 1105
# 00:52:23,534 --> 00:52:24,154
# giờ đây chúng ta không có thiếu
#
# 1106
# 00:52:24,174 --> 00:52:24,674
# thức ăn. Nó không nất viên.
#
# 1107
# 00:52:24,694 --> 00:52:25,295
# Thưa bộ, khuyến khích mình nhìn
#
# 1108
# 00:52:25,315 --> 00:52:25,895
# thấy cái niềm vui của mấy bạn
#
# 1109
# 00:52:25,915 --> 00:52:48,485
# đầu Tu khi ăn thì
#
# 1110
# 00:52:48,505 --> 00:52:48,985
# có những cái chúng ta sẽ
#
# 1111
# 00:52:49,005 --> 00:52:49,546
# tôn trọng, có những cái được
#
# 1112
# 00:52:49,566 --> 00:52:50,146
# tiêu chuẩn từ ngày xưa đặt ra
#
# 1113
# 00:52:50,166 --> 00:52:50,647
# chúng ta tôn trọng nhưng
#
# 1114
# 00:52:50,667 --> 00:52:51,307
# chúng ta sẽ thực hiện nó ở trong
#
# 1115
# 00:52:51,327 --> 00:52:51,887
# cái hoàn cảnh, trong cái cách
#
# 1116
# 00:52:51,907 --> 00:52:52,508
# thích hợp nhất mà ngày hôm nay.
#
# 1117
# 00:52:52,528 --> 00:52:53,108
# Giờ đây chúng ta sẽ cùng nhau
#
# 1118
# 00:52:53,128 --> 00:52:53,749
# trợ giúp trong mong rằng quý vị
#
# 1119
# 00:52:53,769 --> 00:52:54,409
# sẽ chấp nhận và nhìn xem rằng là
#
# 1120
# 00:52:54,429 --> 00:52:55,010
# cái Happy Farm nó sẽ được lớn
#
# 1121
# 00:52:55,030 --> 00:52:55,610
# lên từ như thế nào? Từ một cái
#
# 1122
# 00:52:55,630 --> 00:52:56,230
# mảnh đất hoang dã nó sẽ chuyển
#
# 1123
# 00:52:56,250 --> 00:53:17,685
# thành những
#
# 1124
# 00:53:17,705 --> 00:53:18,265
# cái gì mà đem lại, có thể đến
#
# 1125
# 00:53:18,285 --> 00:53:18,905
# không cần phải làm gì cả ngồi ở
#
# 1126
# 00:53:18,925 --> 00:53:19,445
# đó trong vườn rau, nhìn cái
#
# 1127
# 00:53:19,465 --> 00:53:20,066
# năng lượng của cây rau lớn lên
#
# 1128
# 00:53:20,086 --> 00:53:20,726
# nó cũng là nước hạnh phúc rất là
#
# 1129
# 00:53:20,746 --> 00:53:21,186
# nhiều. Sơm nói, cái nghề
#
# 1130
# 00:53:21,206 --> 00:53:21,846
# làm vườn là một trong những nghề
#
# 1131
# 00:53:21,866 --> 00:53:22,446
# rất là thanh tịnh Sơm nói, nếu
#
# 1132
# 00:53:22,466 --> 00:53:22,986
# mà không bận rộn là Sơm sẽ
#
# 1133
# 00:53:23,006 --> 00:53:23,546
# làm vườn. Sơm nói, trong sách
#
# 1134
# 00:53:23,566 --> 00:53:46,059
# của Sơm thấy, Sơm cũng thấy có
#
# 1135
# 00:53:46,079 --> 00:53:46,679
# rất nhiều hương thú với chuyện
#
# 1136
# 00:53:46,699 --> 00:53:47,240
# làm vườn, với cây côi, chuyện
#
# 1137
# 00:53:47,260 --> 00:53:47,840
# đối giới. Quan sát một cái cây
#
# 1138
# 00:53:47,860 --> 00:53:48,380
# nó từ bệnh, từ bị bệnh, được
#
# 1139
# 00:53:48,400 --> 00:53:48,960
# chữa rồi nó lành mạnh, nên nó
#
# 1140
# 00:53:48,980 --> 00:53:49,520
# công hiến như thế nào? Nó là
#
# 1141
# 00:53:49,540 --> 00:53:50,081
# những cái năng lượng rất là
#
# 1142
# 00:53:50,101 --> 00:53:50,641
# lành mạnh thực hiện. Có nước,
#
# 1143
# 00:53:50,661 --> 00:53:51,261
# có cây xanh, có lá, có những con
#
# 1144
# 00:53:51,281 --> 00:53:51,861
# côn trùng ở trong đó. Có những
#
# 1145
# 00:53:51,881 --> 00:53:52,482
# cái sự sống, nó trôi chảy trong
#
# 1146
# 00:53:52,502 --> 00:54:16,066
# đó và nó đóng góp Mời
#
# 1147
# 00:54:16,086 --> 00:54:16,726
# quý vị đến cùng nhau thưởng thức
#
# 1148
# 00:54:16,746 --> 00:54:17,367
# và có thể bây giờ nó chưa thành
#
# 1149
# 00:54:17,387 --> 00:54:17,947
# hành hình cụ thể như thế nào
#
# 1150
# 00:54:17,967 --> 00:54:18,548
# bởi vì các thầy cũng còn đang
#
# 1151
# 00:54:18,568 --> 00:54:19,148
# phải học phải làm như thế nào
#
# 1152
# 00:54:19,168 --> 00:54:19,768
# mới tốt sẽ có những cái bấp và
#
# 1153
# 00:54:19,788 --> 00:54:20,389
# có những cái mình làm lên xong
#
# 1154
# 00:54:20,409 --> 00:54:21,009
# rồi lại phải phá đi để làm cái
#
# 1155
# 00:54:21,029 --> 00:54:21,670
# khác cho nó đúng hơn nhưng mà nó
#
# 1156
# 00:54:21,690 --> 00:54:22,330
# sẽ có thành quả nó sẽ là một cái
#
# 1157
# 00:54:22,350 --> 00:54:22,911
# minh chứng cho chúng ta đang
#
# 1158
# 00:54:22,931 --> 00:54:23,571
# trên con đường trở thành tổ tiên
#
# 1159
# 00:54:23,591 --> 00:54:24,071
# của đất đại này chúng ta
#
# 1160
# 00:54:24,091 --> 00:54:24,672
# tiếp nối nó và quý vị sẽ được
#
# 1161
# 00:54:24,692 --> 00:54:45,886
# con cháu tôn trọng
#
# 1162
# 00:54:45,906 --> 00:54:46,486
# ở trên con đường này. Nó không
#
# 1163
# 00:54:46,506 --> 00:54:47,087
# phải chỉ ở trong lúc thực tập
#
# 1164
# 00:54:47,107 --> 00:54:47,627
# mồi thiền, không phải chỉ ở
#
# 1165
# 00:54:47,647 --> 00:54:48,187
# trong lúc điên hình này hay
#
# 1166
# 00:54:48,207 --> 00:54:48,808
# không, trong lúc ăn cơm hay nói
#
# 1167
# 00:54:48,828 --> 00:54:49,388
# văn thoại. Mà nó còn là trong
#
# 1168
# 00:54:49,408 --> 00:54:49,968
# những sự đóng góp rất là nhỏ
#
# 1169
# 00:54:49,988 --> 00:54:50,549
# ngói, rất là bình dị đó. Trong
#
# 1170
# 00:54:50,569 --> 00:54:50,969
# lúc nấu ăn, trong lúc
#
# 1171
# 00:54:50,989 --> 00:54:51,569
# thưởng thức thức ăn, trong lúc
#
# 1172
# 00:54:51,589 --> 00:54:52,210
# đi chợ hay trong lúc đóng góp ở
#
# 1173
# 00:54:52,230 --> 00:54:52,810
# đây. Mời quý vị mình cùng nhau
#
# 1174
# 00:54:52,830 --> 00:54:53,410
# nuôi dưỡng cái tâm thức đó để
#
# 1175
# 00:54:53,430 --> 00:55:16,411
# chia sẻ với cho
#
# 1176
# 00:55:16,431 --> 00:55:17,032
# con mình, cho con cháu của mình,
#
# 1177
# 00:55:17,052 --> 00:55:17,672
# cho những người thương của mình
#
# 1178
# 00:55:17,692 --> 00:55:18,252
# chúng ta không ngại khó khăn,
#
# 1179
# 00:55:18,272 --> 00:55:18,853
# không sợ thất bại và đón nhận
#
# 1180
# 00:55:18,873 --> 00:55:19,493
# những thành công không phải chỉ
#
# 1181
# 00:55:19,513 --> 00:55:20,094
# của riêng mình đón nhận những
#
# 1182
# 00:55:20,114 --> 00:55:20,674
# lời khen không phải từ chính
#
# 1183
# 00:55:20,694 --> 00:55:21,335
# mình mà của những người khác nữa
#
# 1184
# 00:55:21,355 --> 00:55:21,895
# và chấp nhận rằng nhìn nhận
#
# 1185
# 00:55:21,915 --> 00:55:22,516
# thành công nó là của chúng chứ
#
# 1186
# 00:55:22,536 --> 00:55:23,096
# không phải là của riêng mình
#
# 1187
# 00:55:23,116 --> 00:55:23,616
# đặc biệt là cái thời điểm
#
# 1188
# 00:55:23,636 --> 00:55:24,217
# khó khăn này khi mà kí hậu nó
#
# 1189
# 00:55:24,237 --> 00:55:42,819
# trở nên khó đoán hơn chúng ta
#
# 1190
# 00:55:42,839 --> 00:55:43,460
# biết rằng đó là một trong những
#
# 1191
# 00:55:43,480 --> 00:55:44,040
# đối tượng của chúng ta trong
#
# 1192
# 00:55:44,060 --> 00:55:44,581
# nhiều thế hệ nhưng bây giờ
#
# 1193
# 00:55:44,601 --> 00:55:45,101
# chúng ta hoàn toàn có thể
#
# 1194
# 00:55:45,121 --> 00:55:45,702
# tiếp tục để sửa chữa hoặc kéo
#
# 1195
# 00:55:45,722 --> 00:55:46,302
# chậm lại cái quá trình đó thì
#
# 1196
# 00:55:46,322 --> 00:55:46,923
# mời đại chúng mình bứng tin và
#
# 1197
# 00:55:46,943 --> 00:55:47,563
# chia sẻ với nhau cái năng lượng
#
# 1198
# 00:55:47,583 --> 00:55:48,124
# tốt này, cái tâm thức này để
#
# 1199
# 00:55:48,144 --> 00:55:48,744
# mình luôn luôn có tương lai để
#
# 1200
# 00:55:48,764 --> 00:55:49,405
# mình luôn luôn có cái môi trường
#
# 1201
# 00:55:49,425 --> 00:55:49,865
# tốt đẹp của sự thu học
#
# 1202
# 00:55:49,886 --> 00:55:50,466
# môi trường ở trong và ở ngoài

# %%
from tnh_scholar.utils.file_utils import write_str_to_file

# %%
sent = transcript.get_sentences()

# %%
sent[-1]
# Out:
# Sentence(text='Mời quý vị mình cùng nhau nuôi dưỡng cái tâm thức đó để chia sẻ với cho con mình, cho con cháu của mình, cho những người thương của mình chúng ta không ngại khó khăn, không sợ thất bại và đón nhận những thành công không phải chỉ của riêng mình đón nhận những lời khen không phải từ chính mình mà của những người khác nữa và chấp nhận rằng nhìn nhận thành công nó là của chúng chứ không phải là của riêng mình đặc biệt là cái thời điểm khó khăn này khi mà kí hậu nó trở nên khó đoán hơn chúng ta biết rằng đó là một trong những đối tượng của chúng ta trong nhiều thế hệ nhưng bây giờ chúng ta hoàn toàn có thể tiếp tục để sửa chữa hoặc kéo chậm lại cái quá trình đó thì mời đại chúng mình bứng tin và chia sẻ với nhau cái năng lượng tốt này, cái tâm thức này để mình luôn luôn có tương lai để mình luôn luôn có cái môi trường tốt đẹp của sự thu học môi trường ở trong và ở ngoài', start=3292310, end=3350466, confidence=0.011, speaker=None, channel=None, words=[Word(text='Mời', start=3292310, end=3292370, confidence=0.011, speaker=None, channel=None), Word(text='quý vị', start=3292390, end=3292510, confidence=0.0115, speaker=None, channel=None), Word(text='mình', start=3292530, end=3292610, confidence=0.011, speaker=None, channel=None), Word(text='cùng', start=3292630, end=3292710, confidence=0.01, speaker=None, channel=None), Word(text='nhau', start=3292730, end=3292810, confidence=0.01, speaker=None, channel=None), Word(text='nuôi dưỡng', start=3292830, end=3293030, confidence=0.01, speaker=None, channel=None), Word(text='cái', start=3293050, end=3293110, confidence=0.011, speaker=None, channel=None), Word(text='tâm thức', start=3293130, end=3293290, confidence=0.01, speaker=None, channel=None), Word(text='đó', start=3293310, end=3293350, confidence=0.012, speaker=None, channel=None), Word(text='để', start=3293370, end=3293410, confidence=0.01, speaker=None, channel=None), Word(text='chia sẻ', start=3293430, end=3293570, confidence=0.01, speaker=None, channel=None), Word(text='với', start=3293590, end=3293650, confidence=0.01, speaker=None, channel=None), Word(text='cho', start=3316351, end=3316411, confidence=0.011, speaker=None, channel=None), Word(text='con', start=3316431, end=3316491, confidence=0.012, speaker=None, channel=None), Word(text='mình,', start=3316511, end=3316591, confidence=0.011, speaker=None, channel=None), Word(text='cho', start=3316611, end=3316671, confidence=0.011, speaker=None, channel=None), Word(text='con cháu', start=3316691, end=3316851, confidence=0.01, speaker=None, channel=None), Word(text='của', start=3316871, end=3316931, confidence=0.011, speaker=None, channel=None), Word(text='mình,', start=3316951, end=3317032, confidence=0.01, speaker=None, channel=None), Word(text='cho', start=3317052, end=3317112, confidence=0.011, speaker=None, channel=None), Word(text='những', start=3317132, end=3317232, confidence=0.01, speaker=None, channel=None), Word(text='người thương', start=3317252, end=3317492, confidence=0.01, speaker=None, channel=None), Word(text='của', start=3317512, end=3317572, confidence=0.012, speaker=None, channel=None), Word(text='mình', start=3317592, end=3317672, confidence=0.011, speaker=None, channel=None), Word(text='chúng ta', start=3317692, end=3317852, confidence=0.01, speaker=None, channel=None), Word(text='không', start=3317872, end=3317972, confidence=0.011, speaker=None, channel=None), Word(text='ngại', start=3317992, end=3318072, confidence=0.01, speaker=None, channel=None), Word(text='khó khăn,', start=3318092, end=3318252, confidence=0.01, speaker=None, channel=None), Word(text='không', start=3318272, end=3318372, confidence=0.01, speaker=None, channel=None), Word(text='sợ', start=3318393, end=3318433, confidence=0.012, speaker=None, channel=None), Word(text='thất bại', start=3318453, end=3318613, confidence=0.01, speaker=None, channel=None), Word(text='và', start=3318633, end=3318673, confidence=0.01, speaker=None, channel=None), Word(text='đón nhận', start=3318693, ...

# %%
out_path = Path("dharma_talk_br_phap_hoi.srt")
write_str_to_file(out_path, srt_out, overwrite=True)

# %%
# Test SRT generation with Whisper
whisper_srt = test_format_generation(audio_file, provider="whisper", format_type="srt")

# Test VTT generation with Whisper
whisper_vtt = test_format_generation(audio_file, provider="whisper", format_type="vtt")

# %%
# Test SRT generation with AssemblyAI
assemblyai_srt = test_format_generation(audio_file, provider="assemblyai", format_type="srt")

# Test VTT generation with AssemblyAI
assemblyai_vtt = test_format_generation(audio_file, provider="assemblyai", format_type="vtt")

# %%
def compare_transcriptions(whisper_result, assemblyai_result):
    """Compare transcriptions from both services"""
    print("Comparing transcription results:")
    print("-" * 80)
    
    # Compare text length
    whisper_len = len(whisper_result["text"])
    assemblyai_len = len(assemblyai_result["text"])
    
    print(f"Whisper text length: {whisper_len} characters")
    print(f"AssemblyAI text length: {assemblyai_len} characters")
    
    # Compare word count
    whisper_words = len(whisper_result["text"].split())
    assemblyai_words = len(assemblyai_result["text"].split())
    
    print(f"Whisper word count: {whisper_words} words")
    print(f"AssemblyAI word count: {assemblyai_words} words")
    
    # Compare first 200 characters
    print("\nWhisper first 200 chars:")
    print(whisper_result["text"][:200])
    
    print("\nAssemblyAI first 200 chars:")
    print(assemblyai_result["text"][:200])
    
    # Show unique capabilities
    print("\nUnique capabilities:")
    print(f"Whisper provides word-level timing: {len(whisper_result.get('words', [])) > 0}")
    print(f"AssemblyAI provides speaker diarization: {len(assemblyai_result.get('utterances', [])) > 0}")

# Compare the results
compare_transcriptions(whisper_result, assemblyai_result)
