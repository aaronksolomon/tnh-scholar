# %%
# %load_ext autoreload
# %autoreload 2

# %%
from dotenv import load_dotenv

# Load project .env from repo root (adjust as needed)
load_dotenv()
# Out:
# True

# %%
from tnh_scholar.gen_ai_service.models.domain import RenderRequest
from tnh_scholar.gen_ai_service.service import GenAIService

# %%
service = GenAIService()

# %%
shell_result_test_str = """
(tnh-scholar) phapman@Aarons-Macbook tnh-scholar % pip install -e .
Obtaining file:///Users/phapman/Desktop/Projects/tnh-scholar
  Installing build dependencies ... done
  Checking if build backend supports build_editable ... done
  Getting requirements to build editable ... done
  Preparing editable metadata (pyproject.toml) ... done
Requirement already satisfied: click==8.1.8 in /Users/phapman/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages (from tnh-scholar==0.1.3) (8.1.8)
Requirement already satisfied: colorlog==6.9.0 in /Users/phapman/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages (from tnh-scholar==0.1.3) (6.9.0)
Requirement already satisfied: Flask==3.1.0 in /Users/phapman/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages (from tnh-scholar==0.1.3) (3.1.0)
Requirement already satisfied: GitPython==3.1.44 in /Users/phapman/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages (from tnh-scholar==0.1.3) (3.1.44)
Requirement already satisfied: Jinja2==3.1.5 in /Users/phapman/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages (from tnh-scholar==0.1.3) (3.1.5)
Requirement already satisfied: langdetect==1.0.9 in /Users/phapman/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages (from tnh-scholar==0.1.3) (1.0.9)
Requirement already satisfied: lxml==5.3.0 in /Users/phapman/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages (from tnh-scholar==0.1.3) (5.3.0)
Requirement already satisfied: numpy==2.0.2 in /Users/phapman/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages (from tnh-scholar==0.1.3) (2.0.2)
Requirement already satisfied: openai==2.5.0 in /Users/phapman/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages (from tnh-scholar==0.1.3) (2.5.0)
Requirement already satisfied: openai_whisper==20240930 in /Users/phapman/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages (from tnh-scholar==0.1.3) (20240930)
Requirement already satisfied: packaging==24.2 in /Users/phapman/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages (from tnh-scholar==0.1.3) (24.2)
Requirement already satisfied: pycountry==24.6.1 in /Users/phapman/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages (from tnh-scholar==0.1.3) (24.6.1)
Requirement already satisfied: pydantic==2.10.4 in /Users/phapman/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages (from tnh-scholar==0.1.3) (2.10.4)
Requirement already satisfied: pydub==0.25.1 in /Users/phapman/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages (from tnh-scholar==0.1.3) (0.25.1)
Requirement already satisfied: python-dotenv==1.0.1 in /Users/phapman/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages (from tnh-scholar==0.1.3) (1.0.1)
Requirement already satisfied: pyngrok==7.2.3 in /Users/phapman/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages (from tnh-scholar==0.1.3) (7.2.3)
Requirement already satisfied: PyYAML==6.0.2 in /Users/phapman/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages (from tnh-scholar==0.1.3) (6.0.2)
Requirement already satisfied: regex==2024.11.6 in /Users/phapman/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages (from tnh-scholar==0.1.3) (2024.11.6)
Requirement already satisfied: requests==2.32.3 in /Users/phapman/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages (from tnh-scholar==0.1.3) (2.32.3)
Requirement already satisfied: tiktoken==0.8.0 in /Users/phapman/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages (from tnh-scholar==0.1.3) (0.8.0)
Requirement already satisfied: torch==2.5.1 in /Users/phapman/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages (from tnh-scholar==0.1.3) (2.5.1)
Requirement already satisfied: tqdm==4.67.1 in /Users/phapman/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages (from tnh-scholar==0.1.3) (4.67.1)
Requirement already satisfied: transformers==4.48 in /Users/phapman/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages (from tnh-scholar==0.1.3) (4.48.0)
Requirement already satisfied: yt_dlp>=2025.1.15 in /Users/phapman/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages (from tnh-scholar==0.1.3) (2025.6.30)
Requirement already satisfied: nltk==3.9.1 in /Users/phapman/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages (from tnh-scholar==0.1.3) (3.9.1)
Requirement already satisfied: unidecode==1.3.8 in /Users/phapman/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages (from tnh-scholar==0.1.3) (1.3.8)
Requirement already satisfied: Werkzeug>=3.1 in /Users/phapman/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages (from Flask==3.1.0->tnh-scholar==0.1.3) (3.1.3)
Requirement already satisfied: itsdangerous>=2.2 in /Users/phapman/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages (from Flask==3.1.0->tnh-scholar==0.1.3) (2.2.0)
Requirement already satisfied: blinker>=1.9 in /Users/phapman/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages (from Flask==3.1.0->tnh-scholar==0.1.3) (1.9.0)
Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/phapman/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages (from GitPython==3.1.44->tnh-scholar==0.1.3) (4.0.12)
Requirement already satisfied: MarkupSafe>=2.0 in /Users/phapman/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages (from Jinja2==3.1.5->tnh-scholar==0.1.3) (3.0.2)
Requirement already satisfied: six in /Users/phapman/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages (from langdetect==1.0.9->tnh-scholar==0.1.3) (1.17.0)
Requirement already satisfied: joblib in /Users/phapman/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages (from nltk==3.9.1->tnh-scholar==0.1.3) (1.4.2)
Requirement already satisfied: anyio<5,>=3.5.0 in /Users/phapman/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages (from openai==2.5.0->tnh-scholar==0.1.3) (4.8.0)
Requirement already satisfied: distro<2,>=1.7.0 in /Users/phapman/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages (from openai==2.5.0->tnh-scholar==0.1.3) (1.9.0)
Requirement already satisfied: httpx<1,>=0.23.0 in /Users/phapman/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages (from openai==2.5.0->tnh-scholar==0.1.3) (0.28.1)
Requirement already satisfied: jiter<1,>=0.10.0 in /Users/phapman/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages (from openai==2.5.0->tnh-scholar==0.1.3) (0.11.1)
Requirement already satisfied: sniffio in /Users/phapman/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages (from openai==2.5.0->tnh-scholar==0.1.3) (1.3.1)
Requirement already satisfied: typing-extensions<5,>=4.11 in /Users/phapman/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages (from openai==2.5.0->tnh-scholar==0.1.3) (4.12.2)
Requirement already satisfied: annotated-types>=0.6.0 in /Users/phapman/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages (from pydantic==2.10.4->tnh-scholar==0.1.3) (0.7.0)
Requirement already satisfied: pydantic-core==2.27.2 in /Users/phapman/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages (from pydantic==2.10.4->tnh-scholar==0.1.3) (2.27.2)
Requirement already satisfied: numba in /Users/phapman/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages (from openai_whisper==20240930->tnh-scholar==0.1.3) (0.61.0)
Requirement already satisfied: more-itertools in /Users/phapman/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages (from openai_whisper==20240930->tnh-scholar==0.1.3) (10.6.0)
Requirement already satisfied: charset-normalizer<4,>=2 in /Users/phapman/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages (from requests==2.32.3->tnh-scholar==0.1.3) (3.4.1)
Requirement already satisfied: idna<4,>=2.5 in /Users/phapman/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages (from requests==2.32.3->tnh-scholar==0.1.3) (3.10)
Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/phapman/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages (from requests==2.32.3->tnh-scholar==0.1.3) (2.3.0)
Requirement already satisfied: certifi>=2017.4.17 in /Users/phapman/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages (from requests==2.32.3->tnh-scholar==0.1.3) (2024.12.14)
Requirement already satisfied: filelock in /Users/phapman/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages (from torch==2.5.1->tnh-scholar==0.1.3) (3.17.0)
Requirement already satisfied: networkx in /Users/phapman/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages (from torch==2.5.1->tnh-scholar==0.1.3) (3.4.2)
Requirement already satisfied: fsspec in /Users/phapman/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages (from torch==2.5.1->tnh-scholar==0.1.3) (2024.12.0)
Requirement already satisfied: setuptools in /Users/phapman/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages (from torch==2.5.1->tnh-scholar==0.1.3) (75.8.0)
Requirement already satisfied: sympy==1.13.1 in /Users/phapman/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages (from torch==2.5.1->tnh-scholar==0.1.3) (1.13.1)
Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/phapman/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages (from sympy==1.13.1->torch==2.5.1->tnh-scholar==0.1.3) (1.3.0)
Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /Users/phapman/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages (from transformers==4.48->tnh-scholar==0.1.3) (0.27.1)
Requirement already satisfied: tokenizers<0.22,>=0.21 in /Users/phapman/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages (from transformers==4.48->tnh-scholar==0.1.3) (0.21.0)
Requirement already satisfied: safetensors>=0.4.1 in /Users/phapman/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages (from transformers==4.48->tnh-scholar==0.1.3) (0.5.2)
Requirement already satisfied: smmap<6,>=3.0.1 in /Users/phapman/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->GitPython==3.1.44->tnh-scholar==0.1.3) (5.0.2)
Requirement already satisfied: httpcore==1.* in /Users/phapman/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai==2.5.0->tnh-scholar==0.1.3) (1.0.7)
Requirement already satisfied: h11<0.15,>=0.13 in /Users/phapman/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai==2.5.0->tnh-scholar==0.1.3) (0.14.0)
Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /Users/phapman/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages (from numba->openai_whisper==20240930->tnh-scholar==0.1.3) (0.44.0)
Building wheels for collected packages: tnh-scholar
  Building editable for tnh-scholar (pyproject.toml) ... done
  Created wheel for tnh-scholar: filename=tnh_scholar-0.1.3-0.editable-py3-none-any.whl size=28969 sha256=db3f011fb71e54fc0d1031258e73d869e6192fb4abe6c6a8a2c0a3b6e485fbf3
  Stored in directory: /private/var/folders/rn/6vvb1zdx0z59xqgkpcy8_fx00000gq/T/pip-ephem-wheel-cache-08o2fkom/wheels/82/ad/f5/d5ac145ee42dd33d312ea46ca567314afa0ec0b7cf00ad98cd
Successfully built tnh-scholar
Installing collected packages: tnh-scholar
  Attempting uninstall: tnh-scholar
    Found existing installation: tnh-scholar 0.1.3
    Uninstalling tnh-scholar-0.1.3:
      Successfully uninstalled tnh-scholar-0.1.3
Successfully installed tnh-scholar-0.1.3
"""

# %%
request = RenderRequest(
    prompt_key="test",        # you should have a basic pattern named test.*
    intent="general",
    user_prompt=shell_result_test_str,
)

rendered, fp = service.catalog.render(request)

rendered.system, rendered.messages, fp
# Out:
# ('# Test\n\nThis is a test prompt for testing AI service prompt requesting\n\n## Task\n\nSummarize the input (user) into a single coherent sentence.\n\nReturn only the summary sentence, not other commentary, formatting or markings, besides normal punctuation.',
# ...

# %%
from tnh_scholar.gen_ai_service.config.params_policy import apply_policy
from tnh_scholar.gen_ai_service.models.transport import ProviderRequest
from tnh_scholar.gen_ai_service.routing.model_router import select_provider_and_model

base_params = apply_policy(intent=request.intent, call_hint=None)
selection = select_provider_and_model(
    intent=request.intent,
    params=base_params,
    settings=service.settings,
)

provider_request = ProviderRequest(
    provider=selection.provider,
    model=selection.model,
    system=rendered.system,
    messages=rendered.messages,
    temperature=selection.temperature,
    max_output_tokens=selection.max_output_tokens,
    seed=selection.seed,
)

provider_request
# Out:
# ProviderRequest(provider='openai', model='gpt-5o-mini', messages=[Message(role=<Role.user: 'user'>, content='\n(tnh-scholar) phapman@Aarons-Macbook tnh-scholar % pip install -e .\nObtaining file:///Users/phapman/Desktop/Projects/tnh-scholar\n  Installing build dependencies ... done\n  Checking if build backend supports build_editable ... done\n  Getting requirements to build editable ... done\n  Preparing editable metadata (pyproject.toml) ... done\nRequirement already satisfied: click==8.1.8 in /Users/phapman/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages (from tnh-scholar==0.1.3) (8.1.8)\nRequirement already satisfied: colorlog==6.9.0 in /Users/phapman/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages (from tnh-scholar==0.1.3) (6.9.0)\nRequirement already satisfied: Flask==3.1.0 in /Users/phapman/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages (from tnh-scholar==0.1.3) (3.1.0)\nRequirement already satisfied: GitPython==3.1.44 in /Users/phapman/.pyenv/versi
# ...

# %%
full_request = RenderRequest(
    prompt_key="test",
    intent="general",
    user_prompt=shell_result_test_str,
    model="gpt-4o-mini",  # override default
)

response = service.generate(full_request)
response
# Out:
# CompletionEnvelope(result=CompletionResult(text='The user successfully installed the tnh-scholar package version 0.1.3 in editable mode using pip on their MacBook.', usage=Usage(prompt_tokens=4108, completion_tokens=27, total_tokens=4135), model='gpt-4o-mini', provider='openai'), provenance=Provenance(provider='openai', model='gpt-4o-mini', sdk_version='2.5.0', started_at=datetime.datetime(2025, 11, 15, 15, 20, 37, 122793), finished_at=datetime.datetime(2025, 11, 15, 15, 20, 39, 85507), attempt_count=1, fingerprint=Fingerprint(schema_version='fp-1', prompt_key='test', prompt_name='test', prompt_base_path='/Users/phapman/Desktop/Projects/tnh-scholar/patterns', prompt_content_hash='sha256:403ea0f84b441bcebf52a274014f7e69ed0f3a32c6cfbe56a350056833418541', variables_hash='sha256:44136fa355b3678a1146ad16f7e8649e94fb4fc21fe77e8310c060f61caaff8a', user_string_hash='sha256:bec1a3b49e9b9bdc2ff463c6bc5e43eb091f199ca6ade06d67ed2f90a4f550f6')), policy_applied={}, warnings=[])
