# %%
# %load_ext autoreload
# %autoreload 2

# %%
import json
import re
from typing import Any, Dict, Optional, Tuple

import yaml

from tnh_scholar.metadata import Frontmatter, Metadata

# %%
from tnh_scholar.ai_text_processing.text_object import TextObject
# Out:
# ---------------------------------------------------------------------------
# PydanticSchemaGenerationError             Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from tnh_scholar.ai_text_processing.text_object import TextObject
#
# File ~/Desktop/tnh-scholar/src/tnh_scholar/ai_text_processing/__init__.py:1
# ----> 1 from .ai_text_processing import (
#       2     OpenAIProcessor,
#       3     SectionParser,
#       4     SectionProcessor,
#       5     find_sections,
#       6     process_text,
#       7     process_text_by_paragraphs,
#       8     process_text_by_sections,
#       9     punctuate_text,
#      10     translate_text_by_lines,
#      11 )
#      12 from .openai_process_interface import openai_process_text
#      13 from .patterns import (
#      14     GitBackedRepository,
#      15     Pattern,
#      16     PatternManager,
#      17 )
#
# File ~/Desktop/tnh-scholar/src/tnh_scholar/ai_text_processing/ai_text_processing.py:28
#      26 from .openai_process_interface import openai_process_text
#      27 from .patterns import Pattern, PatternManager
# ---> 28 from .text_object import AIResponse, TextObject
#      30 # internal package imports
#      31 from .typing import ProcessorResult
#
# File ~/Desktop/tnh-scholar/src/tnh_scholar/ai_text_processing/text_object.py:98
#      91         return cls(
#      92             title=logical_section.title,
#      93             section_range = SectionRange(logical_section.start_line, end_line),
#      94             metadata = metadata
#      95         )
#      97 # This represents the serializable state of a TextObject
# ---> 98 class TextObjectInfo(BaseModel):
#      99     """Serializable information about a text and its sections."""
#     100     source_file: Optional[Path] = None  # Original text file path
#
# File ~/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages/pydantic/_internal/_model_construction.py:226, in ModelMetaclass.__new__(mcs, cls_name, bases, namespace, __pydantic_generic_metadata__, __pydantic_reset_parent_namespace__, _create_model_module, **kwargs)
#     223 if config_wrapper.frozen and '__hash__' not in namespace:
#     224     set_default_hash_func(cls, bases)
# --> 226 complete_model_class(
#     227     cls,
#     228     cls_name,
#     229     config_wrapper,
#     230     raise_errors=False,
#     231     ns_resolver=ns_resolver,
#     232     create_model_module=_create_model_module,
#     233 )
#     235 # If this is placed before the complete_model_class call above,
#     236 # the generic computed fields return type is set to PydanticUndefined
#     237 cls.__pydantic_computed_fields__ = {
#     238     k: v.info for k, v in cls.__pydantic_decorators__.computed_fields.items()
#     239 }
#
# File ~/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages/pydantic/_internal/_model_construction.py:658, in complete_model_class(cls, cls_name, config_wrapper, raise_errors, ns_resolver, create_model_module)
#     651 handler = CallbackGetCoreSchemaHandler(
#     652     partial(gen_schema.generate_schema, from_dunder_get_core_schema=False),
#     653     gen_schema,
#     654     ref_mode='unpack',
#     655 )
#     657 try:
# --> 658     schema = cls.__get_pydantic_core_schema__(cls, handler)
#     659 except PydanticUndefinedAnnotation as e:
#     660     if raise_errors:
#
# File ~/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages/pydantic/main.py:702, in BaseModel.__get_pydantic_core_schema__(cls, source, handler)
#     699     if not cls.__pydantic_generic_metadata__['origin']:
#     700         return cls.__pydantic_core_schema__
# --> 702 return handler(source)
#
# File ~/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages/pydantic/_internal/_schema_generation_shared.py:84, in CallbackGetCoreSchemaHandler.__call__(self, source_type)
#      83 def __call__(self, source_type: Any, /) -> core_schema.CoreSchema:
# ---> 84     schema = self._handler(source_type)
#      85     ref = schema.get('ref')
#      86     if self._ref_mode == 'to-def':
#
# File ~/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages/pydantic/_internal/_generate_schema.py:610, in GenerateSchema.generate_schema(self, obj, from_dunder_get_core_schema)
#     607         schema = from_property
#     609 if schema is None:
# --> 610     schema = self._generate_schema_inner(obj)
#     612 metadata_js_function = _extract_get_pydantic_json_schema(obj, schema)
#     613 if metadata_js_function is not None:
#
# File ~/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages/pydantic/_internal/_generate_schema.py:879, in GenerateSchema._generate_schema_inner(self, obj)
#     877 if lenient_issubclass(obj, BaseModel):
#     878     with self.model_type_stack.push(obj):
# --> 879         return self._model_schema(obj)
#     881 if isinstance(obj, PydanticRecursiveRef):
#     882     return core_schema.definition_reference_schema(schema_ref=obj.type_ref)
#
# File ~/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages/pydantic/_internal/_generate_schema.py:691, in GenerateSchema._model_schema(self, cls)
#     679     model_schema = core_schema.model_schema(
#     680         cls,
#     681         inner_schema,
#    (...)
#     687         ref=model_ref,
#     688     )
#     689 else:
#     690     fields_schema: core_schema.CoreSchema = core_schema.model_fields_schema(
# --> 691         {k: self._generate_md_field_schema(k, v, decorators) for k, v in fields.items()},
#     692         computed_fields=[
#     693             self._computed_field_schema(d, decorators.field_serializers)
#     694             for d in computed_fields.values()
#     695         ],
#     696         extras_schema=extras_schema,
#     697         model_name=cls.__name__,
#     698     )
#     699     inner_schema = apply_validators(fields_schema, decorators.root_validators.values(), None)
#     700     new_inner_schema = define_expected_missing_refs(inner_schema, recursively_defined_type_refs())
#
# File ~/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages/pydantic/_internal/_generate_schema.py:1071, in GenerateSchema._generate_md_field_schema(self, name, field_info, decorators)
#    1064 def _generate_md_field_schema(
#    1065     self,
#    1066     name: str,
#    1067     field_info: FieldInfo,
#    1068     decorators: DecoratorInfos,
#    1069 ) -> core_schema.ModelField:
#    1070     """Prepare a ModelField to represent a model field."""
# -> 1071     common_field = self._common_field_schema(name, field_info, decorators)
#    1072     return core_schema.model_field(
#    1073         common_field['schema'],
#    1074         serialization_exclude=common_field['serialization_exclude'],
#    (...)
#    1078         metadata=common_field['metadata'],
#    1079     )
#
# File ~/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages/pydantic/_internal/_generate_schema.py:1263, in GenerateSchema._common_field_schema(self, name, field_info, decorators)
#    1259         schema = self._apply_annotations(
#    1260             source_type, annotations + validators_from_decorators, transform_inner_schema=set_discriminator
#    1261         )
#    1262     else:
# -> 1263         schema = self._apply_annotations(
#    1264             source_type,
#    1265             annotations + validators_from_decorators,
#    1266         )
#    1268 # This V1 compatibility shim should eventually be removed
#    1269 # push down any `each_item=True` validators
#    1270 # note that this won't work for any Annotated types that get wrapped by a function validator
#    1271 # but that's okay because that didn't exist in V1
#    1272 this_field_validators = filter_field_decorator_info_by_field(decorators.validators.values(), name)
#
# File ~/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages/pydantic/_internal/_generate_schema.py:2056, in GenerateSchema._apply_annotations(self, source_type, annotations, transform_inner_schema)
#    2051         continue
#    2052     get_inner_schema = self._get_wrapped_inner_schema(
#    2053         get_inner_schema, annotation, pydantic_js_annotation_functions
#    2054     )
# -> 2056 schema = get_inner_schema(source_type)
#    2057 if pydantic_js_annotation_functions:
#    2058     core_metadata = schema.setdefault('metadata', {})
#
# File ~/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages/pydantic/_internal/_schema_generation_shared.py:84, in CallbackGetCoreSchemaHandler.__call__(self, source_type)
#      83 def __call__(self, source_type: Any, /) -> core_schema.CoreSchema:
# ---> 84     schema = self._handler(source_type)
#      85     ref = schema.get('ref')
#      86     if self._ref_mode == 'to-def':
#
# File ~/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages/pydantic/_internal/_generate_schema.py:2037, in GenerateSchema._apply_annotations.<locals>.inner_handler(obj)
#    2035 from_property = self._generate_schema_from_property(obj, source_type)
#    2036 if from_property is None:
# -> 2037     schema = self._generate_schema_inner(obj)
#    2038 else:
#    2039     schema = from_property
#
# File ~/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages/pydantic/_internal/_generate_schema.py:884, in GenerateSchema._generate_schema_inner(self, obj)
#     881 if isinstance(obj, PydanticRecursiveRef):
#     882     return core_schema.definition_reference_schema(schema_ref=obj.type_ref)
# --> 884 return self.match_type(obj)
#
# File ~/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages/pydantic/_internal/_generate_schema.py:986, in GenerateSchema.match_type(self, obj)
#     984 origin = get_origin(obj)
#     985 if origin is not None:
# --> 986     return self._match_generic_type(obj, origin)
#     988 res = self._get_prepare_pydantic_annotations_for_known_type(obj, ())
#     989 if res is not None:
#
# File ~/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages/pydantic/_internal/_generate_schema.py:1018, in GenerateSchema._match_generic_type(self, obj, origin)
#    1016     return self._tuple_schema(obj)
#    1017 elif origin in LIST_TYPES:
# -> 1018     return self._list_schema(self._get_first_arg_or_any(obj))
#    1019 elif origin in SET_TYPES:
#    1020     return self._set_schema(self._get_first_arg_or_any(obj))
#
# File ~/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages/pydantic/_internal/_generate_schema.py:367, in GenerateSchema._list_schema(self, items_type)
#     366 def _list_schema(self, items_type: Any) -> CoreSchema:
# --> 367     return core_schema.list_schema(self.generate_schema(items_type))
#
# File ~/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages/pydantic/_internal/_generate_schema.py:610, in GenerateSchema.generate_schema(self, obj, from_dunder_get_core_schema)
#     607         schema = from_property
#     609 if schema is None:
# --> 610     schema = self._generate_schema_inner(obj)
#     612 metadata_js_function = _extract_get_pydantic_json_schema(obj, schema)
#     613 if metadata_js_function is not None:
#
# File ~/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages/pydantic/_internal/_generate_schema.py:884, in GenerateSchema._generate_schema_inner(self, obj)
#     881 if isinstance(obj, PydanticRecursiveRef):
#     882     return core_schema.definition_reference_schema(schema_ref=obj.type_ref)
# --> 884 return self.match_type(obj)
#
# File ~/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages/pydantic/_internal/_generate_schema.py:982, in GenerateSchema.match_type(self, obj)
#     979     return self._zoneinfo_schema()
#     981 if dataclasses.is_dataclass(obj):
# --> 982     return self._dataclass_schema(obj, None)
#     984 origin = get_origin(obj)
#     985 if origin is not None:
#
# File ~/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages/pydantic/_internal/_generate_schema.py:1769, in GenerateSchema._dataclass_schema(self, dataclass, origin)
#    1766 decorators = dataclass.__dict__.get('__pydantic_decorators__') or DecoratorInfos.build(dataclass)
#    1767 # Move kw_only=False args to the start of the list, as this is how vanilla dataclasses work.
#    1768 # Note that when kw_only is missing or None, it is treated as equivalent to kw_only=True
# -> 1769 args = sorted(
#    1770     (self._generate_dc_field_schema(k, v, decorators) for k, v in fields.items()),
#    1771     key=lambda a: a.get('kw_only') is not False,
#    1772 )
#    1773 has_post_init = hasattr(dataclass, '__post_init__')
#    1774 has_slots = hasattr(dataclass, '__slots__')
#
# File ~/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages/pydantic/_internal/_generate_schema.py:1770, in <genexpr>(.0)
#    1766 decorators = dataclass.__dict__.get('__pydantic_decorators__') or DecoratorInfos.build(dataclass)
#    1767 # Move kw_only=False args to the start of the list, as this is how vanilla dataclasses work.
#    1768 # Note that when kw_only is missing or None, it is treated as equivalent to kw_only=True
#    1769 args = sorted(
# -> 1770     (self._generate_dc_field_schema(k, v, decorators) for k, v in fields.items()),
#    1771     key=lambda a: a.get('kw_only') is not False,
#    1772 )
#    1773 has_post_init = hasattr(dataclass, '__post_init__')
#    1774 has_slots = hasattr(dataclass, '__slots__')
#
# File ~/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages/pydantic/_internal/_generate_schema.py:1088, in GenerateSchema._generate_dc_field_schema(self, name, field_info, decorators)
#    1081 def _generate_dc_field_schema(
#    1082     self,
#    1083     name: str,
#    1084     field_info: FieldInfo,
#    1085     decorators: DecoratorInfos,
#    1086 ) -> core_schema.DataclassField:
#    1087     """Prepare a DataclassField to represent the parameter/field, of a dataclass."""
# -> 1088     common_field = self._common_field_schema(name, field_info, decorators)
#    1089     return core_schema.dataclass_field(
#    1090         name,
#    1091         common_field['schema'],
#    (...)
#    1099         metadata=common_field['metadata'],
#    1100     )
#
# File ~/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages/pydantic/_internal/_generate_schema.py:1263, in GenerateSchema._common_field_schema(self, name, field_info, decorators)
#    1259         schema = self._apply_annotations(
#    1260             source_type, annotations + validators_from_decorators, transform_inner_schema=set_discriminator
#    1261         )
#    1262     else:
# -> 1263         schema = self._apply_annotations(
#    1264             source_type,
#    1265             annotations + validators_from_decorators,
#    1266         )
#    1268 # This V1 compatibility shim should eventually be removed
#    1269 # push down any `each_item=True` validators
#    1270 # note that this won't work for any Annotated types that get wrapped by a function validator
#    1271 # but that's okay because that didn't exist in V1
#    1272 this_field_validators = filter_field_decorator_info_by_field(decorators.validators.values(), name)
#
# File ~/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages/pydantic/_internal/_generate_schema.py:2056, in GenerateSchema._apply_annotations(self, source_type, annotations, transform_inner_schema)
#    2051         continue
#    2052     get_inner_schema = self._get_wrapped_inner_schema(
#    2053         get_inner_schema, annotation, pydantic_js_annotation_functions
#    2054     )
# -> 2056 schema = get_inner_schema(source_type)
#    2057 if pydantic_js_annotation_functions:
#    2058     core_metadata = schema.setdefault('metadata', {})
#
# File ~/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages/pydantic/_internal/_schema_generation_shared.py:84, in CallbackGetCoreSchemaHandler.__call__(self, source_type)
#      83 def __call__(self, source_type: Any, /) -> core_schema.CoreSchema:
# ---> 84     schema = self._handler(source_type)
#      85     ref = schema.get('ref')
#      86     if self._ref_mode == 'to-def':
#
# File ~/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages/pydantic/_internal/_generate_schema.py:2037, in GenerateSchema._apply_annotations.<locals>.inner_handler(obj)
#    2035 from_property = self._generate_schema_from_property(obj, source_type)
#    2036 if from_property is None:
# -> 2037     schema = self._generate_schema_inner(obj)
#    2038 else:
#    2039     schema = from_property
#
# File ~/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages/pydantic/_internal/_generate_schema.py:884, in GenerateSchema._generate_schema_inner(self, obj)
#     881 if isinstance(obj, PydanticRecursiveRef):
#     882     return core_schema.definition_reference_schema(schema_ref=obj.type_ref)
# --> 884 return self.match_type(obj)
#
# File ~/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages/pydantic/_internal/_generate_schema.py:986, in GenerateSchema.match_type(self, obj)
#     984 origin = get_origin(obj)
#     985 if origin is not None:
# --> 986     return self._match_generic_type(obj, origin)
#     988 res = self._get_prepare_pydantic_annotations_for_known_type(obj, ())
#     989 if res is not None:
#
# File ~/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages/pydantic/_internal/_generate_schema.py:1014, in GenerateSchema._match_generic_type(self, obj, origin)
#    1012     return self._type_alias_type_schema(obj)
#    1013 elif _typing_extra.origin_is_union(origin):
# -> 1014     return self._union_schema(obj)
#    1015 elif origin in TUPLE_TYPES:
#    1016     return self._tuple_schema(obj)
#
# File ~/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages/pydantic/_internal/_generate_schema.py:1325, in GenerateSchema._union_schema(self, union_type)
#    1323         nullable = True
#    1324     else:
# -> 1325         choices.append(self.generate_schema(arg))
#    1327 if len(choices) == 1:
#    1328     s = choices[0]
#
# File ~/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages/pydantic/_internal/_generate_schema.py:610, in GenerateSchema.generate_schema(self, obj, from_dunder_get_core_schema)
#     607         schema = from_property
#     609 if schema is None:
# --> 610     schema = self._generate_schema_inner(obj)
#     612 metadata_js_function = _extract_get_pydantic_json_schema(obj, schema)
#     613 if metadata_js_function is not None:
#
# File ~/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages/pydantic/_internal/_generate_schema.py:884, in GenerateSchema._generate_schema_inner(self, obj)
#     881 if isinstance(obj, PydanticRecursiveRef):
#     882     return core_schema.definition_reference_schema(schema_ref=obj.type_ref)
# --> 884 return self.match_type(obj)
#
# File ~/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages/pydantic/_internal/_generate_schema.py:995, in GenerateSchema.match_type(self, obj)
#     993 if self._arbitrary_types:
#     994     return self._arbitrary_type_schema(obj)
# --> 995 return self._unknown_type_schema(obj)
#
# File ~/.pyenv/versions/tnh-scholar/lib/python3.12/site-packages/pydantic/_internal/_generate_schema.py:513, in GenerateSchema._unknown_type_schema(self, obj)
#     512 def _unknown_type_schema(self, obj: Any) -> CoreSchema:
# --> 513     raise PydanticSchemaGenerationError(
#     514         f'Unable to generate pydantic-core schema for {obj!r}. '
#     515         'Set `arbitrary_types_allowed=True` in the model_config to ignore this error'
#     516         ' or implement `__get_pydantic_core_schema__` on your type to fully support it.'
#     517         '\n\nIf you got this error by calling handler(<some type>) within'
#     518         ' `__get_pydantic_core_schema__` then you likely need to call'
#     519         ' `handler.generate_schema(<some type>)` since we do not call'
#     520         ' `__get_pydantic_core_schema__` on `<some type>` otherwise to avoid infinite recursion.'
#     521     )
#
# PydanticSchemaGenerationError: Unable to generate pydantic-core schema for <class 'tnh_scholar.metadata.metadata.Metadata'>. Set `arbitrary_types_allowed=True` in the model_config to ignore this error or implement `__get_pydantic_core_schema__` on your type to fully support it.
#
# If you got this error by calling handler(<some type>) within `__get_pydantic_core_schema__` then you likely need to call `handler.generate_schema(<some type>)` since we do not call `__get_pydantic_core_schema__` on `<some type>` otherwise to avoid infinite recursion.
#
# For further information visit https://errors.pydantic.dev/2.10/u/schema-for-unknown-type

# %%
my_dict = {"key1": "test1", "key2": "test2"}

# %%
meta = Metadata(my_dict)

# %%
meta
# Out:
# Metadata({'key1': 'test1', 'key2': 'test2'})

# %%
meta.to_dict()
# Out:
# {'key1': 'test1', 'key2': 'test2'}

# %%
out = Frontmatter.embed(my_dict, "This is a short\ndocument with two lines.")
print(out)
# Out:
# ---
# key1: test1
# key2: test2
# ---
#
# This is a short
# document with two lines.

# %%
Frontmatter.extract(out)
# Out:
# ({'key1': 'test1', 'key2': 'test2'},
#  'This is a short\ndocument with two lines.')

# %%
# JSON-LD implementation:

class MetadataHandler:
    """Handles JSON-LD metadata embedding and extraction for text documents."""
    
    JSONLD_MARKER = "---begin:json-ld---"
    MARKER_END = "---end:json-ld---"
    
    @staticmethod
    def extract(content: str) -> Tuple[Optional[Dict[str, Any]], str]:
        """Extract JSON-LD metadata and content from text.
        
        Args:
            content: Text content potentially containing JSON-LD metadata
            
        Returns:
            Tuple of (metadata dict or None, content without metadata)
        """
        pattern = f"{MetadataHandler.JSONLD_MARKER}(.*?){MetadataHandler.MARKER_END}"
        if match := re.search(pattern, content, re.DOTALL):
            try:
                metadata = json.loads(match[1].strip())
                # Remove the metadata block from content
                clean_content = re.sub(pattern, "", content, flags=re.DOTALL).strip()
                return metadata, clean_content
            except json.JSONDecodeError:
                return None, content
        return None, content

    @staticmethod
    def embed(metadata: Dict[str, Any], content: str) -> str:
        """Embed metadata as JSON-LD in text content.
        
        Args:
            metadata: Dictionary of metadata to embed
            content: Text content
            
        Returns:
            Content with embedded metadata
        """
        json_str = json.dumps(metadata, indent=2)
        metadata_block = (
            f"{MetadataHandler.JSONLD_MARKER}\n"
            f"{json_str}\n{MetadataHandler.MARKER_END}\n\n"
            )
        return f"{metadata_block}{content}"

def create_youtube_metadata(video_info: Dict[str, Any]) -> Dict[str, Any]:
    """Create JSON-LD metadata for YouTube video content.
    
    Based on YouTube's VideoObject schema:
    https://schema.org/VideoObject
    
    Args:
        video_info: Video information from yt-dlp
        
    Returns:
        JSON-LD metadata dictionary
    """
    return {
        "@context": "https://schema.org",
        "@type": "VideoObject",
        "@id": video_info.get("id"),  
        "name": video_info.get("title"),
        "description": video_info.get("description"),
        "uploadDate": video_info.get("upload_date"),
        "duration": video_info.get("duration"),
        "author": {
            "@type": "Person",
            "name": video_info.get("uploader"),
            "url": video_info.get("channel_url")
        },
        "publisher": {
            "@type": "Organization",
            "name": video_info.get("channel"),
            "url": video_info.get("channel_url")
        },
        "inLanguage": video_info.get("language"),
        "genre": video_info.get("categories"),
        "keywords": video_info.get("tags"),
        "url": video_info.get("webpage_url"),
        "originalUrl": video_info.get("original_url"),
        "videoId": video_info.get("id"),
        "contentUrl": f"https://www.youtube.com/watch?v={video_info.get('id')}",
        "chanelUrl": video_info.get("channel_url"),
    }
