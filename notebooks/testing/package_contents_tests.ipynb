# %%
# Paste from pyproject.toml dependencies (modify as needed)
pyproject_deps = dependencies = [
    "click==8.1.8",
    "colorlog==6.9.0",
    "GitPython==3.1.44",
    "Jinja2==3.1.5",
    "langchain_community==0.3.13",
    "langchain_openai==0.2.14",
    "langdetect==1.0.9",
    "lxml==5.3.0",
    "numpy==2.0.2",
    "openai==1.58.1",
    "openai_whisper==20240930",
    "packaging==24.2",
    "pycountry==24.6.1",
    "pydantic==2.10.4",
    "pydub==0.25.1",
    "python-dotenv==1.0.1",
    "PyYAML==6.0.2",
    "regex==2024.11.6",
    "Requests==2.32.3",
    "supabase==2.11.0",
    "tiktoken==0.8.0",
    "torch==2.5.1",
    "tqdm==4.67.1",
    "transformers==4.47.1",
    "yt_dlp==2025.1.15",
    "GitPython==3.1.44"
]

# Paste from pip freeze output (modify as needed)
pip_freeze = """
acres==0.2.0
aiohappyeyeballs==2.4.4
aiohttp==3.11.11
aiosignal==1.3.2
alembic==1.14.0
altair==5.5.0
annotated-types==0.7.0
antlr4-python3-runtime==4.9.3
anyio==4.7.0
appnope==0.1.4
argon2-cffi==23.1.0
argon2-cffi-bindings==21.2.0
arrow==1.3.0
asteroid-filterbanks==0.4.0
asttokens==3.0.0
async-lru==2.0.4
attrs==24.3.0
audioread==3.0.1
babel==2.16.0
backcall==0.2.0
beautifulsoup4==4.12.3
black==24.10.0
bleach==6.2.0
blinker==1.9.0
blis==1.1.0
build==1.2.2.post1
cachetools==5.5.0
catalogue==2.0.10
certifi==2024.12.14
cffi==1.17.1
charset-normalizer==3.4.1
ci-info==0.3.0
click==8.1.8
cloudpathlib==0.20.0
colorama==0.4.6
colorlog==6.9.0
comm==0.2.2
confection==0.1.5
configobj==5.0.9
configparser==7.1.0
contourpy==1.3.1
coverage==7.6.10
cycler==0.12.1
cymem==2.0.10
dataclasses-json==0.6.7
debugpy==1.8.11
decorator==5.1.1
defusedxml==0.7.1
deprecation==2.1.0
distro==1.9.0
docopt==0.6.2
EbookLib==0.18
einops==0.8.0
etelemetry==0.3.1
executing==2.1.0
fastjsonschema==2.21.1
filelock==3.16.1
fitz==0.0.1.dev2
flake8==7.1.1
fonttools==4.55.3
fqdn==1.5.1
frozenlist==1.5.0
fsspec==2024.12.0
ghp-import==2.1.0
git-filter-repo==2.47.0
gitdb==4.0.11
GitPython==3.1.43
google-api-core==2.24.0
google-auth==2.37.0
google-cloud==0.34.0
google-cloud-vision==3.9.0
googleapis-common-protos==1.66.0
gotrue==2.11.1
griffe==1.5.5
grpcio==1.68.1
grpcio-status==1.68.1
h11==0.14.0
h2==4.1.0
hpack==4.0.0
httpcore==1.0.7
httplib2==0.22.0
httpx==0.27.2
httpx-sse==0.4.0
huggingface-hub==0.27.0
hyperframe==6.0.1
HyperPyYAML==1.2.2
idna==3.10
iniconfig==2.0.0
ipykernel==6.29.5
ipython==8.12.3
ipywidgets==8.1.5
isodate==0.6.1
isoduration==20.11.0
jedi==0.19.2
Jinja2==3.1.5
jiter==0.8.2
joblib==1.4.2
json5==0.10.0
jsonpatch==1.33
jsonpointer==3.0.0
jsonschema==4.23.0
jsonschema-specifications==2024.10.1
julius==0.2.7
jupyter-events==0.11.0
jupyter-lsp==2.2.5
jupyter_client==8.6.3
jupyter_core==5.7.2
jupyter_server==2.15.0
jupyter_server_terminals==0.5.3
jupyterlab==4.3.4
jupyterlab_pygments==0.3.0
jupyterlab_server==2.27.3
jupyterlab_widgets==3.0.13
kiwisolver==1.4.8
langchain==0.3.13
langchain-community==0.3.13
langchain-core==0.3.28
langchain-openai==0.2.14
langchain-text-splitters==0.3.4
langcodes==3.5.0
langdetect==1.0.9
langsmith==0.2.7
language_data==1.3.0
lazy_loader==0.4
librosa==0.10.2.post1
lightning==2.5.0.post0
lightning-utilities==0.11.9
llvmlite==0.43.0
looseversion==1.3.0
lxml==5.3.0
Mako==1.3.8
marisa-trie==1.2.1
Markdown==3.7
markdown-it-py==3.0.0
MarkupSafe==3.0.2
marshmallow==3.23.2
matplotlib==3.10.0
matplotlib-inline==0.1.7
mccabe==0.7.0
mdurl==0.1.2
mergedeep==1.3.4
mistune==3.1.0
mkdocs==1.6.1
mkdocs-autorefs==1.3.0
mkdocs-get-deps==0.2.0
mkdocs-material==9.5.50
mkdocs-material-extensions==1.3.1
mkdocstrings==0.27.0
mkdocstrings-python==1.13.0
more-itertools==10.5.0
mpmath==1.3.0
msgpack==1.1.0
multidict==6.1.0
murmurhash==1.0.11
mypy==1.14.1
mypy-extensions==1.0.0
narwhals==1.19.1
nbclient==0.10.2
nbconvert==7.16.5
nbformat==5.10.4
nest-asyncio==1.6.0
networkx==3.4.2
nibabel==5.3.2
nipype==1.9.2
notebook==7.3.2
notebook_shim==0.2.4
numba==0.60.0
numpy==2.0.2
omegaconf==2.3.0
openai==1.58.1
openai-whisper==20240930
optuna==4.1.0
orjson==3.10.13
overrides==7.7.0
packaging==24.2
paginate==0.5.7
pandas==2.2.3
pandocfilters==1.5.1
parso==0.8.4
pathlib==1.0.1
pathspec==0.12.1
pdf2image==1.17.0
pexpect==4.9.0
pickleshare==0.7.5
pillow==11.0.0
pip-tools==7.4.1
pipdeptree==2.24.0
pipreqs==0.5.0
platformdirs==4.3.6
pluggy==1.5.0
pooch==1.8.2
postgrest==0.19.1
preshed==3.0.9
primePy==1.3
prometheus_client==0.21.1
prompt_toolkit==3.0.48
propcache==0.2.1
proto-plus==1.25.0
protobuf==5.29.2
prov==2.0.1
psutil==6.1.1
ptyprocess==0.7.0
pure_eval==0.2.3
puremagic==1.28
pyannote.audio==3.3.2
pyannote.core==5.0.0
pyannote.database==5.1.0
pyannote.metrics==3.2.1
pyannote.pipeline==3.0.1
pyarrow==18.1.0
pyasn1==0.6.1
pyasn1_modules==0.4.1
pycodestyle==2.12.1
pycountry==24.6.1
pycparser==2.22
pydantic==2.10.4
pydantic-settings==2.7.1
pydantic_core==2.27.2
pydeck==0.9.1
pydot==3.0.3
pydub==0.25.1
pyflakes==3.2.0
Pygments==2.18.0
pymdown-extensions==10.14
pyparsing==3.2.0
pyproject_hooks==1.2.0
pytest==8.3.4
pytest-cov==6.0.0
python-dateutil==2.9.0.post0
python-dotenv==1.0.1
python-json-logger==3.2.1
pytorch-lightning==2.5.0.post0
pytorch-metric-learning==2.8.1
pytz==2024.2
pyxnat==1.6.2
PyYAML==6.0.2
pyyaml_env_tag==0.1
pyzmq==26.2.0
rdflib==6.3.2
realtime==2.1.0
referencing==0.35.1
regex==2024.11.6
requests==2.32.3
requests-toolbelt==1.0.0
rfc3339-validator==0.1.4
rfc3986-validator==0.1.1
rich==13.9.4
rpds-py==0.22.3
rsa==4.9
ruamel.yaml==0.18.10
ruamel.yaml.clib==0.2.12
ruff==0.9.2
safetensors==0.4.5
scikit-learn==1.6.0
scipy==1.14.1
semver==3.0.2
Send2Trash==1.8.3
sentencepiece==0.2.0
setuptools==75.6.0
shellingham==1.5.4
simplejson==3.19.3
six==1.17.0
smart-open==7.1.0
smmap==5.0.1
sniffio==1.3.1
sortedcontainers==2.4.0
soundfile==0.13.0
soupsieve==2.6
soxr==0.5.0.post1
spacy==3.8.3
spacy-legacy==3.0.12
spacy-loggers==1.0.5
speechbrain==1.0.2
SQLAlchemy==2.0.36
srsly==2.5.0
stack-data==0.6.3
storage3==0.11.0
streamlit==1.41.1
StrEnum==0.4.15
supabase==2.11.0
supafunc==0.9.0
sympy==1.13.1
tabulate==0.9.0
tenacity==9.0.0
tensorboardX==2.6.2.2
terminado==0.18.1
thinc==8.3.3
threadpoolctl==3.5.0
tiktoken==0.8.0
tinycss2==1.4.0
tokenizers==0.21.0
toml==0.10.2
torch==2.5.1
torch-audiomentations==0.11.2
torch_pitch_shift==1.2.5
torchaudio==2.5.1
torchmetrics==1.6.1
tornado==6.4.2
tqdm==4.67.1
traitlets==5.14.3
traits==6.4.3
transformers==4.47.1
typer==0.15.1
types-python-dateutil==2.9.0.20241206
types-PyYAML==6.0.12.20241230
types-requests==2.32.0.20241016
typing-inspect==0.9.0
typing_extensions==4.12.2
tzdata==2024.2
uri-template==1.3.0
urllib3==2.3.0
wasabi==1.1.3
watchdog==6.0.0
wcwidth==0.2.13
weasel==0.4.1
webcolors==24.11.1
webencodings==0.5.1
websocket-client==1.8.0
websockets==13.1
webvtt-py==0.5.1
wheel==0.45.1
widgetsnbextension==4.0.13
wrapt==1.17.0
yarg==0.1.9
yarl==1.18.3
yt-dlp==2025.1.15
"""

for dep in pyproject_deps:
    if '==' in dep:  # Only look at pinned versions
        pkg, version = dep.split('==')
        for freeze_dep in pip_freeze.strip().split('\n'):
            if freeze_dep.startswith(f'{pkg}=='):
                print(f"{pkg}: pyproject={version}, installed={freeze_dep.split('==')[1]}")
# Out:
# click: pyproject=8.1.8, installed=8.1.8
# colorlog: pyproject=6.9.0, installed=6.9.0
# GitPython: pyproject=3.1.44, installed=3.1.43
# Jinja2: pyproject=3.1.5, installed=3.1.5
# langdetect: pyproject=1.0.9, installed=1.0.9
# lxml: pyproject=5.3.0, installed=5.3.0
# numpy: pyproject=2.0.2, installed=2.0.2
# openai: pyproject=1.58.1, installed=1.58.1
# packaging: pyproject=24.2, installed=24.2
# pycountry: pyproject=24.6.1, installed=24.6.1
# pydantic: pyproject=2.10.4, installed=2.10.4
# pydub: pyproject=0.25.1, installed=0.25.1
# python-dotenv: pyproject=1.0.1, installed=1.0.1
# PyYAML: pyproject=6.0.2, installed=6.0.2
# regex: pyproject=2024.11.6, installed=2024.11.6
# supabase: pyproject=2.11.0, installed=2.11.0
# tiktoken: pyproject=0.8.0, installed=0.8.0
# torch: pyproject=2.5.1, installed=2.5.1
# tqdm: pyproject=4.67.1, installed=4.67.1
# transformers: pyproject=4.47.1, installed=4.47.1
# GitPython: pyproject=3.1.44, installed=3.1.43
