# %%
from pathlib import Path

# %%
from tnh_scholar.cli_tools.audio_transcribe.diarize import (
    check_job_status,
    diarize,
    resume_diarization,
)

# %%
working_dir = Path.home() / "Desktop/trans_test"

# %%
audio_file_path = working_dir \
    / "audio_transcriptions"  \
    / "neil_degrasse_tyson_s_5_m_PFHVYKrNpNk.mp3"
if not audio_file_path.exists:
    raise FileNotFoundError("Audio file not found.")

# %%
result = diarize(audio_file_path)

# %%
check_job_status('994c79b7-5f32-4715-aa34-33f00e216369')

# %%
result = resume_diarization(audio_file_path, '994c79b7-5f32-4715-aa34-33f00e216369')

# %%
result
