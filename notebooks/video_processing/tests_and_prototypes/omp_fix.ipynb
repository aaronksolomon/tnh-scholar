# %%
import whisper
print(whisper.__file__)  # Path to the Whisper library
# Out:
# /opt/anaconda3/envs/tnh-scholar/lib/python3.11/site-packages/whisper/__init__.py

# %%
print(whisper.__version__)
# Out:
# 20240930

# %%
import numba
print(numba.__version__)
# Out:
# 0.60.0

# %%
import torch

# %%
print(torch.__version__)
# Out:
# 2.6.0.dev20241112

# %%
import numpy

# %%
print(numpy.__version__)
# Out:
# 2.0.0

# %%
import sys
print(sys.path)
# Out:
# ['/opt/anaconda3/envs/tnh-scholar/lib/python311.zip', '/opt/anaconda3/envs/tnh-scholar/lib/python3.11', '/opt/anaconda3/envs/tnh-scholar/lib/python3.11/lib-dynload', '', '/opt/anaconda3/envs/tnh-scholar/lib/python3.11/site-packages', '/Users/phapman/Desktop/tnh-scholar/src']

# %%
import sys
print(sys.executable)
# Out:
# /opt/anaconda3/envs/tnh-scholar/bin/python

# %%
torch.set_num_threads(4)  # Example: Set to 4 threads

# %%
model = whisper.load_model('tiny')

# %%
from tnh_scholar import PROJECT_ROOT_DIR

# %%
test_audio_dir = PROJECT_ROOT_DIR / "sandbox" / "audio_transcriptions"

# %%
test_audio_dir.exists()
# Out:
# True

# %%
test_audio_path = test_audio_dir / "Kinh Văn Căn Bản của Thiền Tập 01 [TTSĐCTTĐB 03] ｜ TS Thích Nhất Hạnh(27-11-1994, Làng Mai).mp3"

# %%
test_audio_path.exists()
# Out:
# True

# %%
model.transcribe(str(test_audio_path), verbose=False, language='vi')
# Out:
# /opt/anaconda3/envs/tnh-scholar/lib/python3.11/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 100%|█████████▉| 658916/661916 [05:17<00:01, 2076.31frames/s]
# {'text': ' Bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, b bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, b bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, b bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, b bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, b bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, b bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, llik dạy dạy like đã thấy 여기, bây giờ, bây giờ, bây giờ bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờезде, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, Bộ  ...
#  'segments': [{'id': 0,
#    'seek': 0,
#    'start': 0.0,
#    'end': 30.0,
#    'text': ' Bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ',
#    'tokens': [50364,
#     363,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689],
#    'temperature': 0.0,
#    'avg_logprob': -0.11185914781358507,
#    'compression_ratio': 23.928571428571427,
#    'no_speech_prob': 0.6976486444473267},
#   {'id': 1,
#    'seek': 3000,
#    'start': 30.0,
#    'end': 60.0,
#    'text': ' bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, b',
#    'tokens': [50364,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272],
#    'temperature': 0.0,
#    'avg_logprob': -0.027323136949753014,
#    'compression_ratio': 23.607142857142858,
#    'no_speech_prob': 0.9022340774536133},
#   {'id': 2,
#    'seek': 6000,
#    'start': 60.0,
#    'end': 90.0,
#    'text': ' bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, b',
#    'tokens': [50364,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272],
#    'temperature': 0.0,
#    'avg_logprob': -0.027269132468732485,
#    'compression_ratio': 23.607142857142858,
#    'no_speech_prob': 0.9549704790115356},
#   {'id': 3,
#    'seek': 9000,
#    'start': 90.0,
#    'end': 120.0,
#    'text': ' bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, b',
#    'tokens': [50364,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272],
#    'temperature': 0.0,
#    'avg_logprob': -0.022022914458817964,
#    'compression_ratio': 23.607142857142858,
#    'no_speech_prob': 0.9435298442840576},
#   {'id': 4,
#    'seek': 12000,
#    'start': 120.0,
#    'end': 150.0,
#    'text': ' bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, b',
#    'tokens': [50364,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272],
#    'temperature': 0.0,
#    'avg_logprob': -0.01615689474370982,
#    'compression_ratio': 23.607142857142858,
#    'no_speech_prob': 0.9459538459777832},
#   {'id': 5,
#    'seek': 15000,
#    'start': 150.0,
#    'end': 180.0,
#    'text': ' bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, b',
#    'tokens': [50364,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272],
#    'temperature': 0.0,
#    'avg_logprob': -0.021948183598539756,
#    'compression_ratio': 23.607142857142858,
#    'no_speech_prob': 0.847099781036377},
#   {'id': 6,
#    'seek': 18000,
#    'start': 180.0,
#    'end': 210.0,
#    'text': ' bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, b',
#    'tokens': [50364,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272],
#    'temperature': 0.0,
#    'avg_logprob': -0.02637984186009976,
#    'compression_ratio': 23.607142857142858,
#    'no_speech_prob': 0.9180478453636169},
#   {'id': 7,
#    'seek': 21000,
#    'start': 210.0,
#    'end': 240.0,
#    'text': ' bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, llik dạy dạy like đã thấy 여기, bây giờ, bây giờ, bây giờ bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờезде, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ, bây giờ,',
#    'tokens': [50364,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     287,
#     13462,
#     274,
#     5890,
#     88,
#     274,
#     5890,
#     88,
#     411,
#     17283,
#     27793,
#     7543,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     46683,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11,
#     272,
#     12108,
#     28689,
#     11],
#    'temperature': 1.0,
#    'avg_logprob': -0.3688485526183261,
#    'compression_ratio': 8.296296296296296,
#    'no_speech_prob': 0.5666016936302185},
#   {'id': 8,
#    'seek': 24000,
#    'start': 240.0,
#    'end': 250.0,
#    'text': ' Bộ quán thích kỹ thứ môi một cái mục thay trên ở đảo nguyên, đã biến tập một cuốn sách tin là cạnh đứt triển đặc lục.',
#    'tokens': [50364,
#     363,
#     8047,
#     421,
#     7200,
#     258,
#     30839,
#     350,
#     40085,
#     47269,
#     275,
#     12213,
#     275,
#     13737,
#     14830,
#     275,
#     37664,
#     258,
#     320,
#     33187,
#     19272,
#     2934,
#     40657,
#     297,
#     39344,
#     5050,
#     11,
#     17283,
#     3228,
#     16240,
#     256,
#     35148,
#     15486,
#     2702,
#     31754,
#     262,
#     39569,
#     15935,
#     3684,
#     269,
#     45782,
#     2934,
#     13905,
#     83,
#     1376,
#     38197,
#     2934,
#     38464,
#     287,
#     37664,
#     13,
#     50864],
#    'temperature': 0.0,
#    'avg_logprob': -0.9361735066090981,
#    'compression_ratio': 1.5018587360594795,
#    'no_speech_prob': 0.6260352730751038},
#   {'id': 9,
#    'seek': 24000,
#    'start': 251.0,
#    'end': 269.0,
#    'text': ' Vào trong đó thì thay giết lại sự đào triển mống đẹp từ các quyết buộc, cho đến thế kây giết thế ăn nè, thế bộ để đặc mát, rồi đến các thay, thế khá tăng sáng lảo tín hôm lãng,',
#    'tokens': [50914,
#     691,
#     20807,
#     18826,
#     17647,
#     17510,
#     258,
#     320,
#     1735,
#     13888,
#     23017,
#     33602,
#     2934,
#     20807,
#     1376,
#     38197,
#     275,
#     21092,
#     2934,
#     26965,
#     79,
#     26834,
#     13250,
#     44088,
#     13888,
#     758,
#     34259,
#     11,
#     1586,
#     26353,
#     27100,
#     350,
#     12108,
#     1735,
#     13888,
#     27100,
#     28657,
#     297,
#     1462,
#     11,
#     27100,
#     272,
#     8047,
#     20081,
#     2934,
#     38464,
#     275,
#     7656,
#     11,
#     19908,
#     26353,
#     13250,
#     258,
#     320,
#     11,
#     27100,
#     7168,
#     842,
#     256,
#     34705,
#     262,
#     30344,
#     287,
#     40657,
#     256,
#     10973,
#     276,
#     25670,
#     287,
#     1046,
#     872,
#     11,
#     51814],
#    'temperature': 0.0,
#    'avg_logprob': -0.9361735066090981,
#    'compression_ratio': 1.5018587360594795,
#    'no_speech_prob': 0.6260352730751038},
#   {'id': 10,
#    'seek': 26900,
#    'start': 269.0,
#    'end': 271.0,
#    'text': ' thế năng vô vật.',
#    'tokens': [50364, 27100, 297, 34705, 371, 2851, 371, 25296, 13, 50464],
#    'temperature': 0.0,
#    'avg_logprob': -0.8451549571047547,
#    'compression_ratio': 1.3526570048309179,
#    'no_speech_prob': 0.15086637437343597},
#   {'id': 11,
#    'seek': 26900,
#    'start': 275.0,
#    'end': 282.0,
#    'text': ' Vì đàn các cắm các phẩm, tên là gái năng thiển ở dưới đăng tập lục.',
#    'tokens': [50664,
#     691,
#     4749,
#     2934,
#     22476,
#     13250,
#     269,
#     41227,
#     13250,
#     903,
#     35068,
#     76,
#     11,
#     256,
#     5050,
#     3684,
#     290,
#     28249,
#     297,
#     34705,
#     30994,
#     38197,
#     19272,
#     274,
#     5829,
#     8971,
#     2934,
#     34705,
#     256,
#     35148,
#     287,
#     37664,
#     13,
#     51014],
#    'temperature': 0.0,
#    'avg_logprob': -0.8451549571047547,
#    'compression_ratio': 1.3526570048309179,
#    'no_speech_prob': 0.15086637437343597},
#   {'id': 12,
#    'seek': 26900,
#    'start': 283.0,
#    'end': 290.0,
#    'text': ' Công nói về sự trời là vật. Và công có giết chết các quyết thiển sự vực năng đã tiếp dành kế lệng trên pháp như thế nào.',
#    'tokens': [51064,
#     383,
#     8217,
#     27508,
#     25652,
#     33602,
#     504,
#     21024,
#     3684,
#     371,
#     25296,
#     13,
#     44851,
#     269,
#     8217,
#     6333,
#     1735,
#     13888,
#     417,
#     13888,
#     13250,
#     44088,
#     13888,
#     30994,
#     38197,
#     33602,
#     371,
#     27951,
#     297,
#     34705,
#     17283,
#     48667,
#     274,
#     24449,
#     350,
#     6115,
#     287,
#     8471,
#     872,
#     33187,
#     903,
#     15059,
#     16228,
#     27100,
#     29069,
#     13,
#     51414],
#    'temperature': 0.0,
#    'avg_logprob': -0.8451549571047547,
#    'compression_ratio': 1.3526570048309179,
#    'no_speech_prob': 0.15086637437343597},
#   {'id': 13,
#    'seek': 29000,
#    'start': 290.0,
#    'end': 320.0,
#    'text': ' Vì đàn bộ quán thích kỹ thứ môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi môi',
#    'tokens': [50364,
#     691,
#     4749,
#     2934,
#     22476,
#     272,
#     8047,
#     421,
#     7200,
#     258,
#     30839,
#     350,
#     40085,
#     47269,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213,
#     275,
#     12213],
#    'temperature': 0.0,
#    'avg_logprob': -0.13164105733235676,
#    'compression_ratio': 9.87719298245614,
#    'no_speech_prob': 0.62282395362854},
#   {'id': 14,
#    'seek': 32000,
#    'start': 320.0,
#    'end': 325.84,
#    'text': ' có thể tiếp nhận được trong phay là phải đời búng năm ở lạ xau năm thì mới có濁 để trường đăng tr engine anh',
#    'tokens': [50364,
#     6333,
#     24491,
#     48667,
#     6245,
#     27410,
#     15832,
#     18826,
#     903,
#     320,
#     3684,
#     23394,
#     2934,
#     21024,
#     272,
#     16926,
#     38098,
#     19272,
#     287,
#     5890,
#     2031,
#     1459,
#     38098,
#     17510,
#     37328,
#     6333,
#     26373,
#     223,
#     20081,
#     504,
#     24280,
#     2934,
#     34705,
#     504,
#     2848,
#     18931,
#     50656],
#    'temperature': 1.0,
#    'avg_logprob': -3.063263369278169,
#    'compression_ratio': 1.4351851851851851,
#    'no_speech_prob': 0.08078479766845703},
#   {'id': 15,
#    'seek': 32000,
#    'start': 325.84,
#    'end': 327.16,
#    'text': ' tại vì thế vệ trong đăng đỏ',
#    'tokens': [50656,
#     37773,
#     37902,
#     27100,
#     371,
#     8471,
#     18826,
#     2934,
#     34705,
#     2934,
#     21920,
#     50722],
#    'temperature': 1.0,
#    'avg_logprob': -3.063263369278169,
#    'compression_ratio': 1.4351851851851851,
#    'no_speech_prob': 0.08078479766845703},
#   {'id': 16,
#    'seek': 32000,
#    'start': 327.62,
#    'end': 330.36,
#    'text': ' y Ở sao nói là chính thức khua',
#    'tokens': [50745,
#     288,
#     40132,
#     252,
#     33108,
#     27508,
#     3684,
#     42178,
#     258,
#     27138,
#     7168,
#     4398,
#     50882],
#    'temperature': 1.0,
#    'avg_logprob': -3.063263369278169,
#    'compression_ratio': 1.4351851851851851,
#    'no_speech_prob': 0.08078479766845703},
#   {'id': 17,
#    'seek': 32000,
#    'start': 330.68,
#    'end': 333.28,
#    'text': ' thích dỳ hợt gặp m millisecondsñosSa t SAY',
#    'tokens': [50898,
#     258,
#     30839,
#     274,
#     1297,
#     111,
#     276,
#     27836,
#     83,
#     290,
#     19118,
#     79,
#     275,
#     34184,
#     8242,
#     45393,
#     256,
#     42948,
#     51028],
#    'temperature': 1.0,
#    'avg_logprob': -3.063263369278169,
#    'compression_ratio': 1.4351851851851851,
#    'no_speech_prob': 0.08078479766845703},
#   {'id': 18,
#    'seek': 32000,
#    'start': 333.28,
#    'end': 334.8,
#    'text': ' nha mình tiếp nhỏ trong mỗi dây mà book',
#    'tokens': [51028,
#     297,
#     1641,
#     14526,
#     48667,
#     6245,
#     21920,
#     18826,
#     275,
#     49572,
#     274,
#     12108,
#     13901,
#     1446,
#     51104],
#    'temperature': 1.0,
#    'avg_logprob': -3.063263369278169,
#    'compression_ratio': 1.4351851851851851,
#    'no_speech_prob': 0.08078479766845703},
#   {'id': 19,
#    'seek': 32000,
#    'start': 334.8,
#    'end': 338.72,
#    'text': ' những mới không có thích dần đăng g corners để tiram estiveru ngọa clearly',
#    'tokens': [51104,
#     20136,
#     37328,
#     11415,
#     6333,
#     258,
#     30839,
#     274,
#     18241,
#     2934,
#     34705,
#     290,
#     12413,
#     20081,
#     256,
#     40359,
#     46578,
#     84,
#     6415,
#     12935,
#     64,
#     4448,
#     51300],
#    'temperature': 1.0,
#    'avg_logprob': -3.063263369278169,
#    'compression_ratio': 1.4351851851851851,
#    'no_speech_prob': 0.08078479766845703},
#   {'id': 20,
#    'seek': 32000,
#    'start': 338.72,
#    'end': 340.48,
#    'text': ' chứng thước',
#    'tokens': [51300, 417, 44555, 258, 19578, 51388],
#    'temperature': 1.0,
#    'avg_logprob': -3.063263369278169,
#    'compression_ratio': 1.4351851851851851,
#    'no_speech_prob': 0.08078479766845703},
#   {'id': 21,
#    'seek': 32000,
#    'start': 340.48,
#    'end': 344.24,
#    'text': ' cóker arien nhperson',
#    'tokens': [51388, 6333, 5767, 257, 27378, 6245, 10813, 51576],
#    'temperature': 1.0,
#    'avg_logprob': -3.063263369278169,
#    'compression_ratio': 1.4351851851851851,
#    'no_speech_prob': 0.08078479766845703},
#   {'id': 22,
#    'seek': 32000,
#    'start': 344.78,
#    'end': 349.6,
#    'text': ' mức tạp',
#    'tokens': [51603, 275, 27138, 256, 5890, 79, 51844],
#    'temperature': 1.0,
#    'avg_logprob': -3.063263369278169,
#    'compression_ratio': 1.4351851851851851,
#    'no_speech_prob': 0.08078479766845703},
#   {'id': 23,
#    'seek': 34960,
#    'start': 349.6,
#    'end': 351.6,
#    'text': ' là mình có kích nạn hát không?',
#    'tokens': [50364,
#     3684,
#     14526,
#     6333,
#     350,
#     30839,
#     297,
#     12937,
#     276,
#     7656,
#     11415,
#     30,
#     50464],
#    'temperature': 0.0,
#    'avg_logprob': -0.7776457134046053,
#    'compression_ratio': 1.294478527607362,
#    'no_speech_prob': 0.32245901226997375},
#   {'id': 24,
#    'seek': 34960,
#    'start': 362.6,
#    'end': 364.6,
#    'text': ' Vì vậy, những chúng ta về là không?',
#    'tokens': [51014,
#     691,
#     4749,
#     29738,
#     11,
#     20136,
#     24322,
#     1846,
#     25652,
#     3684,
#     11415,
#     30,
#     51114],
#    'temperature': 0.0,
#    'avg_logprob': -0.7776457134046053,
#    'compression_ratio': 1.294478527607362,
#    'no_speech_prob': 0.32245901226997375},
#   {'id': 25,
#    'seek': 34960,
#    'start': 366.6,
#    'end': 369.6,
#    'text': ' Chính ta sống, trong tăng thân, có là không?',
#    'tokens': [51214,
#     761,
#     26994,
#     1846,
#     262,
#     21092,
#     11,
#     18826,
#     256,
#     34705,
#     258,
#     9667,
#     11,
#     6333,
#     3684,
#     11415,
#     30,
#     51364],
#    'temperature': 0.0,
#    'avg_logprob': -0.7776457134046053,
#    'compression_ratio': 1.294478527607362,
#    'no_speech_prob': 0.32245901226997375},
#   {'id': 26,
#    'seek': 34960,
#    'start': 369.6,
#    'end': 372.6,
#    'text': ' Con mà từng lẽ, là mũ từng lẽ.',
#    'tokens': [51364,
#     2656,
#     275,
#     1467,
#     26834,
#     872,
#     287,
#     15740,
#     11,
#     3684,
#     275,
#     129,
#     102,
#     26834,
#     872,
#     287,
#     15740,
#     13,
#     51514],
#    'temperature': 0.0,
#    'avg_logprob': -0.7776457134046053,
#    'compression_ratio': 1.294478527607362,
#    'no_speech_prob': 0.32245901226997375},
#   {'id': 27,
#    'seek': 34960,
#    'start': 374.6,
#    'end': 376.6,
#    'text': ' Mà nếu khi rồi là không?',
#    'tokens': [51614,
#     376,
#     1467,
#     297,
#     30568,
#     23526,
#     19908,
#     3684,
#     11415,
#     30,
#     51714],
#    'temperature': 0.0,
#    'avg_logprob': -0.7776457134046053,
#    'compression_ratio': 1.294478527607362,
#    'no_speech_prob': 0.32245901226997375},
#   {'id': 28,
#    'seek': 37660,
#    'start': 376.6,
#    'end': 383.6,
#    'text': ' Chính ta chìa nắm vẫn được kích pháp mong thảo, là khóc mong thì hành.',
#    'tokens': [50364,
#     761,
#     26994,
#     1846,
#     417,
#     4749,
#     64,
#     297,
#     41227,
#     49004,
#     15832,
#     350,
#     30839,
#     903,
#     15059,
#     275,
#     556,
#     258,
#     40657,
#     11,
#     3684,
#     7168,
#     40993,
#     275,
#     556,
#     258,
#     4749,
#     276,
#     24449,
#     13,
#     50714],
#    'temperature': 0.0,
#    'avg_logprob': -0.6905252299177538,
#    'compression_ratio': 1.5862068965517242,
#    'no_speech_prob': 0.14842838048934937},
#   {'id': 29,
#    'seek': 37660,
#    'start': 385.6,
#    'end': 389.6,
#    'text': ' Chính ta chìa tới lần thân.',
#    'tokens': [50814,
#     761,
#     26994,
#     1846,
#     417,
#     4749,
#     64,
#     47679,
#     287,
#     18241,
#     258,
#     9667,
#     13,
#     51014],
#    'temperature': 0.0,
#    'avg_logprob': -0.6905252299177538,
#    'compression_ratio': 1.5862068965517242,
#    'no_speech_prob': 0.14842838048934937},
#   {'id': 30,
#    'seek': 37660,
#    'start': 392.6,
#    'end': 394.6,
#    'text': ' Chính ta không tiếp nhận được gì cả?',
#    'tokens': [51164,
#     761,
#     26994,
#     1846,
#     11415,
#     48667,
#     6245,
#     27410,
#     15832,
#     22804,
#     22227,
#     30,
#     51264],
#    'temperature': 0.0,
#    'avg_logprob': -0.6905252299177538,
#    'compression_ratio': 1.5862068965517242,
#    'no_speech_prob': 0.14842838048934937},
#   {'id': 31,
#    'seek': 37660,
#    'start': 394.6,
#    'end': 399.6,
#    'text': ' Chính tập tới, bằng hai thách không, và chính ta từng lẽ bằng hai thách không?',
#    'tokens': [51264,
#     761,
#     26994,
#     256,
#     35148,
#     47679,
#     11,
#     272,
#     27215,
#     21822,
#     258,
#     39569,
#     11415,
#     11,
#     10274,
#     417,
#     26994,
#     1846,
#     26834,
#     872,
#     287,
#     15740,
#     272,
#     27215,
#     21822,
#     258,
#     39569,
#     11415,
#     30,
#     51514],
#    'temperature': 0.0,
#    'avg_logprob': -0.6905252299177538,
#    'compression_ratio': 1.5862068965517242,
#    'no_speech_prob': 0.14842838048934937},
#   {'id': 32,
#    'seek': 37660,
#    'start': 399.6,
#    'end': 402.6,
#    'text': ' Chùa đó, lầm điều lất là đáng tiết.',
#    'tokens': [51514,
#     761,
#     5035,
#     64,
#     17647,
#     11,
#     287,
#     11161,
#     76,
#     42082,
#     287,
#     12436,
#     3684,
#     2934,
#     30344,
#     8757,
#     13888,
#     13,
#     51664],
#    'temperature': 0.0,
#    'avg_logprob': -0.6905252299177538,
#    'compression_ratio': 1.5862068965517242,
#    'no_speech_prob': 0.14842838048934937},
#   {'id': 33,
#    'seek': 40260,
#    'start': 402.6,
#    'end': 407.6,
#    'text': ' Y được cho nên trong ngày đầu, ngày thứ 2, ngày thứ 3.',
#    'tokens': [50364,
#     398,
#     15832,
#     1586,
#     40606,
#     18826,
#     34481,
#     32573,
#     11,
#     34481,
#     47269,
#     568,
#     11,
#     34481,
#     47269,
#     805,
#     13,
#     50614],
#    'temperature': 0.0,
#    'avg_logprob': -0.4159454017557124,
#    'compression_ratio': 1.453125,
#    'no_speech_prob': 0.1576569527387619},
#   {'id': 34,
#    'seek': 40260,
#    'start': 408.6,
#    'end': 414.6,
#    'text': ' Chính ta phải, tiền, chúng ta phải, tiếp nhận.',
#    'tokens': [50664,
#     761,
#     26994,
#     1846,
#     903,
#     18166,
#     11,
#     8757,
#     26871,
#     11,
#     24322,
#     1846,
#     903,
#     18166,
#     11,
#     48667,
#     6245,
#     27410,
#     13,
#     50964],
#    'temperature': 0.0,
#    'avg_logprob': -0.4159454017557124,
#    'compression_ratio': 1.453125,
#    'no_speech_prob': 0.1576569527387619},
#   {'id': 35,
#    'seek': 40260,
#    'start': 415.6,
#    'end': 419.6,
#    'text': ' Chính ta phải đêm cái pháp mong là để thật tập.',
#    'tokens': [51014,
#     761,
#     26994,
#     1846,
#     903,
#     18166,
#     2934,
#     13213,
#     14830,
#     903,
#     15059,
#     275,
#     556,
#     3684,
#     20081,
#     258,
#     25296,
#     256,
#     35148,
#     13,
#     51214],
#    'temperature': 0.0,
#    'avg_logprob': -0.4159454017557124,
#    'compression_ratio': 1.453125,
#    'no_speech_prob': 0.1576569527387619},
#   {'id': 36,
#    'seek': 40260,
#    'start': 420.6,
#    'end': 423.6,
#    'text': ' Tại vì thật tập tà lần không?',
#    'tokens': [51264,
#     314,
#     12745,
#     37902,
#     258,
#     25296,
#     256,
#     35148,
#     256,
#     1467,
#     287,
#     18241,
#     11415,
#     30,
#     51414],
#    'temperature': 0.0,
#    'avg_logprob': -0.4159454017557124,
#    'compression_ratio': 1.453125,
#    'no_speech_prob': 0.1576569527387619},
#   {'id': 37,
#    'seek': 40260,
#    'start': 424.6,
#    'end': 428.6,
#    'text': ' Mà giữ dàng hơn thật tập mục mình.',
#    'tokens': [51464,
#     376,
#     1467,
#     1735,
#     12225,
#     274,
#     26653,
#     34335,
#     258,
#     25296,
#     256,
#     35148,
#     275,
#     37664,
#     14526,
#     13,
#     51664],
#    'temperature': 0.0,
#    'avg_logprob': -0.4159454017557124,
#    'compression_ratio': 1.453125,
#    'no_speech_prob': 0.1576569527387619},
#   {'id': 38,
#    'seek': 42860,
#    'start': 429.6,
#    'end': 434.6,
#    'text': ' Tại vì đẹp của mình, với dàng hơn, cạo tế tâm lần, hay lần ngang là.',
#    'tokens': [50414,
#     314,
#     12745,
#     37902,
#     2934,
#     26965,
#     79,
#     11990,
#     14526,
#     11,
#     18916,
#     274,
#     26653,
#     34335,
#     11,
#     269,
#     43789,
#     256,
#     6115,
#     256,
#     24484,
#     287,
#     18241,
#     11,
#     4842,
#     287,
#     18241,
#     6415,
#     656,
#     3684,
#     13,
#     50664],
#    'temperature': 0.0,
#    'avg_logprob': -0.5972006818373427,
#    'compression_ratio': 1.6879699248120301,
#    'no_speech_prob': 0.2210160344839096},
#   {'id': 39,
#    'seek': 42860,
#    'start': 435.6,
#    'end': 438.6,
#    'text': ' Tại vì ở tay lần không thì ai cũng thật tập tạp.',
#    'tokens': [50714,
#     314,
#     12745,
#     37902,
#     19272,
#     39224,
#     287,
#     18241,
#     11415,
#     17510,
#     9783,
#     22747,
#     258,
#     25296,
#     256,
#     35148,
#     256,
#     5890,
#     79,
#     13,
#     50864],
#    'temperature': 0.0,
#    'avg_logprob': -0.5972006818373427,
#    'compression_ratio': 1.6879699248120301,
#    'no_speech_prob': 0.2210160344839096},
#   {'id': 40,
#    'seek': 42860,
#    'start': 439.6,
#    'end': 445.6,
#    'text': ' Và trong cái không không cần của sự thật tập nó, thì sự thật tập của mình, trở thành rất dễ dàng.',
#    'tokens': [50914,
#     44851,
#     18826,
#     14830,
#     11415,
#     11415,
#     47580,
#     11990,
#     33602,
#     258,
#     25296,
#     256,
#     35148,
#     6604,
#     11,
#     17510,
#     33602,
#     258,
#     25296,
#     256,
#     35148,
#     11990,
#     14526,
#     11,
#     504,
#     13755,
#     39953,
#     25147,
#     274,
#     36664,
#     274,
#     26653,
#     13,
#     51214],
#    'temperature': 0.0,
#    'avg_logprob': -0.5972006818373427,
#    'compression_ratio': 1.6879699248120301,
#    'no_speech_prob': 0.2210160344839096},
#   {'id': 41,
#    'seek': 42860,
#    'start': 449.6,
#    'end': 451.6,
#    'text': ' Chắc mình tắt, sự thật tà lần không?',
#    'tokens': [51414,
#     761,
#     30838,
#     14526,
#     256,
#     31454,
#     11,
#     33602,
#     258,
#     25296,
#     256,
#     1467,
#     287,
#     18241,
#     11415,
#     30,
#     51514],
#    'temperature': 0.0,
#    'avg_logprob': -0.5972006818373427,
#    'compression_ratio': 1.6879699248120301,
#    'no_speech_prob': 0.2210160344839096},
#   {'id': 42,
#    'seek': 42860,
#    'start': 451.6,
#    'end': 453.6,
#    'text': ' Chính ta không có đi.',
#    'tokens': [51514, 761, 26994, 1846, 11415, 6333, 13264, 13, 51614],
#    'temperature': 0.0,
#    'avg_logprob': -0.5972006818373427,
#    'compression_ratio': 1.6879699248120301,
#    'no_speech_prob': 0.2210160344839096},
#   {'id': 43,
#    'seek': 42860,
#    'start': 453.6,
#    'end': 457.6,
#    'text': ' Bằng cái phương thức nảo khác ngoài với phương tháp pháp thì hành.',
#    'tokens': [51614,
#     363,
#     27215,
#     14830,
#     903,
#     24605,
#     258,
#     27138,
#     297,
#     40657,
# ...
#    'compression_ratio': 1.5426356589147288,
#    'no_speech_prob': 0.18169257044792175},
#   {'id': 960,
#    'seek': 432332,
#    'start': 4328.32,
#    'end': 4331.32,
#    'text': ' Mà chưa đọc kinh ăn bằng thủ ý.',
#    'tokens': [50614,
#     376,
#     1467,
#     46575,
#     2934,
#     12935,
#     66,
#     350,
#     10085,
#     28657,
#     272,
#     27215,
#     258,
#     28903,
#     49291,
#     13,
#     50764],
#    'temperature': 0.0,
#    'avg_logprob': -0.45403456150140975,
#    'compression_ratio': 1.5426356589147288,
#    'no_speech_prob': 0.18169257044792175},
#   {'id': 961,
#    'seek': 432332,
#    'start': 4331.32,
#    'end': 4333.32,
#    'text': ' Mà chưa thích tập và ăn bằng thủ ý.',
#    'tokens': [50764,
#     376,
#     1467,
#     46575,
#     258,
#     30839,
#     256,
#     35148,
#     10274,
#     28657,
#     272,
#     27215,
#     258,
#     28903,
#     49291,
#     13,
#     50864],
#    'temperature': 0.0,
#    'avg_logprob': -0.45403456150140975,
#    'compression_ratio': 1.5426356589147288,
#    'no_speech_prob': 0.18169257044792175},
#   {'id': 962,
#    'seek': 432332,
#    'start': 4333.32,
#    'end': 4335.32,
#    'text': ' Cái chỗ đó không thể chắc nhận được.',
#    'tokens': [50864,
#     383,
#     28249,
#     23579,
#     245,
#     17647,
#     11415,
#     24491,
#     417,
#     30838,
#     6245,
#     27410,
#     15832,
#     13,
#     50964],
#    'temperature': 0.0,
#    'avg_logprob': -0.45403456150140975,
#    'compression_ratio': 1.5426356589147288,
#    'no_speech_prob': 0.18169257044792175},
#   {'id': 963,
#    'seek': 432332,
#    'start': 4338.32,
#    'end': 4340.32,
#    'text': ' Thế thả.',
#    'tokens': [51114, 334, 6115, 258, 7398, 13, 51214],
#    'temperature': 0.0,
#    'avg_logprob': -0.45403456150140975,
#    'compression_ratio': 1.5426356589147288,
#    'no_speech_prob': 0.18169257044792175},
#   {'id': 964,
#    'seek': 432332,
#    'start': 4340.32,
#    'end': 4341.32,
#    'text': ' Nó thục.',
#    'tokens': [51214, 426, 812, 258, 37664, 13, 51264],
#    'temperature': 0.0,
#    'avg_logprob': -0.45403456150140975,
#    'compression_ratio': 1.5426356589147288,
#    'no_speech_prob': 0.18169257044792175},
#   {'id': 965,
#    'seek': 432332,
#    'start': 4341.32,
#    'end': 4343.32,
#    'text': ' Trước hết nó thục về thật.',
#    'tokens': [51264,
#     1765,
#     19578,
#     44414,
#     6604,
#     258,
#     37664,
#     25652,
#     258,
#     25296,
#     13,
#     51364],
#    'temperature': 0.0,
#    'avg_logprob': -0.45403456150140975,
#    'compression_ratio': 1.5426356589147288,
#    'no_speech_prob': 0.18169257044792175},
#   {'id': 966,
#    'seek': 432332,
#    'start': 4343.32,
#    'end': 4346.32,
#    'text': ' Theo kinh quan này mới thả.',
#    'tokens': [51364,
#     42519,
#     350,
#     10085,
#     19068,
#     12542,
#     37328,
#     258,
#     7398,
#     13,
#     51514],
#    'temperature': 0.0,
#    'avg_logprob': -0.45403456150140975,
#    'compression_ratio': 1.5426356589147288,
#    'no_speech_prob': 0.18169257044792175},
#   {'id': 967,
#    'seek': 432332,
#    'start': 4346.32,
#    'end': 4351.32,
#    'text': ' Cũng như là theo kinh n�� sửa là 2 kinh mà mình nói tới sang này.',
#    'tokens': [51514,
#     383,
#     129,
#     21077,
#     16228,
#     3684,
#     40594,
#     350,
#     10085,
#     297,
#     15773,
#     262,
#     27801,
#     64,
#     3684,
#     568,
#     350,
#     10085,
#     13901,
#     14526,
#     27508,
#     47679,
#     9980,
#     12542,
#     13,
#     51764],
#    'temperature': 0.0,
#    'avg_logprob': -0.45403456150140975,
#    'compression_ratio': 1.5426356589147288,
#    'no_speech_prob': 0.18169257044792175},
#   {'id': 968,
#    'seek': 435132,
#    'start': 4351.32,
#    'end': 4353.32,
#    'text': ' Chị thân nè.',
#    'tokens': [50364, 761, 11708, 258, 9667, 297, 1462, 13, 50464],
#    'temperature': 0.0,
#    'avg_logprob': -0.9249708311898368,
#    'compression_ratio': 0.7,
#    'no_speech_prob': 0.28255635499954224},
#   {'id': 969,
#    'seek': 435132,
#    'start': 4353.32,
#    'end': 4355.32,
#    'text': ' Là.',
#    'tokens': [50464, 22237, 13, 50564],
#    'temperature': 0.0,
#    'avg_logprob': -0.9249708311898368,
#    'compression_ratio': 0.7,
#    'no_speech_prob': 0.28255635499954224},
#   {'id': 970,
#    'seek': 438132,
#    'start': 4381.32,
#    'end': 4383.32,
#    'text': ' Chị thân nè.',
#    'tokens': [50364, 761, 11708, 258, 9667, 297, 1462, 13, 50464],
#    'temperature': 0.0,
#    'avg_logprob': -0.32029638687769574,
#    'compression_ratio': 2.2873563218390807,
#    'no_speech_prob': 0.20998507738113403},
#   {'id': 971,
#    'seek': 438132,
#    'start': 4383.32,
#    'end': 4385.32,
#    'text': ' Chị thân nè.',
#    'tokens': [50464, 761, 11708, 258, 9667, 297, 1462, 13, 50564],
#    'temperature': 0.0,
#    'avg_logprob': -0.32029638687769574,
#    'compression_ratio': 2.2873563218390807,
#    'no_speech_prob': 0.20998507738113403},
#   {'id': 972,
#    'seek': 438132,
#    'start': 4385.32,
#    'end': 4387.32,
#    'text': ' Chị thân nè.',
#    'tokens': [50564, 761, 11708, 258, 9667, 297, 1462, 13, 50664],
#    'temperature': 0.0,
#    'avg_logprob': -0.32029638687769574,
#    'compression_ratio': 2.2873563218390807,
#    'no_speech_prob': 0.20998507738113403},
#   {'id': 973,
#    'seek': 438132,
#    'start': 4387.32,
#    'end': 4389.32,
#    'text': ' Chị thân nè.',
#    'tokens': [50664, 761, 11708, 258, 9667, 297, 1462, 13, 50764],
#    'temperature': 0.0,
#    'avg_logprob': -0.32029638687769574,
#    'compression_ratio': 2.2873563218390807,
#    'no_speech_prob': 0.20998507738113403},
#   {'id': 974,
#    'seek': 438132,
#    'start': 4389.32,
#    'end': 4391.32,
#    'text': ' Chị thân nè.',
#    'tokens': [50764, 761, 11708, 258, 9667, 297, 1462, 13, 50864],
#    'temperature': 0.0,
#    'avg_logprob': -0.32029638687769574,
#    'compression_ratio': 2.2873563218390807,
#    'no_speech_prob': 0.20998507738113403},
#   {'id': 975,
#    'seek': 438132,
#    'start': 4391.32,
#    'end': 4393.32,
#    'text': ' Chị thân nè.',
#    'tokens': [50864, 761, 11708, 258, 9667, 297, 1462, 13, 50964],
#    'temperature': 0.0,
#    'avg_logprob': -0.32029638687769574,
#    'compression_ratio': 2.2873563218390807,
#    'no_speech_prob': 0.20998507738113403},
#   {'id': 976,
#    'seek': 438132,
#    'start': 4399.32,
#    'end': 4400.32,
#    'text': ' Thân.',
#    'tokens': [51264, 334, 9667, 13, 51314],
#    'temperature': 0.0,
#    'avg_logprob': -0.32029638687769574,
#    'compression_ratio': 2.2873563218390807,
#    'no_speech_prob': 0.20998507738113403},
#   {'id': 977,
#    'seek': 438132,
#    'start': 4400.32,
#    'end': 4403.32,
#    'text': ' Tất cả các nối tưởng đầu của chân nhỉ.',
#    'tokens': [51314,
#     314,
#     12436,
#     22227,
#     13250,
#     297,
#     24273,
#     256,
#     49301,
#     32573,
#     11990,
#     417,
#     9667,
#     6245,
#     43325,
#     13,
#     51464],
#    'temperature': 0.0,
#    'avg_logprob': -0.32029638687769574,
#    'compression_ratio': 2.2873563218390807,
#    'no_speech_prob': 0.20998507738113403},
#   {'id': 978,
#    'seek': 438132,
#    'start': 4403.32,
#    'end': 4405.32,
#    'text': ' Chị thân nè.',
#    'tokens': [51464, 761, 11708, 258, 9667, 297, 1462, 13, 51564],
#    'temperature': 0.0,
#    'avg_logprob': -0.32029638687769574,
#    'compression_ratio': 2.2873563218390807,
#    'no_speech_prob': 0.20998507738113403},
#   {'id': 979,
#    'seek': 438132,
#    'start': 4405.32,
#    'end': 4407.32,
#    'text': ' Chị thân nè.',
#    'tokens': [51564, 761, 11708, 258, 9667, 297, 1462, 13, 51664],
#    'temperature': 0.0,
#    'avg_logprob': -0.32029638687769574,
#    'compression_ratio': 2.2873563218390807,
#    'no_speech_prob': 0.20998507738113403},
#   {'id': 980,
#    'seek': 440732,
#    'start': 4408.32,
#    'end': 4411.32,
#    'text': ' Bà hay thả là một yêu tổ thật về thân.',
#    'tokens': [50414,
#     363,
#     1467,
#     4842,
#     258,
#     7398,
#     3684,
#     15486,
#     49107,
#     256,
#     20950,
#     258,
#     25296,
#     25652,
#     258,
#     9667,
#     13,
#     50564],
#    'temperature': 0.0,
#    'avg_logprob': -0.5115605431634027,
#    'compression_ratio': 1.3414634146341464,
#    'no_speech_prob': 0.3860126733779907},
#   {'id': 981,
#    'seek': 440732,
#    'start': 4423.32,
#    'end': 4430.32,
#    'text': ' Nhưng mà chị yêu tổ hơi thả thật về thân đó là chính là cái mặc là cái câu.',
#    'tokens': [51164,
#     26390,
#     42509,
#     13901,
#     417,
#     11708,
#     49107,
#     256,
#     20950,
#     276,
#     21537,
#     258,
#     7398,
#     258,
#     25296,
#     25652,
#     258,
#     9667,
#     17647,
#     3684,
#     417,
#     26994,
#     3684,
#     14830,
#     275,
#     38464,
#     3684,
#     14830,
#     19288,
#     84,
#     13,
#     51514],
#    'temperature': 0.0,
#    'avg_logprob': -0.5115605431634027,
#    'compression_ratio': 1.3414634146341464,
#    'no_speech_prob': 0.3860126733779907},
#   {'id': 982,
#    'seek': 440732,
#    'start': 4431.32,
#    'end': 4435.32,
#    'text': ' Lất đưa ta sang hợp nhất và đoàn tụ với cái tâm.',
#    'tokens': [51564,
#     441,
#     12436,
#     2934,
#     27060,
#     1846,
#     9980,
#     276,
#     27836,
#     79,
#     41081,
#     10274,
#     2934,
#     78,
#     22476,
#     256,
#     17740,
#     18916,
#     14830,
#     256,
#     24484,
#     13,
#     51764],
#    'temperature': 0.0,
#    'avg_logprob': -0.5115605431634027,
#    'compression_ratio': 1.3414634146341464,
#    'no_speech_prob': 0.3860126733779907},
#   {'id': 983,
#    'seek': 443732,
#    'start': 4437.32,
#    'end': 4439.32,
#    'text': ' Chị thân nè.',
#    'tokens': [50364, 761, 11708, 258, 9667, 297, 1462, 13, 50464],
#    'temperature': 1.0,
#    'avg_logprob': -1.914077447385204,
#    'compression_ratio': 1.4325259515570934,
#    'no_speech_prob': 0.2555619776248932},
#   {'id': 984,
#    'seek': 443732,
#    'start': 4439.32,
#    'end': 4441.32,
#    'text': ' Vòng th incub mày.',
#    'tokens': [50464, 691, 36782, 258, 33345, 45464, 13, 50564],
#    'temperature': 1.0,
#    'avg_logprob': -1.914077447385204,
#    'compression_ratio': 1.4325259515570934,
#    'no_speech_prob': 0.2555619776248932},
#   {'id': 985,
#    'seek': 443732,
#    'start': 4441.32,
#    'end': 4443.32,
#    'text': ' Rồi thứ hết lên.',
#    'tokens': [50564, 497, 15695, 47269, 276, 13888, 33368, 13, 50664],
#    'temperature': 1.0,
#    'avg_logprob': -1.914077447385204,
#    'compression_ratio': 1.4325259515570934,
#    'no_speech_prob': 0.2555619776248932},
#   {'id': 986,
#    'seek': 443732,
#    'start': 4443.32,
#    'end': 4445.32,
#    'text': ' Trân nîm.',
#    'tokens': [50664, 1765, 9667, 297, 7517, 76, 13, 50764],
#    'temperature': 1.0,
#    'avg_logprob': -1.914077447385204,
#    'compression_ratio': 1.4325259515570934,
#    'no_speech_prob': 0.2555619776248932},
#   {'id': 987,
#    'seek': 443732,
#    'start': 4445.32,
#    'end': 4449.32,
#    'text': ' Lưa là trân nメ về hơi thа.',
#    'tokens': [50764,
#     441,
#     27060,
#     3684,
#     504,
#     9667,
#     297,
#     21647,
#     25652,
#     276,
#     21537,
#     258,
#     386,
#     13,
#     50964],
#    'temperature': 1.0,
#    'avg_logprob': -1.914077447385204,
#    'compression_ratio': 1.4325259515570934,
#    'no_speech_prob': 0.2555619776248932},
#   {'id': 988,
#    'seek': 443732,
#    'start': 4449.32,
#    'end': 4455.32,
#    'text': ' Chúc tạo biến ràng khi trong đổ xuân này chúng tập thả.',
#    'tokens': [50964,
#     761,
#     31585,
#     256,
#     43789,
#     3228,
#     16240,
#     367,
#     26653,
#     23526,
#     18826,
#     2934,
#     20950,
#     41104,
#     9667,
#     12542,
#     24322,
#     256,
#     35148,
#     258,
#     7398,
#     13,
#     51264],
#    'temperature': 1.0,
#    'avg_logprob': -1.914077447385204,
#    'compression_ratio': 1.4325259515570934,
#    'no_speech_prob': 0.2555619776248932},
#   {'id': 989,
#    'seek': 443732,
#    'start': 4455.32,
#    'end': 4459.32,
#    'text': ' Nhưng mà chúng ta không thở có ý thức.',
#    'tokens': [51264,
#     26390,
#     42509,
#     13901,
#     24322,
#     1846,
#     11415,
#     258,
#     13755,
#     6333,
#     49291,
#     258,
#     27138,
#     13,
#     51464],
#    'temperature': 1.0,
#    'avg_logprob': -1.914077447385204,
#    'compression_ratio': 1.4325259515570934,
#    'no_speech_prob': 0.2555619776248932},
#   {'id': 990,
#    'seek': 443732,
#    'start': 4459.32,
#    'end': 4461.32,
#    'text': ' Bá khi mặc vào chịu ở chớ lý thức và học hay hơi thатели có ý thức.',
#    'tokens': [51464,
#     363,
#     842,
#     23526,
#     275,
#     38464,
#     24995,
#     45167,
#     84,
#     19272,
#     23579,
#     249,
#     287,
#     11822,
#     258,
#     27138,
#     10274,
#     46786,
#     4842,
#     276,
#     21537,
#     258,
#     43512,
#     6333,
#     49291,
#     258,
#     27138,
#     13,
#     51564],
#    'temperature': 1.0,
#    'avg_logprob': -1.914077447385204,
#    'compression_ratio': 1.4325259515570934,
#    'no_speech_prob': 0.2555619776248932},
#   {'id': 991,
#    'seek': 443732,
#    'start': 4461.32,
#    'end': 4463.32,
#    'text': ' Về hơi th 하면서 có ý thức.',
#    'tokens': [51564,
#     691,
#     9602,
#     276,
#     21537,
#     258,
#     37466,
#     6333,
#     49291,
#     258,
#     27138,
#     13,
#     51664],
#    'temperature': 1.0,
#    'avg_logprob': -1.914077447385204,
#    'compression_ratio': 1.4325259515570934,
#    'no_speech_prob': 0.2555619776248932},
#   {'id': 992,
#    'seek': 443732,
#    'start': 4463.32,
#    'end': 4464.32,
#    'text': ' Vi лай ta nè.',
#    'tokens': [51664, 6626, 35475, 1846, 297, 1462, 13, 51714],
#    'temperature': 1.0,
#    'avg_logprob': -1.914077447385204,
#    'compression_ratio': 1.4325259515570934,
#    'no_speech_prob': 0.2555619776248932},
#   {'id': 993,
#    'seek': 443732,
#    'start': 4464.32,
#    'end': 4466.32,
#    'text': ' B crochet này mới th расс.',
#    'tokens': [51714, 363, 9387, 12542, 37328, 258, 23345, 13, 51814],
#    'temperature': 1.0,
#    'avg_logprob': -1.914077447385204,
#    'compression_ratio': 1.4325259515570934,
#    'no_speech_prob': 0.2555619776248932},
#   {'id': 994,
#    'seek': 446732,
#    'start': 4467.32,
#    'end': 4475.32,
#    'text': ' Công kinh quán nhé mấy thật bục dạy.',
#    'tokens': [50364,
#     383,
#     8217,
#     350,
#     10085,
#     421,
#     7200,
#     6245,
#     526,
#     275,
#     13417,
#     258,
#     25296,
#     272,
#     37664,
#     274,
#     5890,
#     88,
#     13,
#     50764],
#    'temperature': 0.2,
#    'avg_logprob': -0.7732409359364028,
#    'compression_ratio': 1.3163841807909604,
#    'no_speech_prob': 0.5217990875244141},
#   {'id': 995,
#    'seek': 446732,
#    'start': 4475.32,
#    'end': 4480.32,
#    'text': ' Bục dạy bốn bài tập.',
#    'tokens': [50764,
#     363,
#     37664,
#     274,
#     5890,
#     88,
#     272,
#     31754,
#     272,
#     21971,
#     256,
#     35148,
#     13,
#     51014],
#    'temperature': 0.2,
#    'avg_logprob': -0.7732409359364028,
#    'compression_ratio': 1.3163841807909604,
#    'no_speech_prob': 0.5217990875244141},
#   {'id': 996,
#    'seek': 446732,
#    'start': 4480.32,
#    'end': 4485.32,
#    'text': ' Bốn có thể nói là bốn cái dạy bốn cái sự hương dẫn,',
#    'tokens': [51014,
#     363,
#     31754,
#     6333,
#     24491,
#     27508,
#     3684,
#     272,
#     31754,
#     14830,
#     274,
#     5890,
#     88,
#     272,
#     31754,
#     14830,
#     33602,
#     276,
#     24605,
#     274,
#     35400,
#     11,
#     51264],
#    'temperature': 0.2,
#    'avg_logprob': -0.7732409359364028,
#    'compression_ratio': 1.3163841807909604,
#    'no_speech_prob': 0.5217990875244141},
#   {'id': 997,
#    'seek': 446732,
#    'start': 4485.32,
#    'end': 4490.32,
#    'text': ' về sự thực tập, đứa hẹn thế hay thật.',
#    'tokens': [51264,
#     25652,
#     33602,
#     50183,
#     256,
#     35148,
#     11,
#     2934,
#     13905,
#     64,
#     276,
#     26965,
#     77,
#     27100,
#     4842,
#     258,
#     25296,
#     13,
#     51514],
#    'temperature': 0.2,
#    'avg_logprob': -0.7732409359364028,
#    'compression_ratio': 1.3163841807909604,
#    'no_speech_prob': 0.5217990875244141},
#   {'id': 998,
#    'seek': 446732,
#    'start': 4490.32,
#    'end': 4494.32,
#    'text': ' Thế vào một hơi dài.',
#    'tokens': [51514,
#     334,
#     6115,
#     24995,
#     15486,
#     276,
#     21537,
#     274,
#     21971,
#     13,
#     51714],
#    'temperature': 0.2,
#    'avg_logprob': -0.7732409359364028,
#    'compression_ratio': 1.3163841807909604,
#    'no_speech_prob': 0.5217990875244141},
#   {'id': 999,
#    'seek': 449432,
#    'start': 4494.32,
#    'end': 4497.32,
#    'text': ' Tụi biết là tôi thử vào một hơi dài.',
#    'tokens': [50364,
#     314,
#     17740,
#     72,
#     28432,
#     3684,
#     22336,
#     258,
#     27801,
#     24995,
#     15486,
#     276,
#     21537,
#     274,
#     21971,
#     13,
#     50514],
#    'temperature': 0.0,
#    'avg_logprob': -0.43093031196184056,
#    'compression_ratio': 1.435897435897436,
#    'no_speech_prob': 0.03406809642910957},
#   ...],
#  'language': 'vi'}
